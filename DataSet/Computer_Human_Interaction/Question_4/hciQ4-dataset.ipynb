# %% [markdown]
# ChatGLM

# %%
Q={}
Question_4 = "(Adaptive Interface Responsiveness) 系统的自适应界面是否能有效响应你的需求变化？(Adaptive Interface Issues) 在自适应过程中，你是否遇到过任何问题？(Desired Features in Adaptive Interfaces) 你希望自适应界面增加哪些功能来提升适应性？"
questions_4 = [
    "系统的自适应界面是否能有效响应你的需求变化？",
    "在自适应过程中，你是否遇到过任何问题？",
    "你希望自适应界面增加哪些功能来提升适应性？"
]
responses_chatglm = answers = {

   "人机交互研究员": [
        "系统的自适应界面能够有效响应我的需求变化，但在处理复杂交互场景时仍有改进空间。",
        "在自适应过程中，我遇到了一些界面元素与功能匹配不准确的问题。",
        "我希望自适应界面能够提供更加精准的功能匹配和更加灵活的交互方式。"
    ],
    "交互设计专家": [
        "系统的自适应界面在设计上基本符合我的需求变化，但在处理设计创新时有些不足。",
        "在自适应过程中，我遇到了一些界面布局与设计理念不匹配的问题。",
        "我希望自适应界面能够提供更加灵活和可自定义的界面布局，以及更加创新的设计工具。"
    ],
    "计算机科学教授": [
        "系统的自适应界面能够有效响应我的需求变化，但在教学演示时，有时输入响应不够迅速。",
        "在自适应过程中，我遇到了一些输入设备与教学流程不匹配的问题。",
        "我希望自适应界面能够提供更快的输入响应和更稳定的系统性能，以及更好的教学辅助工具。"
    ],
    "人工智能研究员": [
        "系统的自适应界面能够有效响应我的需求变化，但在数据处理和模型训练时，有时会遇到效率问题。",
        "在自适应过程中，我遇到了一些输入设备与工作流程不匹配的问题。",
        "我希望自适应界面能够提供更加高效的数据输入和处理功能，以及更加灵活的输入设备。"
    ],
    "认知科学专家": [
        "系统的自适应界面能够有效响应我的需求变化，但在模拟复杂认知任务时，交互体验还有待提升。",
        "在自适应过程中，我遇到了一些交互体验不够自然和直观的问题。",
        "我希望自适应界面能够提供更加自然和直观的交互方式，以及更加灵活的输入设备。"
    ],
    "社会学研究员": [
        "系统的自适应界面能够有效响应我的需求变化，但在数据分析时，输入设备的响应速度有些慢。",
        "在自适应过程中，我遇到了一些输入设备与数据分析软件集成不够紧密的问题。",
        "我希望自适应界面能够提供更加快速的响应和更好的软件集成，以及更加灵活的输入设备。"
    ],
    "虚拟现实专家": [
        "系统的自适应界面能够有效响应我的需求变化，但在虚拟现实应用中，手柄的舒适度有待提高。",
        "在自适应过程中，我遇到了一些手柄操作与虚拟环境不匹配的问题。",
        "我希望自适应界面能够提供更加舒适和精准的虚拟现实交互体验，以及更加灵活的输入设备。"
    ],
    "技术伦理学家": [
        "系统的自适应界面能够有效响应我的需求变化，但在处理敏感数据时，输入设备的安全性有待提高。",
        "在自适应过程中，我遇到了一些输入设备在处理敏感数据时的安全漏洞。",
        "我希望自适应界面能够提供更加安全和可靠的数据处理功能，以及更加灵活的输入设备。"
    ],
    "用户体验研究员": [
        "系统的自适应界面能够有效响应我的需求变化，但在用户研究中，输入设备的可用性有待提升。",
        "在自适应过程中，我遇到了一些输入设备在用户研究中不够直观和易用的问题。",
        "我希望自适应界面能够提供更加直观和易用的用户研究工具，以及更加灵活的输入设备。"
    ],
    "人机交互技术顾问": [
        "系统的自适应界面能够有效响应我的需求变化，但在定制化解决方案时，输入设备的灵活性有待提高。",
        "在自适应过程中，我遇到了一些输入设备在定制化解决方案中的限制。",
        "我希望自适应界面能够提供更加灵活和可定制的解决方案，以及更加灵活的输入设备。"
    ],
   "软件开发者": [
        "系统的自适应界面能够有效响应我的需求变化，但在开发复杂项目时，输入设备的响应速度有些慢。",
        "在自适应过程中，我遇到了一些输入设备在处理复杂项目需求时的效率问题。",
        "我希望自适应界面能够提供更加快速和高效的开发工具，以及更加灵活的输入设备。"
    ],
    "UX/UI设计师": [
        "系统的自适应界面在设计上基本符合我的需求变化，但在设计创新时有些不足。",
        "在自适应过程中，我遇到了一些界面布局与设计理念不匹配的问题。",
        "我希望自适应界面能够提供更加灵活和可自定义的界面布局，以及更加创新的设计工具。"
    ],
    "产品经理": [
        "系统的自适应界面能够有效响应我的需求变化，但在市场分析时，输入设备的实时数据处理功能还有待提升。",
        "在自适应过程中，我遇到了一些输入设备在市场分析中的实时数据处理问题。",
        "我希望自适应界面能够提供更加实时和高效的市场分析工具，以及更加灵活的输入设备。"
    ],
    "技术支持工程师": [
        "系统的自适应界面能够有效响应我的需求变化，但在技术支持中，有时输入响应不够迅速。",
        "在自适应过程中，我遇到了一些输入设备与技术支持流程不匹配的问题。",
        "我希望自适应界面能够提供更快的输入响应和更稳定的系统性能，以及更好的技术支持工具。"
    ],
    "系统管理员": [
        "系统的自适应界面能够有效响应我的需求变化，但在系统管理中，有时输入响应不够迅速。",
        "在自适应过程中，我遇到了一些输入设备与系统管理流程不匹配的问题。",
        "我希望自适应界面能够提供更快的输入响应和更稳定的系统性能，以及更好的系统管理工具。"
    ],
    "数据分析师": [
        "系统的自适应界面能够有效响应我的需求变化，但在数据分析中，有时输入响应不够迅速。",
        "在自适应过程中，我遇到了一些输入设备与数据分析流程不匹配的问题。",
        "我希望自适应界面能够提供更快的输入响应和更稳定的系统性能，以及更好的数据分析工具。"
    ],
    "内容创作者": [
        "系统的自适应界面能够有效响应我的需求变化，但在内容创作中，有时输入响应不够迅速。",
        "在自适应过程中，我遇到了一些输入设备与内容创作流程不匹配的问题。",
        "我希望自适应界面能够提供更快的输入响应和更稳定的系统性能，以及更好的内容创作工具。"
    ],
    "教育技术专家": [
        "系统的自适应界面能够有效响应我的需求变化，但在教育技术中，有时输入响应不够迅速。",
        "在自适应过程中，我遇到了一些输入设备与教育技术流程不匹配的问题。",
        "我希望自适应界面能够提供更快的输入响应和更稳定的系统性能，以及更好的教育技术工具。"
    ],
    "游戏开发者": [
        "系统的自适应界面能够有效响应我的需求变化，但在游戏开发中，有时输入响应不够迅速。",
        "在自适应过程中，我遇到了一些输入设备与游戏开发流程不匹配的问题。",
        "我希望自适应界面能够提供更快的输入响应和更稳定的系统性能，以及更好的游戏开发工具。"
    ],
    "数字营销专员": [
        "系统的自适应界面能够有效响应我的需求变化，但在数字营销中，有时输入响应不够迅速。",
        "在自适应过程中，我遇到了一些输入设备与数字营销流程不匹配的问题。",
        "我希望自适应界面能够提供更快的输入响应和更稳定的系统性能，以及更好的数字营销工具。"
    ],
   "普通消费者": [
        "系统的自适应界面基本符合我的需求变化，但在使用时，有时会遇到一些操作上的不便。",
        "在自适应过程中，我遇到了一些界面元素位置和布局上的问题。",
        "我希望自适应界面能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "中学生": [
        "系统的自适应界面基本符合我的需求变化，但在学习时，有时会遇到一些操作上的不便。",
        "在自适应过程中，我遇到了一些界面元素位置和布局上的问题。",
        "我希望自适应界面能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "家庭主妇/主夫": [
        "系统的自适应界面基本符合我的需求变化，但在日常家务管理时，有时会遇到一些操作上的不便。",
        "在自适应过程中，我遇到了一些界面元素位置和布局上的问题。",
        "我希望自适应界面能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "老年人": [
        "系统的自适应界面基本符合我的需求变化，但在使用时，有时会遇到一些操作上的不便。",
        "在自适应过程中，我遇到了一些界面元素位置和布局上的问题。",
        "我希望自适应界面能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "残障人士": [
        "系统的自适应界面基本符合我的需求变化，但在使用时，有时会遇到一些操作上的不便。",
        "在自适应过程中，我遇到了一些界面元素位置和布局上的问题。",
        "我希望自适应界面能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "零售店员": [
        "系统的自适应界面基本符合我的需求变化，但在工作操作时，有时会遇到一些操作上的不便。",
        "在自适应过程中，我遇到了一些界面元素位置和布局上的问题。",
        "我希望自适应界面能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "非技术工作者": [
        "系统的自适应界面基本符合我的需求变化，但在日常工作操作时，有时会遇到一些操作上的不便。",
        "在自适应过程中，我遇到了一些界面元素位置和布局上的问题。",
        "我希望自适应界面能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "自由职业者": [
        "系统的自适应界面基本符合我的需求变化，但在工作操作时，有时会遇到一些操作上的不便。",
        "在自适应过程中，我遇到了一些界面元素位置和布局上的问题。",
        "我希望自适应界面能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "游戏爱好者": [
        "系统的自适应界面基本符合我的需求变化，但在游戏操作时，有时会遇到一些操作上的不便。",
        "在自适应过程中，我遇到了一些界面元素位置和布局上的问题。",
        "我希望自适应界面能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "退休人员": [
        "系统的自适应界面基本符合我的需求变化，但在日常休闲活动时，有时会遇到一些操作上的不便。",
        "在自适应过程中，我遇到了一些界面元素位置和布局上的问题。",
        "我希望自适应界面能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ]
}


Q["Question_4"]={"Question_4":Question_4, "questions_4":questions_4,"responses_chatglm":responses_chatglm}

# %% [markdown]
# Qwen

# %%
responses_qwen = {
     "人机交互研究员": [
        "自适应界面应该能够根据用户的上下文和行为自动调整布局和功能，以优化用户体验。",
        "在某些情况下，自适应界面的变化可能会让人感到困惑，尤其是当变化过于频繁时。",
        "我希望自适应界面能够支持更细致的个性化设置，让用户能够微调界面的自适应逻辑。"
    ],
    "交互设计专家": [
        "自适应界面对于提高产品的可用性至关重要，尤其是在多设备环境下。",
        "有时，自适应界面的改变可能会导致用户的学习成本增加。",
        "我希望自适应界面能够提供一种简洁的方式让用户控制界面的变化。"
    ],
    "计算机科学教授": [
        "自适应界面的设计是一个重要的研究领域，它涉及到多种算法和技术。",
        "在某些情况下，自适应界面可能会导致界面变得难以预测。",
        "我希望自适应界面能够更好地处理多用户场景，并且能够支持多任务处理。"
    ],
    "人工智能研究员": [
        "自适应界面对于开发能够学习用户偏好的智能应用至关重要。",
        "有时候，自适应界面的更新可能会导致用户的习惯被打破。",
        "我希望自适应界面能够具备更强的学习能力，以便更好地预测用户的需求。"
    ],
    "认知科学专家": [
        "自适应界面对于研究人类的认知过程非常有用，特别是关于注意力和记忆的研究。",
        "在某些情况下，自适应界面的变化可能会干扰用户的认知流程。",
        "我希望自适应界面能够更好地模拟人类的认知模型，从而减少用户的认知负荷。"
    ],
    "社会学研究员": [
        "自适应界面的社会影响值得深入研究，特别是在公共空间和社区中。",
        "有时候，自适应界面的变化可能会导致用户之间的交流受到影响。",
        "我希望自适应界面能够更好地支持社区参与和社会互动。"
    ],
    "虚拟现实专家": [
        "自适应界面对于虚拟现实体验来说是不可或缺的，特别是在复杂的虚拟环境中。",
        "有时候，自适应界面的变化可能会让用户感到迷失。",
        "我希望自适应界面能够更好地支持虚拟现实中的导航和交互。"
    ],
    "技术伦理学家": [
        "自适应界面的伦理考量包括隐私和用户控制。",
        "在某些情况下，自适应界面可能会引发隐私担忧。",
        "我希望自适应界面能够提供更透明的隐私设置和更强的用户控制。"
    ],
    "用户体验研究员": [
        "自适应界面对于提升用户体验有着重要作用。",
        "有时候，自适应界面的变化可能会让用户感到不适。",
        "我希望自适应界面能够提供更精细的个性化选项，让用户更好地控制其体验。"
    ],
    "人机交互技术顾问": [
        "自适应界面的应用需要考虑到不同用户群体的需求。",
        "有时候，自适应界面的变化可能会导致用户感到不适应。",
        "我希望自适应界面能够支持更灵活的配置选项，以满足不同用户的需求。"
    ],

    # 中等专业水平角色
    "软件开发者": [
        "自适应界面的实现需要考虑多种编程技术和框架。",
        "有时候，自适应界面的变化可能会导致开发难度增加。",
        "我希望自适应界面能够提供更简单的API来支持开发工作。"
    ],
    "UX/UI设计师": [
        "自适应界面的设计需要考虑多种视觉元素和交互模式。",
        "有时候，自适应界面的变化可能会破坏原有的设计一致性。",
        "我希望自适应界面能够提供更多的设计模板和指南。"
    ],
    "产品经理": [
        "自适应界面的产品化需要平衡用户需求和技术限制。",
        "有时候，自适应界面的变化可能会对产品规划造成影响。",
        "我希望自适应界面能够更好地支持产品迭代和升级。"
    ],
    "技术支持工程师": [
        "自适应界面的支持需要考虑多种设备和技术平台。",
        "有时候，自适应界面的变化可能会导致技术支持的负担增加。",
        "我希望自适应界面能够提供更清晰的故障排除指南。"
    ],
    "系统管理员": [
        "自适应界面的部署需要考虑服务器负载和安全性。",
        "有时候，自适应界面的变化可能会导致系统不稳定。",
        "我希望自适应界面能够提供更强大的监控和管理工具。"
    ],
    "数据分析师": [
        "自适应界面的数据收集对于分析用户行为非常重要。",
        "有时候，自适应界面的变化可能会影响数据分析的准确性。",
        "我希望自适应界面能够提供更全面的数据收集功能。"
    ],
    "内容创作者": [
        "自适应界面对于内容展示来说是一个重要的工具。",
        "有时候，自适应界面的变化可能会对内容的呈现产生负面影响。",
        "我希望自适应界面能够提供更丰富的媒体支持功能。"
    ],
    "教育技术专家": [
        "自适应界面对于在线教育来说是非常有用的。",
        "有时候，自适应界面的变化可能会对学生的学习进度产生影响。",
        "我希望自适应界面能够提供更多的学习资源和支持。"
    ],
    "游戏开发者": [
        "自适应界面对于游戏体验来说是非常关键的。",
        "有时候，自适应界面的变化可能会对游戏的流畅度产生负面影响。",
        "我希望自适应界面能够提供更好的游戏性能优化。"
    ],
    "数字营销专员": [
        "自适应界面对于数字营销来说是一个重要的工具。",
        "有时候，自适应界面的变化可能会对营销策略的实施产生影响。",
        "我希望自适应界面能够提供更强大的营销分析功能。"
    ],

    # 初等专业水平角色
    "普通消费者": [
        "自适应界面让我的使用体验更加顺畅。",
        "有时候，自适应界面的变化可能会让我感到有些混乱。",
        "我希望自适应界面能够提供更简单的设置选项，让我更容易控制界面的行为。"
    ],
    "中学生": [
        "自适应界面让我的学习更加高效。",
        "有时候，自适应界面的变化可能会打断我的学习流程。",
        "我希望自适应界面能够提供更多的学习资源，比如视频教程和练习题。"
    ],
    "家庭主妇/主夫": [
        "自适应界面让我的日常任务变得更加轻松。",
        "有时候，自适应界面的变化可能会让我感到有些困惑。",
        "我希望自适应界面能够提供更多的实用工具，比如菜谱和购物清单。"
    ],
    "老年人": [
        "自适应界面让我的操作变得更加简单。",
        "有时候，自适应界面的变化可能会让我感到有些难以跟上。",
        "我希望自适应界面能够提供更大的字体和图标，让界面更加清晰。"
    ],
    "残障人士": [
        "自适应界面让我的使用变得更加容易。",
        "有时候，自适应界面的变化可能会对我造成不便。",
        "我希望自适应界面能够提供更多的辅助功能，比如语音命令和大字体模式。"
    ],
    "零售店员": [
        "自适应界面让我的工作变得更加高效。",
        "有时候，自适应界面的变化可能会导致我需要重新学习使用界面。",
        "我希望自适应界面能够提供更直接的商品查找功能。"
    ],
    "非技术工作者": [
        "自适应界面让我的日常操作变得更加方便。",
        "有时候，自适应界面的变化可能会让我感到有些困扰。",
        "我希望自适应界面能够提供更简单的操作指南。"
    ],
    "自由职业者": [
        "自适应界面让我的工作变得更加高效。",
        "有时候，自适应界面的变化可能会导致我需要重新适应新的布局。",
        "我希望自适应界面能够提供更便捷的任务管理功能。"
    ],
    "游戏爱好者": [
        "自适应界面让我的游戏体验更加流畅。",
        "有时候，自适应界面的变化可能会对我的游戏进度产生影响。",
        "我希望自适应界面能够提供更多的游戏内辅助工具。"
    ],
    "退休人员": [
        "自适应界面让我的退休生活变得更加有趣。",
        "有时候，自适应界面的变化可能会让我感到有些不适应。",
        "我希望自适应界面能够提供更多的休闲娱乐选项，比如阅读和音乐播放器。"
    ]
}
Q["Question_4"]["responses_qwen"]=responses_qwen

# %% [markdown]
# Coze

# %%
responses_doubao={
    "人机交互研究员": [
        "作为人机交互研究员，系统的自适应界面在一定程度上能响应需求变化，但仍有优化空间。它有时能捕捉到主要需求的转变，但对于细微和特殊的需求变化响应不够精准。",
        "在自适应过程中，遇到过界面调整速度过慢、对复杂需求的理解偏差等问题，影响使用体验。",
        "希望自适应界面能增加对用户行为模式的深度学习功能，以及更智能的预测和主动适应能力。"
    ],
    "交互设计专家": [
        "身为交互设计专家，系统的自适应界面能部分有效响应需求变化，但在保持整体美感和一致性方面还有待加强。",
        "自适应过程中，出现过界面元素布局混乱、色彩搭配不协调等影响视觉体验的问题。",
        "期望自适应界面能增加根据用户情绪和审美偏好进行调整的功能，同时提升界面元素的自适应排版能力。"
    ],
    "计算机科学教授": [
        "以计算机科学教授的角度看，系统的自适应界面在响应需求变化方面的算法和逻辑有待完善。",
        "遇到过自适应不准确导致系统性能下降、资源分配不合理等问题。",
        "希望自适应界面能增强对硬件资源的优化配置和高效利用功能，提升系统的整体性能。"
    ],
    "人工智能研究员": [
        "作为人工智能研究员，系统的自适应界面在处理复杂和动态的需求变化时，智能程度还不够高。",
        "自适应过程中，存在对新出现的需求模式识别慢、适应性调整不够及时的问题。",
        "希望自适应界面能结合更先进的人工智能算法，提升对未知需求的学习和适应能力。"
    ],
    "认知科学专家": [
        "从认知科学角度，系统的自适应界面在符合人类认知习惯和心理预期的需求变化响应上还有差距。",
        "自适应中，有时会出现与用户认知模式冲突、导致操作困惑的问题。",
        "期望自适应界面能基于认知科学原理，更好地适配用户的思维模式和认知过程。"
    ],
    "社会学研究员": [
        "身为社会学研究员，系统的自适应界面在考虑社会文化背景和群体差异导致的需求变化方面不够充分。",
        "遇到过因未充分考虑社会因素而导致的适应性偏差问题。",
        "希望自适应界面能增加对不同社会文化和群体需求的识别和适应功能。"
    ],
    "虚拟现实专家": [
        "作为虚拟现实专家，系统的自适应界面在虚拟环境中的需求变化响应还不够自然和流畅。",
        "自适应过程中，在虚拟场景的切换和交互方式的调整上有时不够顺滑。",
        "期待自适应界面能在虚拟现实中提供更无缝的适应体验，增强环境感知和交互的自然性。"
    ],
    "技术伦理学家": [
        "作为技术伦理学家，系统的自适应界面在伦理层面的需求变化响应需要更谨慎的考量。",
        "遇到过因自适应导致的用户隐私泄露、数据使用不当等伦理问题。",
        "希望自适应界面能建立更严格的伦理规范和保障机制，确保在适应需求变化过程中的合法性和道德性。"
    ],
    "用户体验研究员": [
        "身为用户体验研究员，系统的自适应界面在满足用户直观感受和期望的需求变化响应上还有不足。",
        "自适应中，出现过用户满意度下降、操作便捷性降低等问题。",
        "期望自适应界面能更注重用户情感需求和潜在期望，提升用户的整体满意度。"
    ],
    "人机交互技术顾问": [
        "作为人机交互技术顾问，系统的自适应界面在实际应用中的需求变化响应效果不够稳定和可靠。",
        "遇到过因不同设备和平台的差异导致的自适应不一致问题。",
        "希望自适应界面能提高跨设备和平台的兼容性和一致性，确保稳定的适应性表现。"
    ],
    "软件开发者": [
        "作为软件开发者，系统的自适应界面在与软件开发流程和代码架构的整合方面存在挑战。",
        "自适应过程中，出现过与现有代码冲突、开发维护难度增加等问题。",
        "希望自适应界面能提供更友好的开发接口和工具，降低与软件开发的整合难度。"
    ],
    "UX/UI设计师": [
        "身为UX/UI设计师，系统的自适应界面在保持设计风格和品牌一致性的需求变化响应上有待优化。",
        "自适应中，有时会出现品牌形象受损、设计风格不协调的问题。",
        "期望自适应界面能更好地遵循设计原则和品牌规范，确保在变化中保持统一的视觉形象。"
    ],
    "产品经理": [
        "作为产品经理，系统的自适应界面在满足市场需求和产品定位的变化响应上不够灵活和精准。",
        "遇到过因自适应不当导致产品竞争力下降、用户流失等问题。",
        "希望自适应界面能更好地结合市场动态和产品策略，提升产品的适应性和竞争力。"
    ],
    "技术支持工程师": [
        "作为技术支持工程师，系统的自适应界面在故障诊断和技术支持的需求变化响应上不够高效和准确。",
        "自适应过程中，出现过故障排查困难、技术支持资源分配不合理等问题。",
        "希望自适应界面能提供更清晰的故障提示和技术支持引导，提高服务效率和质量。"
    ],
    "系统管理员": [
        "身为系统管理员，系统的自适应界面在系统性能监控和资源管理的需求变化响应上不够及时和智能。",
        "遇到过因自适应导致系统负载不均衡、资源浪费等问题。",
        "期望自适应界面能加强对系统状态的实时监测和智能调整，优化资源分配和性能表现。"
    ],
    "数据分析师": [
        "作为数据分析师，系统的自适应界面在数据展示和分析需求的变化响应上不够灵活和深入。",
        "自适应过程中，出现过数据可视化效果不佳、分析维度切换困难等问题。",
        "希望自适应界面能提供更丰富的数据展示方式和更便捷的分析操作，满足复杂的数据分析需求。"
    ],
    "内容创作者": [
        "身为内容创作者，系统的自适应界面在创作工具和内容展示的需求变化响应上不够创新和个性化。",
        "自适应中，有时会出现创作灵感受阻、内容展示效果不理想的问题。",
        "期望自适应界面能根据创作者的风格和需求提供更多定制化和创意性的功能。"
    ],
    "教育技术专家": [
        "作为教育技术专家，系统的自适应界面在教育场景和教学方法的需求变化响应上不够贴合教育规律。",
        "遇到过因自适应不当导致教学效果不佳、学生学习体验下降的问题。",
        "希望自适应界面能依据教育理论和学生特点，提供更具针对性和有效性的适应功能。"
    ],
    "游戏开发者": [
        "作为游戏开发者，系统的自适应界面在游戏玩法和用户体验的需求变化响应上不够迅速和精彩。",
        "自适应过程中，出现过游戏平衡性破坏、玩家满意度降低的问题。",
        "希望自适应界面能实时响应游戏内的动态变化，提供更具沉浸感和挑战性的体验。"
    ],
    "数字营销专员": [
        "身为数字营销专员，系统的自适应界面在营销活动和用户互动的需求变化响应上不够敏锐和有效。",
        "自适应中，有时会出现营销策略执行不到位、用户参与度不高的问题。",
        "期望自适应界面能更精准地捕捉市场动态和用户行为，提升营销效果和用户参与度。"
    ],
    "普通消费者": [
        "作为普通消费者，感觉系统的自适应界面有时能响应需求变化，但不太稳定。",
        "自适应过程中，遇到过界面突然变得不好用、操作变得复杂的情况。",
        "希望自适应界面能更简单易懂，操作更方便，能根据我的日常习惯自动调整。"
    ],
    "中学生": [
        "作为中学生，系统的自适应界面不是总能跟上我的需求变化，有点跟不上节奏。",
        "自适应的时候，会出现影响我学习和娱乐的问题，比如界面太乱。",
        "希望自适应界面能更好地适应学习场景，比如自动切换到学习模式，屏蔽一些干扰。"
    ],
    "家庭主妇/主夫": [
        "作为家庭主妇/主夫，系统的自适应界面在处理家务相关需求变化时不太给力。",
        "自适应中，有时会出现不符合家庭使用习惯的情况。",
        "希望自适应界面能增加适合家庭生活的功能，比如根据购物清单自动推荐商品。"
    ],
    "老年人": [
        "作为老年人，系统的自适应界面不太能明白我的需求变化，用起来费劲。",
        "自适应的时候，经常出现我看不懂的情况，很麻烦。",
        "希望自适应界面能更简单明了，字体大一点，操作步骤少一点。"
    ],
    "残障人士": [
        "作为残障人士，系统的自适应界面对我的特殊需求变化响应不够好。",
        "自适应过程中，会遇到不方便操作的问题。",
        "希望自适应界面能增加更多无障碍功能，满足我们的特殊需求。"
    ],
    "零售店员": [
        "作为零售店员，系统的自适应界面在应对销售需求变化时不太及时。",
        "自适应中，有时会出现库存显示不准确、结账流程出错的问题。",
        "希望自适应界面能实时更新销售数据，优化结账流程。"
    ],
    "非技术工作者": [
        "作为非技术工作者，系统的自适应界面有时候不太能适应我的工作需求变化。",
        "自适应时，会出现和工作软件不兼容的问题。",
        "希望自适应界面能更兼容常用的工作软件，操作更轻松。"
    ],
    "自由职业者": [
        "作为自由职业者，系统的自适应界面在满足不同工作场景需求变化方面表现一般。",
        "自适应中，有时会出现网络连接不稳定、数据同步不及时的问题。",
        "希望自适应界面能保证稳定的网络连接，及时同步数据。"
    ],
    "游戏爱好者": [
        "作为游戏爱好者，系统的自适应界面在游戏体验需求变化方面不够出色。",
        "自适应过程中，会出现影响游戏流畅度和画质的问题。",
        "希望自适应界面能根据游戏性能自动优化设置，提升游戏体验。"
    ],
    "退休人员": [
        "作为退休人员，系统的自适应界面对我的需求变化响应不太好，用着不方便。",
        "自适应的时候，经常出现我不会操作的情况。",
        "希望自适应界面能更简洁易用，功能不要太复杂。"
    ]
}
Q["Question_4"]["responses_doubao"]=responses_doubao

# %%
response_qwen2 = {
     # 高等专业水平角色
    "人机交互研究员": [
        "自适应界面能够通过动态调整布局和功能，显著提高用户体验。",
        "在复杂任务中，自适应界面的变化可能会导致用户分心。",
        "希望自适应界面能够集成机器学习算法，以更精准地预测用户需求。"
    ],
    "交互设计专家": [
        "自适应界面对于提升产品的可访问性和可用性至关重要。",
        "有时，自适应界面的调整可能会导致用户感到不连贯。",
        "希望自适应界面能够支持更多元化的交互方式，如手势控制和语音识别。"
    ],
    "计算机科学教授": [
        "自适应界面是未来计算环境的关键组成部分。",
        "在教学场景中，自适应界面的变化可能会干扰学生的注意力。",
        "希望自适应界面能够更好地支持教育工具的整合，如代码编辑器和模拟器。"
    ],
    "人工智能研究员": [
        "自适应界面对于构建智能助手至关重要。",
        "在某些情境下，自适应界面的过度调整可能会引起用户的不适。",
        "希望自适应界面能够支持更复杂的用户意图理解，以提供更加个性化的建议。"
    ],
    "认知科学专家": [
        "自适应界面对于研究人类如何与技术交互提供了宝贵的实验平台。",
        "在认知研究中，自适应界面的变化可能会干扰实验的可控性。",
        "希望自适应界面能够更好地模拟自然交互模式，减少用户的学习曲线。"
    ],
    "社会学研究员": [
        "自适应界面有助于缩小数字鸿沟，促进社会包容。",
        "在多元文化背景下，自适应界面可能会导致文化误解。",
        "希望自适应界面能够更好地支持多语言和跨文化交流。"
    ],
    "虚拟现实专家": [
        "自适应界面对于虚拟现实体验至关重要。",
        "在虚拟环境中，自适应界面的变化可能会导致用户迷失方向。",
        "希望自适应界面能够更好地支持虚拟现实中的沉浸式体验。"
    ],
    "技术伦理学家": [
        "自适应界面的伦理考量包括隐私保护和透明度。",
        "在某些情况下，自适应界面可能会导致隐私泄露。",
        "希望自适应界面能够提供更透明的数据收集和使用机制。"
    ],
    "用户体验研究员": [
        "自适应界面对于提高用户体验有着不可替代的作用。",
        "有时候，自适应界面的变化可能会导致用户混淆。",
        "希望自适应界面能够提供更直观的用户反馈机制，以持续改进。"
    ],
    "人机交互技术顾问": [
        "自适应界面能够帮助企业更好地满足客户需求。",
        "在企业环境中，自适应界面的变化可能会导致员工培训成本增加。",
        "希望自适应界面能够支持更灵活的企业定制选项。"
    ],

    # 中等专业水平角色
    "软件开发者": [
        "自适应界面的实现需要强大的后端支持。",
        "在开发过程中，自适应界面的维护可能会消耗额外的时间。",
        "希望自适应界面能够提供更强大的API，以支持更高级的功能开发。"
    ],
    "UX/UI设计师": [
        "自适应界面的设计需要考虑不同屏幕尺寸。",
        "在设计过程中，自适应界面可能会增加设计复杂性。",
        "希望自适应界面能够提供更多的设计工具和模板。"
    ],
    "产品经理": [
        "自适应界面的产品化需要综合考虑用户需求和技术可行性。",
        "在产品迭代中，自适应界面的变化可能会导致用户流失。",
        "希望自适应界面能够提供更强大的A/B测试工具。"
    ],
    "技术支持工程师": [
        "自适应界面的支持需要考虑多种操作系统。",
        "在技术支持方面，自适应界面可能会增加故障排查难度。",
        "希望自适应界面能够提供更详细的错误报告和调试工具。"
    ],
    "系统管理员": [
        "自适应界面的部署需要考虑服务器的性能。",
        "在系统维护中，自适应界面可能会导致资源分配问题。",
        "希望自适应界面能够提供更高效的资源管理方案。"
    ],
    "数据分析师": [
        "自适应界面的数据收集有助于了解用户行为。",
        "在数据分析中，自适应界面的变化可能会导致数据解释困难。",
        "希望自适应界面能够提供更详细的数据追踪选项。"
    ],
    "内容创作者": [
        "自适应界面对于内容发布来说非常有用。",
        "在内容管理中，自适应界面的变化可能会导致内容展示不一致。",
        "希望自适应界面能够提供更多的内容管理和发布工具。"
    ],
    "教育技术专家": [
        "自适应界面对于在线教育来说是一个重要的工具。",
        "在课程设计中，自适应界面的变化可能会导致课程结构不清晰。",
        "希望自适应界面能够提供更强大的课程构建工具。"
    ],
    "游戏开发者": [
        "自适应界面对于游戏体验来说非常重要。",
        "在游戏开发中，自适应界面的变化可能会导致玩家体验中断。",
        "希望自适应界面能够提供更丰富的游戏内互动选项。"
    ],
    "数字营销专员": [
        "自适应界面对于数字营销来说是一个重要的工具。",
        "在营销活动中，自适应界面的变化可能会导致活动效果不稳定。",
        "希望自适应界面能够提供更强大的营销自动化工具。"
    ],

    # 初等专业水平角色
    "普通消费者": [
        "自适应界面让我的日常生活变得更加便利。",
        "有时候，自适应界面的变化可能会让我感到有些不知所措。",
        "希望自适应界面能够提供更简单的用户设置选项。"
    ],
    "中学生": [
        "自适应界面让我的学习更加高效。",
        "有时候，自适应界面的变化可能会让我分心。",
        "希望自适应界面能够提供更多的学习辅助工具，如笔记和总结功能。"
    ],
    "家庭主妇/主夫": [
        "自适应界面让我的日常任务变得更加轻松。",
        "有时候，自适应界面的变化可能会让我感到有些困惑。",
        "希望自适应界面能够提供更多的家务管理工具，如购物列表和食谱推荐。"
    ],
    "老年人": [
        "自适应界面让我的操作变得更加简单。",
        "有时候，自适应界面的变化可能会让我感到有些难以跟上。",
        "希望自适应界面能够提供更多的辅助功能，如放大镜和语音助手。"
    ],
    "残障人士": [
        "自适应界面让我的使用变得更加容易。",
        "有时候，自适应界面的变化可能会对我造成不便。",
        "希望自适应界面能够提供更多的无障碍选项，如键盘导航和高对比度模式。"
    ],
    "零售店员": [
        "自适应界面让我的工作变得更加高效。",
        "有时候，自适应界面的变化可能会导致我需要重新学习使用界面。",
        "希望自适应界面能够提供更直观的库存管理和客户关系管理工具。"
    ],
    "非技术工作者": [
        "自适应界面让我的日常操作变得更加方便。",
        "有时候，自适应界面的变化可能会让我感到有些困扰。",
        "希望自适应界面能够提供更简单的操作指南和帮助文档。"
    ],
    "自由职业者": [
        "自适应界面让我的工作变得更加高效。",
        "有时候，自适应界面的变化可能会导致我需要重新适应新的布局。",
        "希望自适应界面能够提供更强大的项目管理和时间跟踪工具。"
    ],
    "游戏爱好者": [
        "自适应界面让我的游戏体验更加流畅。",
        "有时候，自适应界面的变化可能会对我的游戏进度产生影响。",
        "希望自适应界面能够提供更多的游戏内社交功能。"
    ],
    "退休人员": [
        "自适应界面让我的退休生活变得更加有趣。",
        "有时候，自适应界面的变化可能会让我感到有些不适应。",
        "希望自适应界面能够提供更多的娱乐选项，如电影推荐和音乐播放器。"
    ]
}
Q["Question_4"]["response_qwen2"]=response_qwen2

# %%
occupations = [
    # 高专业程度 (Advanced) - 5
    "人机交互研究员", "交互设计专家", "计算机科学教授", "人工智能研究员", "认知科学专家",
    "社会学研究员", "虚拟现实专家", "技术伦理学家", "用户体验研究员", "人机交互技术顾问",

    # 中等专业程度 (Intermediate) - 3
    "软件开发者", "UX/UI设计师", "产品经理", "技术支持工程师", "系统管理员",
    "数据分析师", "内容创作者", "教育技术专家", "游戏开发者", "数字营销专员",

    # 低专业程度 (Beginner) - 1
    "普通消费者", "中学生", "家庭主妇/主夫", "老年人", "残障人士",
    "零售店员", "非技术工作者", "自由职业者", "游戏爱好者", "退休人员"
]


print(Q.keys())
print(Q['Question_4'].keys())
print(Q['Question_4']['Question_4'])
print(Q['Question_4']['questions_4'])
print(Q['Question_4']['responses_chatglm'].keys())
print(Q['Question_4']['responses_chatglm']['软件开发者'])
#'responses_qwen', 'responses_doubao', 'response_qwen2'和responses_chatglm中格式一致
# Out:
# dict_keys(['Question_4'])
# dict_keys(['Question_4', 'questions_4', 'responses_chatglm', 'responses_qwen', 'responses_doubao', 'response_qwen2'])
# (Adaptive Interface Responsiveness) 系统的自适应界面是否能有效响应你的需求变化？(Adaptive Interface Issues) 在自适应过程中，你是否遇到过任何问题？(Desired Features in Adaptive Interfaces) 你希望自适应界面增加哪些功能来提升适应性？
# ['系统的自适应界面是否能有效响应你的需求变化？', '在自适应过程中，你是否遇到过任何问题？', '你希望自适应界面增加哪些功能来提升适应性？']
# dict_keys(['人机交互研究员', '交互设计专家', '计算机科学教授', '人工智能研究员', '认知科学专家', '社会学研究员', '虚拟现实专家', '技术伦理学家', '用户体验研究员', '人机交互技术顾问', '软件开发者', 'UX/UI设计师', '产品经理', '技术支持工程师', '系统管理员', '数据分析师', '内容创作者', '教育技术专家', '游戏开发者', '数字营销专员', '普通消费者', '中学生', '家庭主妇/主夫', '老年人', '残障人士', '零售店员', '非技术工作者', '自由职业者', '游戏爱好者', '退休人员'])
# ['系统的自适应界面能够有效响应我的需求变化，但在开发复杂项目时，输入设备的响应速度有些慢。', '在自适应过程中，我遇到了一些输入设备在处理复杂项目需求时的效率问题。', '我希望自适应界面能够提供更加快速和高效的开发工具，以及更加灵活的输入设备。']

# %%
import json
# 指定要保存的 JSON 文件名
filename = 'Question_4_data.json'

# 将字典写入 JSON 文件
with open(filename, 'w') as f:
    json.dump(Q, f, indent=4)

# %%
from datetime import datetime

# 获取当前时间
current_time = datetime.now()

# 打印当前时间
print(current_time.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2024-08-06 20:50:49
