# %% [markdown]
# ChatGLM

# %%
Q={}
Question_5 = "(Efficiency of Multimodal Interaction) 多模态交互是否提高了你与系统的互动效率？(Multimodal Integration Issues) 在使用多模态交互时，你是否遇到过融合不佳的情况？(Multimodal Interaction Improvements) 你希望在哪些方面进一步改进多模态交互的体验？"
questions_5 = [
    "多模态交互是否提高了你与系统的互动效率？",
    "在使用多模态交互时，你是否遇到过融合不佳的情况？",
    "你希望在哪些方面进一步改进多模态交互的体验？"
]
responses_chatglm = answers = {
    # 高专业程度 (Advanced) - 5
  "人机交互研究员": [
        "多模态交互确实提高了我与系统的互动效率，尤其是在复杂的交互场景中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和手势识别的同步上。",
        "我希望多模态交互能够进一步优化不同模态之间的同步和协调，以及提供更加灵活和可定制的交互选项。"
    ],
    "交互设计专家": [
        "多模态交互提高了我与系统的互动效率，尤其是在设计创新时。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在视觉和触觉的融合上。",
        "我希望多模态交互能够提供更加灵活和可自定义的界面布局，以及更加创新的设计工具。"
    ],
    "计算机科学教授": [
        "多模态交互提高了我与系统的互动效率，尤其是在教学演示中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更快的输入响应和更稳定的系统性能，以及更好的教学辅助工具。"
    ],
    "人工智能研究员": [
        "多模态交互提高了我与系统的互动效率，尤其是在数据处理和模型训练时。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加高效的数据输入和处理功能，以及更加灵活的输入设备。"
    ],
    "认知科学专家": [
        "多模态交互提高了我与系统的互动效率，尤其是在模拟复杂认知任务时。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加自然和直观的交互方式，以及更加灵活的输入设备。"
    ],
    "社会学研究员": [
        "多模态交互提高了我与系统的互动效率，尤其是在社会互动研究中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够增加对社会网络和人类行为模式的理解，以提高分析准确性。"
    ],
    "虚拟现实专家": [
        "多模态交互提高了我与系统的互动效率，尤其是在沉浸式体验中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更高级的虚拟现实交互技术，以增强用户体验。"
    ],
    "技术伦理学家": [
        "多模态交互提高了我与系统的互动效率，尤其是在伦理决策中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够增加伦理决策支持功能，以提高其道德判断能力。"
    ],
    "用户体验研究员": [
        "多模态交互提高了我与系统的互动效率，尤其是在用户研究中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更深入的用户洞察和体验优化建议。"
    ],
    "人机交互技术顾问": [
        "多模态交互提高了我与系统的互动效率，尤其是在定制化解决方案中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加灵活和可定制的解决方案，以及更加灵活的输入设备。"
    ],
       "软件开发者": [
        "多模态交互提高了我与系统的互动效率，尤其是在开发复杂项目时。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加快速和高效的开发工具，以及更加灵活的输入设备。"
    ],
    "UX/UI设计师": [
        "多模态交互提高了我与系统的互动效率，尤其是在设计创新时。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在视觉和触觉的融合上。",
        "我希望多模态交互能够提供更加灵活和可自定义的界面布局，以及更加创新的设计工具。"
    ],
    "产品经理": [
        "多模态交互提高了我与系统的互动效率，尤其是在市场分析时。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加实时和高效的市场分析工具，以及更加灵活的输入设备。"
    ],
    "技术支持工程师": [
        "多模态交互提高了我与系统的互动效率，尤其是在技术支持中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更快的输入响应和更稳定的系统性能，以及更好的技术支持工具。"
    ],
    "系统管理员": [
        "多模态交互提高了我与系统的互动效率，尤其是在系统管理中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更快的输入响应和更稳定的系统性能，以及更好的系统管理工具。"
    ],
    "数据分析师": [
        "多模态交互提高了我与系统的互动效率，尤其是在数据分析中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更快的输入响应和更稳定的系统性能，以及更好的数据分析工具。"
    ],
    "内容创作者": [
        "多模态交互提高了我与系统的互动效率，尤其是在内容创作中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更快的输入响应和更稳定的系统性能，以及更好的内容创作工具。"
    ],
    "教育技术专家": [
        "多模态交互提高了我与系统的互动效率，尤其是在教育技术中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更快的输入响应和更稳定的系统性能，以及更好的教育技术工具。"
    ],
    "游戏开发者": [
        "多模态交互提高了我与系统的互动效率，尤其是在游戏开发中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更快的输入响应和更稳定的系统性能，以及更好的游戏开发工具。"
    ],
    "数字营销专员": [
        "多模态交互提高了我与系统的互动效率，尤其是在数字营销中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更快的输入响应和更稳定的系统性能，以及更好的数字营销工具。"
    ],
     "普通消费者": [
        "多模态交互提高了我与系统的互动效率，尤其是在日常使用中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "中学生": [
        "多模态交互提高了我与系统的互动效率，尤其是在学习中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "家庭主妇/主夫": [
        "多模态交互提高了我与系统的互动效率，尤其是在日常家务管理中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "老年人": [
        "多模态交互提高了我与系统的互动效率，尤其是在使用中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "残障人士": [
        "多模态交互提高了我与系统的互动效率，尤其是在使用中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "零售店员": [
        "多模态交互提高了我与系统的互动效率，尤其是在工作操作中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "非技术工作者": [
        "多模态交互提高了我与系统的互动效率，尤其是在日常工作操作中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "自由职业者": [
        "多模态交互提高了我与系统的互动效率，尤其是在工作操作中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "游戏爱好者": [
        "多模态交互提高了我与系统的互动效率，尤其是在游戏操作中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ],
    "退休人员": [
        "多模态交互提高了我与系统的互动效率，尤其是在日常休闲活动中。",
        "在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。",
        "我希望多模态交互能够提供更加简单易用的操作界面，以及更加直观和易用的交互方式。"
    ]
}


Q["Question_5"]={"Question_5":Question_5, "questions_5":questions_5,"responses_chatglm":responses_chatglm}

# %% [markdown]
# Qwen

# %%
responses_qwen = {
    # 高等专业水平角色
    "人机交互研究员": [
        "多模态交互显著提高了实验和研究过程中的互动效率。",
        "在处理大量数据时，不同模态之间的融合偶尔会不流畅。",
        "希望进一步优化不同模态之间的同步和协调能力。"
    ],
    "交互设计专家": [
        "多模态交互使得设计过程更为直观。",
        "在设计阶段，不同模态的切换可能会导致一些混淆。",
        "希望能够简化不同模态之间的转换流程。"
    ],
    "计算机科学教授": [
        "多模态交互在教学和演示中极为有效。",
        "在课堂上，不同模态的融合有时不够平滑。",
        "希望增加更多教学辅助工具以支持多模态交互。"
    ],
    "人工智能研究员": [
        "多模态交互对于开发智能系统至关重要。",
        "在研发过程中，模态间的协同工作可能存在问题。",
        "希望能够加强不同模态之间的智能融合技术。"
    ],
    "认知科学专家": [
        "多模态交互为认知研究提供了丰富的数据来源。",
        "在实验中，不同模态的数据融合可能遇到挑战。",
        "希望进一步提高数据融合的准确性和一致性。"
    ],
    "社会学研究员": [
        "多模态交互有助于深入理解社会现象。",
        "在实地调研时，不同模态之间的切换可能不够流畅。",
        "希望改善不同模态数据的收集和分析方法。"
    ],
    "虚拟现实专家": [
        "多模态交互极大地丰富了虚拟体验。",
        "在虚拟环境中，不同模态的融合可能会出现问题。",
        "希望改进不同模态的同步技术和感知反馈。"
    ],
    "技术伦理学家": [
        "多模态交互涉及多种隐私和伦理问题。",
        "在使用过程中，不同模态的数据安全可能存在隐患。",
        "希望确保多模态交互的安全性和透明度。"
    ],
    "用户体验研究员": [
        "多模态交互显著提升了用户满意度。",
        "在用户测试中，不同模态之间的融合可能不理想。",
        "希望增强不同模态交互的一致性和流畅度。"
    ],
    "人机交互技术顾问": [
        "多模态交互为企业提供了创新的机会。",
        "在企业应用中，不同模态的集成可能需要优化。",
        "希望提供更强大的多模态集成解决方案。"
    ],

    # 中等专业水平角色
    "软件开发者": [
        "多模态交互让开发过程更为灵活。",
        "在编码时，不同模态的接口可能会导致问题。",
        "希望增加更多易于使用的多模态编程工具。"
    ],
    "UX/UI设计师": [
        "多模态交互使设计更加富有创意。",
        "在设计阶段，不同模态的融合可能不够自然。",
        "希望提供更多设计指南和支持工具。"
    ],
    "产品经理": [
        "多模态交互有助于产品差异化。",
        "在产品规划中，不同模态的整合可能不够顺畅。",
        "希望提供更好的多模态产品策略指导。"
    ],
    "技术支持工程师": [
        "多模态交互让技术支持更高效。",
        "在解决问题时，不同模态之间可能存在兼容性问题。",
        "希望改进不同模态的技术支持工具。"
    ],
    "系统管理员": [
        "多模态交互简化了系统管理任务。",
        "在日常运维中，不同模态的操作可能不够一致。",
        "希望提供更统一的多模态管理系统。"
    ],
    "数据分析师": [
        "多模态交互让数据分析更直观。",
        "在数据分析中，不同模态的数据可能难以融合。",
        "希望提供更强大的多模态数据分析工具。"
    ],
    "内容创作者": [
        "多模态交互让创作过程更丰富。",
        "在创作过程中，不同模态的结合可能不够流畅。",
        "希望提供更多创作工具以支持多模态交互。"
    ],
    "教育技术专家": [
        "多模态交互增强了在线教育体验。",
        "在课程设计中，不同模态的整合可能不够协调。",
        "希望提供更多的多模态教学工具。"
    ],
    "游戏开发者": [
        "多模态交互让游戏体验更真实。",
        "在游戏开发中，不同模态的融合可能不够完美。",
        "希望提供更多游戏开发工具支持多模态交互。"
    ],
    "数字营销专员": [
        "多模态交互让营销活动更吸引人。",
        "在营销活动中，不同模态的内容可能不够协调。",
        "希望提供更多的多模态营销策略支持。"
    ],

    # 初等专业水平角色
    "普通消费者": [
        "多模态交互让我的日常生活更便捷。",
        "有时候，不同模态之间的转换可能不够顺畅。",
        "希望提供更简单的多模态交互教程。"
    ],
    "中学生": [
        "多模态交互让我的学习更有趣。",
        "有时候，不同模态的切换可能让我分心。",
        "希望提供更多的多模态学习工具。"
    ],
    "家庭主妇/主夫": [
        "多模态交互让我的家务管理更轻松。",
        "有时候，不同模态之间的融合可能不够自然。",
        "希望提供更多的家务管理工具支持多模态交互。"
    ],
    "老年人": [
        "多模态交互让我的操作更简单。",
        "有时候，不同模态之间的转换可能让我感到困惑。",
        "希望提供更友好的多模态交互指南。"
    ],
    "残障人士": [
        "多模态交互让我的使用更方便。",
        "有时候，不同模态的融合可能不够友好。",
        "希望提供更多的无障碍多模态交互选项。"
    ],
    "零售店员": [
        "多模态交互让我的工作更高效。",
        "有时候，不同模态之间的切换可能不够流畅。",
        "希望提供更简单的多模态交互培训。"
    ],
    "非技术工作者": [
        "多模态交互让我的日常任务更轻松。",
        "有时候，不同模态的融合可能不够直观。",
        "希望提供更简单的多模态交互指南。"
    ],
    "自由职业者": [
        "多模态交互让我的工作更高效。",
        "有时候，不同模态之间的切换可能不够自然。",
        "希望提供更多的多模态项目管理工具。"
    ],
    "游戏爱好者": [
        "多模态交互让我的游戏体验更丰富。",
        "有时候，不同模态的融合可能不够完美。",
        "希望提供更多的游戏内多模态交互选项。"
    ],
    "退休人员": [
        "多模态交互让我的休闲时光更愉快。",
        "有时候，不同模态之间的转换可能不够流畅。",
        "希望提供更简单的多模态交互教程。"
    ]
}
Q["Question_5"]["responses_qwen"]=responses_qwen

# %% [markdown]
# Coze

# %%
responses_doubao={
   "人机交互研究员": [
        "作为人机交互研究员，多模态交互在一定程度上提高了与系统的互动效率，尤其是在复杂任务和多信息处理方面。",
        "使用多模态交互时，遇到过不同模态之间切换不流畅、信息融合不准确导致理解偏差的情况。",
        "希望在多模态信息的实时同步和精准融合方面进一步改进，以及提升不同模态切换的自然性。"
    ],
    "交互设计专家": [
        "身为交互设计专家，多模态交互确实为互动带来了新的可能性，但效率提升还未达到理想状态。",
        "在使用中，存在视觉、语音等模态融合不协调，影响整体交互体验的问题。",
        "期望在多模态交互的美学设计和用户引导方面进行改进，让用户能更自然地运用不同模态。"
    ],
    "计算机科学教授": [
        "以计算机科学教授的角度看，多模态交互有潜力提高效率，但技术实现上仍面临诸多挑战。",
        "遇到过由于算法不完善导致多模态信息融合不佳，影响系统响应准确性的情况。",
        "希望在多模态交互的算法优化和计算资源利用上有所改进，提高系统性能。"
    ],
    "人工智能研究员": [
        "作为人工智能研究员，多模态交互在某些场景中提高了效率，但模型对多模态数据的理解和融合仍需加强。",
        "使用时发现不同模态数据的权重分配不合理，影响交互效果。",
        "希望在多模态数据的特征提取和融合策略上取得突破，提升交互的智能性。"
    ],
    "认知科学专家": [
        "从认知科学角度，多模态交互对大脑信息处理有积极影响，但与人类认知模式的匹配还不够完美。",
        "遇到过因不符合人类认知习惯导致的多模态交互融合困难。",
        "期望能基于人类认知规律优化多模态交互，使其更符合大脑的信息处理方式。"
    ],
    "社会学研究员": [
        "身为社会学研究员，多模态交互在社会互动方面有一定价值，但在适应不同社会文化背景时存在问题。",
        "使用中发现多模态交互在不同社会群体中的接受度和融合效果差异较大。",
        "希望在考虑社会文化多样性方面改进多模态交互，使其更具包容性。"
    ],
    "虚拟现实专家": [
        "作为虚拟现实专家，多模态交互增强了虚拟环境的沉浸感和互动效率，但在真实感和流畅性上有待改进。",
        "在虚拟现实场景中，多模态交互有时会出现延迟和不真实的融合效果。",
        "期待在多感官融合和虚拟环境的适应性方面提升多模态交互的体验。"
    ],
    "技术伦理学家": [
        "作为技术伦理学家，多模态交互在带来便利的同时，也引发了一些伦理问题，如隐私保护和数据滥用。",
        "使用过程中，存在因伦理考量不足导致的多模态数据融合不当的情况。",
        "希望在多模态交互的发展中建立健全的伦理规范和监管机制。"
    ],
    "用户体验研究员": [
        "身为用户体验研究员，多模态交互在部分场景中提高了用户与系统的互动效率，但用户满意度仍有提升空间。",
        "发现用户在不同模态的选择和切换上存在困惑，导致融合不佳。",
        "期望在用户教育和个性化设置方面改进多模态交互，以满足不同用户的需求。"
    ],
    "人机交互技术顾问": [
        "作为人机交互技术顾问，多模态交互在实际应用中对互动效率的提升尚不均衡，存在技术整合的难题。",
        "遇到过不同设备和系统之间多模态交互的兼容性问题，影响融合效果。",
        "希望在跨平台和设备的一致性方面改进多模态交互，确保稳定的交互体验。"
    ],
    "软件开发者": [
        "作为软件开发者，多模态交互为应用开发带来了新机遇，但在技术实现和集成上存在困难。",
        "使用多模态交互开发时，面临不同开发框架和工具之间的融合问题。",
        "希望在软件开发工具和框架的支持上进一步完善多模态交互，降低开发难度。"
    ],
    "UX/UI设计师": [
        "身为UX/UI设计师，多模态交互丰富了设计手段，但在不同模态的界面整合和用户引导上需要改进。",
        "在设计中，存在多模态元素布局不合理，影响用户对不同模态的感知和运用。",
        "期望在多模态界面的布局和视觉引导方面进行优化，提高用户的操作效率。"
    ],
    "产品经理": [
        "作为产品经理，多模态交互有潜力提升产品竞争力，但在满足用户期望和市场需求方面仍有差距。",
        "遇到过由于对用户需求理解不足导致的多模态交互功能设计不合理的情况。",
        "希望在市场调研和用户需求分析的基础上，改进多模态交互的产品规划和功能设计。"
    ],
    "技术支持工程师": [
        "作为技术支持工程师，多模态交互在故障诊断和用户支持方面的效率提升有限，存在技术复杂性问题。",
        "使用多模态交互进行技术支持时，面临不同模态数据的收集和分析困难。",
        "希望在多模态数据的收集和分析工具上改进，提高技术支持的效率和准确性。"
    ],
    "系统管理员": [
        "身为系统管理员，多模态交互在系统管理和监控方面的应用效果尚不显著，存在资源分配和协调的问题。",
        "在系统管理中，多模态交互的不同模态之间的资源占用和协同工作不够优化。",
        "期望在系统资源管理和多模态协同工作方面改进，提升系统管理的效率和稳定性。"
    ],
    "数据分析师": [
        "作为数据分析师，多模态交互为数据分析提供了新视角，但在数据整合和解读上存在挑战。",
        "使用时发现多模态数据的一致性和准确性难以保证，影响分析结果。",
        "希望在多模态数据的质量控制和整合算法上改进，提高数据分析的可靠性。"
    ],
    "内容创作者": [
        "身为内容创作者，多模态交互为创作带来了更多灵感，但在不同模态内容的融合和表达上有待提高。",
        "创作过程中，多模态内容的协调和展示效果有时不尽人意。",
        "期望在多模态内容的编辑和展示工具上改进，更好地实现创意表达。"
    ],
    "教育技术专家": [
        "作为教育技术专家，多模态交互在教育场景中的应用有一定效果，但在适应教学方法和学生需求方面需要完善。",
        "遇到过因多模态交互与教学内容融合不佳影响教学效果的情况。",
        "希望在根据教育目标和学生特点优化多模态交互的设计和应用方面进行改进。"
    ],
    "游戏开发者": [
        "作为游戏开发者，多模态交互为游戏体验带来了创新，但在游戏平衡和玩家适应性方面存在问题。",
        "在游戏开发中，多模态交互的引入有时会打破游戏平衡，影响玩家体验。",
        "希望在保持游戏平衡和提升玩家对多模态交互适应性方面改进，增强游戏的趣味性。"
    ],
    "数字营销专员": [
        "身为数字营销专员，多模态交互在营销活动中的效果有待观察，存在用户参与度和效果评估的难题。",
        "使用多模态交互进行营销时，不同模态的整合和对用户行为的引导不够有效。",
        "希望在提高用户参与度和精准效果评估方面改进多模态交互，提升营销效果。"
    ],
    "普通消费者": [
        "作为普通消费者，感觉多模态交互有点新鲜，但对互动效率的提升不太明显。",
        "使用时遇到过不同模态切换麻烦，融合不自然的情况。",
        "希望能更简单易用，不同模态之间的切换更顺畅。"
    ],
    "中学生": [
        "作为中学生，多模态交互在学习中有时有帮助，但不太稳定。",
        "会有声音和画面不同步，影响理解的情况。",
        "希望在学习资源的多模态呈现和互动方式上改进。"
    ],
    "家庭主妇/主夫": [
        "作为家庭主妇/主夫，多模态交互在家庭生活中的应用不太顺手。",
        "不同模态的操作复杂，融合效果不好。",
        "希望能更贴合家庭生活需求，操作更简单。"
    ],
    "老年人": [
        "作为老年人，多模态交互不太好懂，没觉得提高效率。",
        "用起来感觉混乱，不好融合。",
        "希望界面更清晰，操作更简单直接。"
    ],
    "残障人士": [
        "作为残障人士，多模态交互的帮助有限，融合问题较多。",
        "某些模态不适合我们的特殊情况，融合不好。",
        "希望能根据残障情况进行个性化优化。"
    ],
    "零售店员": [
        "作为零售店员，多模态交互在工作中的效率提升不明显。",
        "存在不同模态数据不准确，融合有误的情况。",
        "希望能在商品信息展示和客户沟通方面改进。"
    ],
    "非技术工作者": [
        "作为非技术工作者，多模态交互使用起来有些复杂，没明显提高工作效率。",
        "遇到过多种模态协调不好，操作不便利的情况。",
        "希望能更通俗易懂，操作步骤更简洁。"
    ],
    "自由职业者": [
        "作为自由职业者，多模态交互在工作场景中的效率提升一般。",
        "有时会出现不同模态切换卡顿，影响工作进度。",
        "希望在稳定性和响应速度上改进，适应多变的工作需求。"
    ],
    "游戏爱好者": [
        "作为游戏爱好者，多模态交互在游戏中体验还不错，但有提升空间。",
        "偶尔会有模态融合不到位，影响游戏沉浸感。",
        "希望在与游戏情节的结合和互动反馈上更出色。"
    ],
    "退休人员": [
        "作为退休人员，多模态交互不太容易上手，没提高互动效率。",
        "感觉不同模态整合混乱，不好操作。",
        "希望能更简单易用，符合我们的使用习惯。"
    ]
}
Q["Question_5"]["responses_doubao"]=responses_doubao

# %%
response_qwen2 = {
   # 高等专业水平角色
    "人机交互研究员": [
        "多模态交互提供了更自然的沟通方式，从而提高了实验效率。",
        "融合不佳的情况通常出现在需要快速切换模态的情境下。",
        "希望进一步提升模态之间的无缝切换体验。"
    ],
    "交互设计专家": [
        "多模态交互为用户提供了多样化的交互方式。",
        "在设计过程中，模态之间的逻辑一致性有时会受到影响。",
        "希望改善不同模态之间的逻辑连贯性。"
    ],
    "计算机科学教授": [
        "多模态交互在教学中增强了学生的参与感。",
        "在课堂互动中，不同模态的反馈速度可能会有所不同。",
        "希望优化不同模态的响应速度。"
    ],
    "人工智能研究员": [
        "多模态交互为我们提供了更全面的数据集。",
        "在处理复杂场景时，模态之间的信息同步可能会出现问题。",
        "希望增强模态间的信息同步机制。"
    ],
    "认知科学专家": [
        "多模态交互有助于更好地模拟人类的认知过程。",
        "在实验中，不同模态的信号可能会相互干扰。",
        "希望减少模态间的信号干扰。"
    ],
    "社会学研究员": [
        "多模态交互能够帮助我们更全面地理解社会行为。",
        "在数据收集过程中，不同模态的数据一致性是个挑战。",
        "希望提高不同模态数据的一致性。"
    ],
    "虚拟现实专家": [
        "多模态交互创造了沉浸式的虚拟体验。",
        "在虚拟环境中，不同模态的延迟可能会降低沉浸感。",
        "希望减少不同模态之间的延迟。"
    ],
    "技术伦理学家": [
        "多模态交互引发了关于隐私的新思考。",
        "在使用过程中，不同模态的数据保护标准可能不一致。",
        "希望制定统一的数据保护标准。"
    ],
    "用户体验研究员": [
        "多模态交互提升了用户的整体体验。",
        "在用户体验测试中，不同模态的用户偏好差异很大。",
        "希望能更好地满足不同用户的偏好。"
    ],
    "人机交互技术顾问": [
        "多模态交互为企业带来了新的商业模式。",
        "在实际部署时，不同模态的兼容性可能会成为问题。",
        "希望增强不同模态之间的兼容性。"
    ],

    # 中等专业水平角色
    "软件开发者": [
        "多模态交互为软件开发提供了更多的可能性。",
        "在开发过程中，不同模态的API集成可能会出现兼容性问题。",
        "希望简化不同模态API的集成过程。"
    ],
    "UX/UI设计师": [
        "多模态交互激发了新的设计灵感。",
        "在设计阶段，不同模态的设计元素可能难以协调。",
        "希望提供更多的设计元素协调工具。"
    ],
    "产品经理": [
        "多模态交互有助于创造独特的产品特性。",
        "在产品规划中，不同模态的市场接受度可能会有所不同。",
        "希望评估不同市场的模态接受度。"
    ],
    "技术支持工程师": [
        "多模态交互简化了技术支持的过程。",
        "在解决技术问题时，不同模态的故障排查可能不够高效。",
        "希望提高不同模态故障排查的效率。"
    ],
    "系统管理员": [
        "多模态交互简化了系统监控的工作。",
        "在日常运维中，不同模态的警报可能会造成混淆。",
        "希望减少不同模态警报造成的混淆。"
    ],
    "数据分析师": [
        "多模态交互让数据分析变得更加直观。",
        "在数据分析中，不同模态的数据关联可能会出现问题。",
        "希望改进不同模态数据的关联方法。"
    ],
    "内容创作者": [
        "多模态交互为创作提供了更多的素材。",
        "在创作过程中，不同模态的内容整合可能会遇到挑战。",
        "希望提供更好的内容整合工具。"
    ],
    "教育技术专家": [
        "多模态交互促进了个性化学习的发展。",
        "在课程设计中，不同模态的教学资源可能难以平衡。",
        "希望提供更平衡的教学资源。"
    ],
    "游戏开发者": [
        "多模态交互增加了游戏的可玩性。",
        "在游戏开发中，不同模态的游戏机制可能不够协调。",
        "希望提高不同模态游戏机制的协调性。"
    ],
    "数字营销专员": [
        "多模态交互让营销策略更加多样化。",
        "在营销活动中，不同模态的品牌形象可能不够统一。",
        "希望保持不同模态品牌形象的一致性。"
    ],

    # 初等专业水平角色
    "普通消费者": [
        "多模态交互让我的生活更加便利。",
        "有时候，不同模态之间的切换可能会有些复杂。",
        "希望简化不同模态之间的切换步骤。"
    ],
    "中学生": [
        "多模态交互让我的学习变得更有趣。",
        "有时候，不同模态的学习材料可能难以理解。",
        "希望提供更易懂的学习材料。"
    ],
    "家庭主妇/主夫": [
        "多模态交互让我的家务管理变得更加轻松。",
        "有时候，不同模态的应用程序可能不够直观。",
        "希望提供更直观的家庭管理应用程序。"
    ],
    "老年人": [
        "多模态交互让我的操作变得更简单。",
        "有时候，不同模态的设备操作可能会有些困难。",
        "希望提供更简单的设备操作指南。"
    ],
    "残障人士": [
        "多模态交互让我的使用体验得到提升。",
        "有时候，不同模态的辅助功能可能不够完善。",
        "希望提供更多辅助功能选项。"
    ],
    "零售店员": [
        "多模态交互让我的工作更加高效。",
        "有时候，不同模态的顾客服务工具可能不够直观。",
        "希望提供更直观的服务工具。"
    ],
    "非技术工作者": [
        "多模态交互让我的日常工作更轻松。",
        "有时候，不同模态的应用程序可能不够友好。",
        "希望提供更友好的应用程序。"
    ],
    "自由职业者": [
        "多模态交互让我的工作效率更高。",
        "有时候，不同模态的工具可能不够集成。",
        "希望提供更集成的工具。"
    ],
    "游戏爱好者": [
        "多模态交互让我的游戏体验更加丰富。",
        "有时候，不同模态的游戏控制可能会不够流畅。",
        "希望提供更流畅的游戏控制。"
    ],
    "退休人员": [
        "多模态交互让我的娱乐活动更有趣。",
        "有时候，不同模态的应用程序可能不够容易上手。",
        "希望提供更容易上手的应用程序。"
    ]
}
Q["Question_5"]["response_qwen2"]=response_qwen2

# %%
occupations = [
    # 高专业程度 (Advanced) - 5
    "人机交互研究员", "交互设计专家", "计算机科学教授", "人工智能研究员", "认知科学专家",
    "社会学研究员", "虚拟现实专家", "技术伦理学家", "用户体验研究员", "人机交互技术顾问",

    # 中等专业程度 (Intermediate) - 3
    "软件开发者", "UX/UI设计师", "产品经理", "技术支持工程师", "系统管理员",
    "数据分析师", "内容创作者", "教育技术专家", "游戏开发者", "数字营销专员",

    # 低专业程度 (Beginner) - 1
    "普通消费者", "中学生", "家庭主妇/主夫", "老年人", "残障人士",
    "零售店员", "非技术工作者", "自由职业者", "游戏爱好者", "退休人员"
]


print(Q.keys())
print(Q['Question_5'].keys())
print(Q['Question_5']['Question_5'])
print(Q['Question_5']['questions_5'])
print(Q['Question_5']['responses_chatglm'].keys())
print(Q['Question_5']['responses_chatglm']['软件开发者'])
#'responses_qwen', 'responses_doubao', 'response_qwen2'和responses_chatglm中格式一致
# Out:
# dict_keys(['Question_5'])
# dict_keys(['Question_5', 'questions_5', 'responses_chatglm', 'responses_qwen', 'responses_doubao', 'response_qwen2'])
# (Efficiency of Multimodal Interaction) 多模态交互是否提高了你与系统的互动效率？(Multimodal Integration Issues) 在使用多模态交互时，你是否遇到过融合不佳的情况？(Multimodal Interaction Improvements) 你希望在哪些方面进一步改进多模态交互的体验？
# ['多模态交互是否提高了你与系统的互动效率？', '在使用多模态交互时，你是否遇到过融合不佳的情况？', '你希望在哪些方面进一步改进多模态交互的体验？']
# dict_keys(['人机交互研究员', '交互设计专家', '计算机科学教授', '人工智能研究员', '认知科学专家', '社会学研究员', '虚拟现实专家', '技术伦理学家', '用户体验研究员', '人机交互技术顾问', '软件开发者', 'UX/UI设计师', '产品经理', '技术支持工程师', '系统管理员', '数据分析师', '内容创作者', '教育技术专家', '游戏开发者', '数字营销专员', '普通消费者', '中学生', '家庭主妇/主夫', '老年人', '残障人士', '零售店员', '非技术工作者', '自由职业者', '游戏爱好者', '退休人员'])
# ['多模态交互提高了我与系统的互动效率，尤其是在开发复杂项目时。', '在使用多模态交互时，我偶尔会遇到融合不佳的情况，尤其是在语音识别和视觉的融合上。', '我希望多模态交互能够提供更加快速和高效的开发工具，以及更加灵活的输入设备。']

# %%
import json
# 指定要保存的 JSON 文件名
filename = 'Question_5_data.json'

# 将字典写入 JSON 文件
with open(filename, 'w') as f:
    json.dump(Q, f, indent=4)

# %%
from datetime import datetime

# 获取当前时间
current_time = datetime.now()

# 打印当前时间
print(current_time.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2024-08-06 20:50:51
