# %% [markdown]
# ChatGLM

# %%
Q={}
Question_3 = "(Haptic Impact on Experience) 触觉反馈对你在虚拟现实中的体验是否有显著影响？(Realism of Haptics) 你是否觉得当前的触觉反馈技术足够真实？(Haptic Technology Improvements) 你希望触觉反馈技术在哪些方面得到改进？"
questions_3 = [
    "触觉反馈对你在虚拟现实中的体验是否有显著影响？",
    "你是否觉得当前的触觉反馈技术足够真实？",
    "你希望触觉反馈技术在哪些方面得到改进？"
]
responses_chatglm = answers = {
    # 高专业程度 (Advanced) - 5
    "人机交互研究员": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在探索和交互时。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "交互设计专家": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在用户界面设计中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "计算机科学教授": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在教育演示中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "人工智能研究员": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在研究复杂交互时。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "认知科学专家": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在研究认知过程时。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "社会学研究员": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在社会互动研究中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "虚拟现实专家": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在沉浸式体验中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "技术伦理学家": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在伦理决策中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "用户体验研究员": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在用户研究中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "人机交互技术顾问": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在定制化解决方案中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
      "软件开发者": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在游戏开发中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "UX/UI设计师": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在用户界面设计中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "产品经理": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在产品规划中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "技术支持工程师": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在技术支持中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "系统管理员": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在系统管理中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "数据分析师": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在数据分析中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "内容创作者": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在内容创作中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "教育技术专家": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在教育技术中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "游戏开发者": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在游戏开发中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "数字营销专员": [
        "触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在数字营销中。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
     "普通消费者": [
        "触觉反馈对我来说在虚拟现实中的体验有一定的影响，但我希望它能够更加真实和自然。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "中学生": [
        "触觉反馈对我来说在虚拟现实中的体验有一定的影响，但我希望它能够更加真实和自然。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "家庭主妇/主夫": [
        "触觉反馈对我来说在虚拟现实中的体验有一定的影响，但我希望它能够更加真实和自然。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "老年人": [
        "触觉反馈对我来说在虚拟现实中的体验有一定的影响，但我希望它能够更加真实和自然。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "残障人士": [
        "触觉反馈对我来说在虚拟现实中的体验有一定的影响，但我希望它能够更加真实和自然。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "零售店员": [
        "触觉反馈对我来说在虚拟现实中的体验有一定的影响，但我希望它能够更加真实和自然。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "非技术工作者": [
        "触觉反馈对我来说在虚拟现实中的体验有一定的影响，但我希望它能够更加真实和自然。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "自由职业者": [
        "触觉反馈对我来说在虚拟现实中的体验有一定的影响，但我希望它能够更加真实和自然。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "游戏爱好者": [
        "触觉反馈对我来说在虚拟现实中的体验有一定的影响，但我希望它能够更加真实和自然。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ],
    "退休人员": [
        "触觉反馈对我来说在虚拟现实中的体验有一定的影响，但我希望它能够更加真实和自然。",
        "我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。",
        "我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。"
    ]

}


Q["Question_3"]={"Question_3":Question_3, "questions_3":questions_3,"responses_chatglm":responses_chatglm}

# %% [markdown]
# Qwen

# %%
responses_qwen = {
  # 高等专业水平角色
    "人机交互研究员": [
        "触觉反馈对于虚拟现实体验至关重要，它增强了沉浸感和交互的真实性。",
        "现有的触觉反馈技术还存在局限，尤其是在传递细腻触感方面。",
        "我希望触觉反馈技术能够提供更丰富、更精细的触感体验，包括温度和质地的变化。"
    ],
    "交互设计专家": [
        "触觉反馈极大地丰富了虚拟现实中的用户体验，使交互更为自然。",
        "当前的技术在模拟真实的触觉反馈方面仍有提升空间。",
        "我期待触觉反馈技术能够更好地模拟不同材质的感觉，并且减少延迟。"
    ],
    "计算机科学教授": [
        "触觉反馈是虚拟现实不可或缺的一部分，它让体验更加逼真。",
        "我认为目前的技术在重现复杂的触觉体验方面仍有待进步。",
        "我希望看到触觉反馈技术能够更好地集成到教学和科研工具中，以增强学习和实验的沉浸感。"
    ],
    "人工智能研究员": [
        "触觉反馈对于训练机器学习模型来理解物理世界非常重要。",
        "现有的触觉反馈系统在精确度上有待提高。",
        "我希望触觉反馈技术能够更加智能化，能够根据用户的动作和环境自动调整反馈强度。"
    ],
    "认知科学专家": [
        "触觉反馈有助于大脑更好地融入虚拟环境，对研究人类感知有很大帮助。",
        "目前的技术在模拟真实触感方面尚不完美。",
        "我希望触觉反馈技术能够更加贴近人类皮肤的真实感受，包括温度和湿度的变化。"
    ],
    "社会学研究员": [
        "触觉反馈技术有助于研究不同文化背景下人们对虚拟世界的接受程度。",
        "我认为现有的触觉反馈系统在模拟文化相关的触感方面还需要进一步发展。",
        "我希望触觉反馈技术能够更好地反映不同文化中的触感偏好。"
    ],
    "虚拟现实专家": [
        "触觉反馈是构建沉浸式虚拟现实体验的关键因素。",
        "我认为当前的技术在模拟复杂触觉场景时还有所欠缺。",
        "我希望触觉反馈技术能够支持更广泛的运动范围，并且提高反馈的精确度。"
    ],
    "技术伦理学家": [
        "触觉反馈技术在伦理上提出了关于个人隐私和安全的新问题。",
        "我认为现有的技术在确保用户数据安全方面做得还不够。",
        "我希望触觉反馈技术能够更好地保护用户的个人信息，并确保数据的安全传输。"
    ],
    "用户体验研究员": [
        "触觉反馈显著提高了用户与虚拟世界的互动体验。",
        "我认为现有的触觉反馈技术在一致性方面还有待提高。",
        "我希望触觉反馈技术能够提供更一致、更可预测的反馈模式。"
    ],
    "人机交互技术顾问": [
        "触觉反馈对于优化虚拟现实应用至关重要。",
        "我认为当前的技术在模拟自然手势和动作时还有提升空间。",
        "我希望触觉反馈技术能够更好地模拟手部动作，提高手势识别的准确性。"
    ],

    # 中等专业水平角色
    "软件开发者": [
        "触觉反馈在虚拟现实开发中很重要，它可以让用户感觉到虚拟物体的存在。",
        "我认为现有的技术在模拟真实触感方面还不够成熟。",
        "我希望触觉反馈技术能够更容易地集成到开发工具中，提高开发效率。"
    ],
    "UX/UI设计师": [
        "触觉反馈对于创建直观的虚拟界面很有帮助。",
        "我认为现有的技术在模拟真实材料的感觉方面还可以做得更好。",
        "我希望触觉反馈技术能够提供更广泛的材质模拟选项。"
    ],
    "产品经理": [
        "触觉反馈增加了产品的吸引力，有助于销售。",
        "我认为现有的技术在用户体验的一致性方面还需要改进。",
        "我希望触觉反馈技术能够更加可靠，减少失败率。"
    ],
    "技术支持工程师": [
        "触觉反馈有助于用户更好地理解和操作虚拟环境。",
        "我认为现有的技术在可靠性方面还有待提高。",
        "我希望触觉反馈技术能够减少故障率，提高维护效率。"
    ],
    "系统管理员": [
        "触觉反馈技术对于维护虚拟现实系统的可用性很重要。",
        "我认为现有的技术在维护方面还需要简化。",
        "我希望触觉反馈技术能够更易于维护，减少停机时间。"
    ],
    "数据分析师": [
        "触觉反馈可以帮助分析用户在虚拟环境中的行为。",
        "我认为现有的技术在数据收集方面还有待改进。",
        "我希望触觉反馈技术能够提供更精确的行为数据。"
    ],
    "内容创作者": [
        "触觉反馈增加了虚拟内容的真实感。",
        "我认为现有的技术在模拟触感细节方面还可以做得更好。",
        "我希望触觉反馈技术能够支持更多的触感细节。"
    ],
    "教育技术专家": [
        "触觉反馈有助于学生更好地理解抽象概念。",
        "我认为现有的技术在教育应用方面还可以做得更好。",
        "我希望触觉反馈技术能够更好地融入教育课程。"
    ],
    "游戏开发者": [
        "触觉反馈对于创造沉浸式游戏体验至关重要。",
        "我认为现有的技术在模拟游戏内的触感方面还有提升空间。",
        "我希望触觉反馈技术能够更好地支持游戏内物体的触感反馈。"
    ],
    "数字营销专员": [
        "触觉反馈技术有助于提升产品宣传的吸引力。",
        "我认为现有的技术在广告应用方面还可以做得更好。",
        "我希望触觉反馈技术能够更容易地应用于营销活动。"
    ],

    # 初等专业水平角色
    "普通消费者": [
        "触觉反馈让我在虚拟现实中感觉更加真实。",
        "我认为现有的技术在模拟真实的触感方面还不够好。",
        "我希望触觉反馈技术能够更加逼真，就像真正的触摸一样。"
    ],
    "中学生": [
        "触觉反馈让虚拟现实游戏更有趣。",
        "我认为现有的技术在模拟游戏中的触感方面还有待改进。",
        "我希望触觉反馈技术能够更好地模拟游戏内物体的质感。"
    ],
    "家庭主妇/主夫": [
        "触觉反馈让烹饪类虚拟现实游戏更加真实。",
        "我认为现有的技术在模拟食材的触感方面还可以做得更好。",
        "我希望触觉反馈技术能够更好地模拟食物的质感。"
    ],
    "老年人": [
        "触觉反馈让虚拟现实体验更加有趣。",
        "我认为现有的技术在模拟熟悉的触感方面还有提升空间。",
        "我希望触觉反馈技术能够更好地模拟日常物品的触感。"
    ],
    "残障人士": [
        "触觉反馈帮助我更好地与虚拟世界互动。",
        "我认为现有的技术在提供辅助功能方面还需要改进。",
        "我希望触觉反馈技术能够更好地支持无障碍设计。"
    ],
    "零售店员": [
        "触觉反馈让虚拟试穿体验更加真实。",
        "我认为现有的技术在模拟布料的触感方面还有待提高。",
        "我希望触觉反馈技术能够更好地模拟不同类型布料的手感。"
    ],
    "非技术工作者": [
        "触觉反馈让虚拟现实体验更加有趣。",
        "我认为现有的技术在模拟日常物品的触感方面还有待改进。",
        "我希望触觉反馈技术能够更容易理解和使用。"
    ],
    "自由职业者": [
        "触觉反馈让虚拟办公室体验更加真实。",
        "我认为现有的技术在模拟办公用品的触感方面还有待提高。",
        "我希望触觉反馈技术能够更好地模拟办公用品的质感。"
    ],
    "游戏爱好者": [
        "触觉反馈让游戏体验更加沉浸。",
        "我认为现有的技术在模拟游戏中的触感方面还有提升空间。",
        "我希望触觉反馈技术能够更好地模拟游戏角色的动作。"
    ],
    "退休人员": [
        "触觉反馈让虚拟现实体验更加有趣。",
        "我认为现有的技术在模拟熟悉的触感方面还有提升空间。",
        "我希望触觉反馈技术能够更好地模拟日常生活中常见的物体。"
    ]
}
Q["Question_3"]["responses_qwen"]=responses_qwen

# %% [markdown]
# Coze

# %%
responses_doubao={
       "人机交互研究员": [
        "作为人机交互研究员，触觉反馈在虚拟现实中的体验有着显著影响。它能够增强沉浸感和交互的真实感，让用户更深入地融入虚拟环境。",
        "当前的触觉反馈技术距离足够真实还有一定差距，在模拟复杂和细微的触感方面仍有待提高。",
        "希望触觉反馈技术能够在模拟材质的多样性、力度的精细控制以及响应的及时性方面得到显著改进。"
    ],
    "交互设计专家": [
        "身为交互设计专家，触觉反馈对虚拟现实体验至关重要，能为设计带来更多可能性和吸引力。",
        "目前的触觉反馈技术真实感不足，无法完全还原真实世界中的丰富触感。",
        "期望触觉反馈技术在模拟不同物体的纹理和温度变化上有所突破，提升真实感。"
    ],
    "计算机科学教授": [
        "以计算机科学教授的视角，触觉反馈明显影响虚拟现实体验，是提升系统性能的关键因素之一。",
        "当前触觉反馈技术在准确性和稳定性方面不够理想，影响真实感的呈现。",
        "希望能在触觉反馈的算法优化和硬件创新上取得进展，提高反馈的精准度。"
    ],
    "人工智能研究员": [
        "作为人工智能研究员，触觉反馈对虚拟现实体验有较大影响，有助于丰富智能交互的感知渠道。",
        "现有的触觉反馈技术在模拟复杂环境和情感化的触觉方面不够真实。",
        "希望触觉反馈技术能与人工智能算法更好结合，实现更智能和真实的触觉模拟。"
    ],
    "认知科学专家": [
        "从认知科学角度，触觉反馈对虚拟现实体验的影响深远，直接影响用户的认知和感知。",
        "当前触觉反馈技术在符合人类认知模型的真实感营造上尚有不足。",
        "期望触觉反馈技术能依据认知科学原理，更精准地模拟人类触觉感知。"
    ],
    "社会学研究员": [
        "身为社会学研究员，触觉反馈在虚拟现实体验中具有显著影响，可能改变社会交往和互动模式。",
        "目前的触觉反馈技术在适应不同社会文化背景下的真实触觉感知方面存在欠缺。",
        "希望触觉反馈技术能考虑社会文化差异，提供更具包容性的真实触觉体验。"
    ],
    "虚拟现实专家": [
        "作为虚拟现实专家，触觉反馈对提升虚拟现实沉浸感影响极大，是关键的体验要素。",
        "当下的触觉反馈技术在真实感上还不能完全满足高端虚拟现实应用的需求。",
        "期待触觉反馈技术在多感官融合和全身触觉覆盖方面取得重大改进。"
    ],
    "技术伦理学家": [
        "作为技术伦理学家，触觉反馈在虚拟现实中的影响需要从伦理角度审视，确保其合理使用。",
        "当前触觉反馈技术在伦理考量下的真实感呈现不够完善，可能引发伦理问题。",
        "希望触觉反馈技术在发展过程中遵循伦理原则，同时提升真实感和安全性。"
    ],
    "用户体验研究员": [
        "身为用户体验研究员，触觉反馈对虚拟现实的用户体验有显著影响，直接关系到用户满意度。",
        "现有的触觉反馈技术在满足用户对真实感的期望方面还有差距。",
        "期望触觉反馈技术在个性化设置和用户情感响应方面得到加强，提升真实体验。"
    ],
    "人机交互技术顾问": [
        "作为人机交互技术顾问，触觉反馈对虚拟现实体验影响显著，是优化交互效果的重要手段。",
        "当前触觉反馈技术在真实感的一致性和可靠性方面有待改进。",
        "希望触觉反馈技术能在跨平台和多设备的兼容性上有所提升，保证真实体验的稳定性。"
    ],
    "软件开发者": [
        "作为软件开发者，触觉反馈对虚拟现实软件的质量和吸引力有重要影响。",
        "当前的触觉反馈技术在与软件的集成和实时响应方面不够真实。",
        "希望触觉反馈技术能提供更便捷的开发接口和更高效的资源利用，增强真实感。"
    ],
    "UX/UI设计师": [
        "身为UX/UI设计师，触觉反馈对虚拟现实界面设计影响明显，能提升用户的操作感知。",
        "目前的触觉反馈技术在与视觉和听觉元素的协调配合上真实感不足。",
        "期望触觉反馈技术在与其他感官反馈的融合和协同方面有更好的表现，创造更真实的综合体验。"
    ],
    "产品经理": [
        "作为产品经理，触觉反馈对虚拟现实产品的市场竞争力有重大影响。",
        "当前触觉反馈技术在成本和性能之间的平衡上无法达到足够的真实感。",
        "希望触觉反馈技术能在降低成本的同时，不断提升真实感，满足市场需求。"
    ],
    "技术支持工程师": [
        "作为技术支持工程师，触觉反馈对虚拟现实系统的稳定性和维护难度有一定影响。",
        "现有的触觉反馈技术在故障诊断和修复的便利性方面真实感不够。",
        "希望触觉反馈技术在自我诊断和远程维护支持方面得到改进，提高真实的运维体验。"
    ],
    "系统管理员": [
        "身为系统管理员，触觉反馈对虚拟现实系统的整体管理和资源分配有影响。",
        "当前触觉反馈技术在系统层面的优化和资源利用效率上真实感欠佳。",
        "期望触觉反馈技术在系统集成和资源管理方面更加成熟，提供更真实有效的支持。"
    ],
    "数据分析师": [
        "作为数据分析师，触觉反馈在虚拟现实数据采集和分析方面可能产生影响。",
        "目前的触觉反馈技术在提供准确和有价值的数据反馈方面真实感有限。",
        "希望触觉反馈技术能为数据分析提供更丰富和真实的触感数据，辅助分析决策。"
    ],
    "内容创作者": [
        "身为内容创作者，触觉反馈对虚拟现实内容创作的灵感和表现力有影响。",
        "当下的触觉反馈技术在激发创意和还原想象中的触感方面真实感不足。",
        "期望触觉反馈技术能为创作提供更多灵感源泉，实现更逼真的触觉内容创作。"
    ],
    "教育技术专家": [
        "作为教育技术专家，触觉反馈对虚拟现实教育应用的效果和学习体验有显著影响。",
        "当前触觉反馈技术在适应教育场景和满足学习需求的真实感方面有待加强。",
        "希望触觉反馈技术能更好地服务于教育目的，提供更具教育意义的真实触觉体验。"
    ],
    "游戏开发者": [
        "作为游戏开发者，触觉反馈对游戏的沉浸感和玩法创新影响巨大。",
        "现有的触觉反馈技术在游戏中的真实感还不能完全满足玩家的高要求。",
        "期望触觉反馈技术能在游戏互动和情节体验上有更出色的表现，提升真实度。"
    ],
    "数字营销专员": [
        "身为数字营销专员，触觉反馈在虚拟现实营销中的用户参与和品牌体验方面有影响。",
        "目前的触觉反馈技术在创造独特和令人难忘的营销真实感方面尚有不足。",
        "希望触觉反馈技术能为数字营销活动带来更具冲击力和真实感的用户互动。"
    ],
    "普通消费者": [
        "作为普通消费者，触觉反馈在虚拟现实体验中感觉挺新鲜，但影响不是特别大。",
        "当前的触觉反馈技术感觉不太真实，没有那种身临其境的感觉。",
        "希望能更真实地模拟各种物体的触感，像摸到真实东西一样。"
    ],
    "中学生": [
        "作为中学生，触觉反馈在玩虚拟现实游戏时有一些影响，觉得挺有趣。",
        "不过现在的触觉反馈技术还不够真实，不够刺激。",
        "希望能在力度和感觉的变化上更丰富，更像真的。"
    ],
    "家庭主妇/主夫": [
        "作为家庭主妇/主夫，触觉反馈在虚拟现实里好像影响不大，不是很常用到。",
        "现在的触觉反馈技术不太真实，没什么特别的感觉。",
        "要是能在做家务相关的虚拟体验中更真实就好了。"
    ],
    "老年人": [
        "作为老年人，触觉反馈对我在虚拟现实中的体验没啥太大影响，不太懂这个。",
        "感觉现在的技术不真实，也不太感兴趣。",
        "希望简单点，别太复杂就行。"
    ],
    "残障人士": [
        "作为残障人士，触觉反馈在某些虚拟现实应用中可能有帮助，但不太真实。",
        "当前的触觉反馈技术对我们的特殊需求考虑不够。",
        "希望能更方便我们使用，并且更真实地满足需求。"
    ],
    "零售店员": [
        "作为零售店员，触觉反馈在虚拟现实的商品展示中影响不大，不太实用。",
        "现在的触觉反馈技术不真实，对工作没帮助。",
        "希望能在商品展示和销售培训方面更真实有用。"
    ],
    "非技术工作者": [
        "作为非技术工作者，触觉反馈在虚拟现实体验里感觉一般，不太明显。",
        "当前的触觉反馈技术不太真实，没太大感觉。",
        "希望能更简单易懂，真实感强点。"
    ],
    "自由职业者": [
        "作为自由职业者，触觉反馈在偶尔的虚拟现实娱乐中有点影响，但不关键。",
        "现在的触觉反馈技术真实感不足，不够吸引人。",
        "希望能更真实有趣，增加娱乐性。"
    ],
    "游戏爱好者": [
        "作为游戏爱好者，触觉反馈对游戏体验影响很大，很期待更好的效果。",
        "目前的触觉反馈技术不够真实，不够过瘾。",
        "希望能在细节和强度上更逼真，有更多变化。"
    ],
    "退休人员": [
        "作为退休人员，触觉反馈在虚拟现实里影响不大，不太在乎这个。",
        "现在的触觉反馈技术感觉不真实，也不太需要。",
        "要是能简单点，容易感受就好了。"
    ]
}
Q["Question_3"]["responses_doubao"]=responses_doubao

# %%
response_qwen2 = {
   "人机交互研究员": [
        "触觉反馈在虚拟现实中的重要性不容小觑，它不仅增强了沉浸感，还能促进用户的认知学习。",
        "当前的触觉反馈技术在精度和响应速度方面仍有不足。",
        "我希望能看到触觉反馈技术在多感官融合方面取得突破，比如结合听觉和视觉反馈。"
    ],
    "交互设计专家": [
        "触觉反馈技术对于提升用户体验至关重要，特别是在复杂的交互设计中。",
        "现有的触觉反馈技术在模拟复杂环境下的触觉反馈方面存在挑战。",
        "我期待触觉反馈技术能更好地支持动态反馈机制，适应快速变化的虚拟环境。"
    ],
    "计算机科学教授": [
        "触觉反馈技术的研究对于计算机科学领域来说是一个重要的跨学科课题。",
        "我认为现有技术在触觉反馈的准确性和实时性方面有待加强。",
        "我希望未来的技术能够实现更高级别的触觉反馈定制化，满足个性化需求。"
    ],
    "人工智能研究员": [
        "触觉反馈技术的进步对于开发具有更高智能水平的机器人至关重要。",
        "现有的触觉反馈系统在处理非结构化环境中的触觉数据方面能力有限。",
        "我希望未来的触觉反馈技术能够实现更好的环境适应性和学习能力。"
    ],
    "认知科学专家": [
        "触觉反馈技术对于认知科学研究有着深远的意义，它可以帮助我们了解大脑如何处理触觉信息。",
        "我认为现有技术在模拟复杂触觉模式方面还需进一步探索。",
        "我希望触觉反馈技术能够在认知研究中发挥更大作用，如在神经反馈训练中。"
    ],
    "社会学研究员": [
        "触觉反馈技术的社会影响值得关注，特别是在社交互动和公共空间的设计上。",
        "我认为现有的触觉反馈系统在模拟人际互动的触感方面还有待提高。",
        "我希望触觉反馈技术能够促进更多元化的社会交往方式。"
    ],
    "虚拟现实专家": [
        "触觉反馈技术的发展是推动虚拟现实行业向前的重要动力。",
        "我认为现有技术在模拟大规模环境下的触觉反馈方面还有很大的发展空间。",
        "我希望触觉反馈技术能够实现更广泛的应用，比如在远程医疗领域。"
    ],
    "技术伦理学家": [
        "触觉反馈技术在伦理层面提出了许多新的问题，例如隐私权和个人边界。",
        "我认为现有技术在保护用户隐私方面还需加强。",
        "我希望触觉反馈技术能够在保障用户隐私的同时，提供丰富的触觉体验。"
    ],
    "用户体验研究员": [
        "触觉反馈对于提升用户体验有着不可替代的作用。",
        "我认为现有技术在提供一致性和可靠性方面的表现还有待提高。",
        "我希望触觉反馈技术能够更好地适应不同用户的偏好和需求。"
    ],
    "人机交互技术顾问": [
        "触觉反馈技术的应用对于改善人机交互的质量至关重要。",
        "我认为现有技术在实现触觉反馈的无缝集成方面还有待改进。",
        "我希望触觉反馈技术能够更容易地集成到现有的交互系统中。"
    ],

    # 中等专业水平角色
    "软件开发者": [
        "触觉反馈技术对于软件开发来说是一个有趣的挑战。",
        "我认为现有技术在实现触觉反馈的灵活性方面还需努力。",
        "我希望触觉反馈技术能够更方便地集成到开发环境中。"
    ],
    "UX/UI设计师": [
        "触觉反馈技术为UI设计带来了全新的维度。",
        "我认为现有技术在提供直观的触觉反馈方面还有改进空间。",
        "我希望触觉反馈技术能够提供更灵活的设计选项。"
    ],
    "产品经理": [
        "触觉反馈技术对于产品创新至关重要。",
        "我认为现有技术在提高产品竞争力方面还需加强。",
        "我希望触觉反馈技术能够提供更多差异化的特性。"
    ],
    "技术支持工程师": [
        "触觉反馈技术的应用对于技术支持来说是一个新的领域。",
        "我认为现有技术在提高设备的耐用性和维护性方面还需努力。",
        "我希望触觉反馈技术能够降低维护成本。"
    ],
    "系统管理员": [
        "触觉反馈技术对于系统管理来说意味着新的挑战。",
        "我认为现有技术在支持远程管理和监控方面还需改进。",
        "我希望触觉反馈技术能够更好地支持远程管理工具。"
    ],
    "数据分析师": [
        "触觉反馈技术的数据对于分析用户行为非常重要。",
        "我认为现有技术在提供准确的数据集方面还需提高。",
        "我希望触觉反馈技术能够提供更高质量的数据。"
    ],
    "内容创作者": [
        "触觉反馈技术为创作提供了新的灵感。",
        "我认为现有技术在支持创意内容的制作方面还需加强。",
        "我希望触觉反馈技术能够提供更多的创意工具。"
    ],
    "教育技术专家": [
        "触觉反馈技术对于教育技术来说是一个巨大的机遇。",
        "我认为现有技术在支持教育创新方面还需改进。",
        "我希望触觉反馈技术能够更好地服务于个性化学习。"
    ],
    "游戏开发者": [
        "触觉反馈技术对于游戏设计来说是一个创新的方向。",
        "我认为现有技术在提供沉浸式体验方面还需努力。",
        "我希望触觉反馈技术能够更好地支持游戏设计。"
    ],
    "数字营销专员": [
        "触觉反馈技术为数字营销带来了新的可能。",
        "我认为现有技术在支持品牌体验方面还需提高。",
        "我希望触觉反馈技术能够提供更具吸引力的品牌体验。"
    ],

    # 初等专业水平角色
    "普通消费者": [
        "触觉反馈技术让我的虚拟体验更加生动。",
        "我认为现有技术在提供自然的触感方面还需改进。",
        "我希望触觉反馈技术能够更加平易近人，价格更亲民。"
    ],
    "中学生": [
        "触觉反馈技术让我的学习变得更加有趣。",
        "我认为现有技术在模拟课堂体验方面还需加强。",
        "我希望触觉反馈技术能够帮助我更好地理解抽象概念。"
    ],
    "家庭主妇/主夫": [
        "触觉反馈技术让我的家务变得更加轻松。",
        "我认为现有技术在模拟厨房用品的触感方面还需改进。",
        "我希望触觉反馈技术能够提供更多的生活便利。"
    ],
    "老年人": [
        "触觉反馈技术让我的日常生活变得更加丰富。",
        "我认为现有技术在模拟熟悉事物的触感方面还需提高。",
        "我希望触觉反馈技术能够更好地支持老年人的生活。"
    ],
    "残障人士": [
        "触觉反馈技术让我的沟通变得更加容易。",
        "我认为现有技术在提供无障碍支持方面还需加强。",
        "我希望触觉反馈技术能够更好地支持无障碍设计。"
    ],
    "零售店员": [
        "触觉反馈技术让我的工作变得更加高效。",
        "我认为现有技术在模拟商品触感方面还需提高。",
        "我希望触觉反馈技术能够更好地支持零售体验。"
    ],
    "非技术工作者": [
        "触觉反馈技术让我的娱乐变得更加丰富。",
        "我认为现有技术在提供简单的触觉体验方面还需改进。",
        "我希望触觉反馈技术能够更加易于使用。"
    ],
    "自由职业者": [
        "触觉反馈技术让我的工作变得更加高效。",
        "我认为现有技术在提供工作辅助方面还需提高。",
        "我希望触觉反馈技术能够更好地支持远程工作。"
    ],
    "游戏爱好者": [
        "触觉反馈技术让我的游戏体验更加真实。",
        "我认为现有技术在提供游戏内触感方面还需加强。",
        "我希望触觉反馈技术能够更好地支持游戏控制器。"
    ],
    "退休人员": [
        "触觉反馈技术让我的退休生活变得更加有趣。",
        "我认为现有技术在模拟日常活动的触感方面还需提高。",
        "我希望触觉反馈技术能够更好地支持老年生活。"
    ]
}
Q["Question_3"]["response_qwen2"]=response_qwen2

# %%
occupations = [
    # 高专业程度 (Advanced) - 5
    "人机交互研究员", "交互设计专家", "计算机科学教授", "人工智能研究员", "认知科学专家",
    "社会学研究员", "虚拟现实专家", "技术伦理学家", "用户体验研究员", "人机交互技术顾问",

    # 中等专业程度 (Intermediate) - 3
    "软件开发者", "UX/UI设计师", "产品经理", "技术支持工程师", "系统管理员",
    "数据分析师", "内容创作者", "教育技术专家", "游戏开发者", "数字营销专员",

    # 低专业程度 (Beginner) - 1
    "普通消费者", "中学生", "家庭主妇/主夫", "老年人", "残障人士",
    "零售店员", "非技术工作者", "自由职业者", "游戏爱好者", "退休人员"
]


print(Q.keys())
print(Q['Question_3'].keys())
print(Q['Question_3']['Question_3'])
print(Q['Question_3']['questions_3'])
print(Q['Question_3']['responses_chatglm'].keys())
print(Q['Question_3']['responses_chatglm']['软件开发者'])
#'responses_qwen', 'responses_doubao', 'response_qwen2'和responses_chatglm中格式一致
# Out:
# dict_keys(['Question_3'])
# dict_keys(['Question_3', 'questions_3', 'responses_chatglm', 'responses_qwen', 'responses_doubao', 'response_qwen2'])
# (Haptic Impact on Experience) 触觉反馈对你在虚拟现实中的体验是否有显著影响？(Realism of Haptics) 你是否觉得当前的触觉反馈技术足够真实？(Haptic Technology Improvements) 你希望触觉反馈技术在哪些方面得到改进？
# ['触觉反馈对你在虚拟现实中的体验是否有显著影响？', '你是否觉得当前的触觉反馈技术足够真实？', '你希望触觉反馈技术在哪些方面得到改进？']
# dict_keys(['人机交互研究员', '交互设计专家', '计算机科学教授', '人工智能研究员', '认知科学专家', '社会学研究员', '虚拟现实专家', '技术伦理学家', '用户体验研究员', '人机交互技术顾问', '软件开发者', 'UX/UI设计师', '产品经理', '技术支持工程师', '系统管理员', '数据分析师', '内容创作者', '教育技术专家', '游戏开发者', '数字营销专员', '普通消费者', '中学生', '家庭主妇/主夫', '老年人', '残障人士', '零售店员', '非技术工作者', '自由职业者', '游戏爱好者', '退休人员'])
# ['触觉反馈对我个人在虚拟现实中的体验有显著影响，尤其是在游戏开发中。', '我认为当前的触觉反馈技术在某些情况下是真实的，但在大多数情况下还不够真实。', '我希望触觉反馈技术能够在模拟物体和环境的真实感上得到改进，以及提供更加自然和直观的交互体验。']

# %%
import json
# 指定要保存的 JSON 文件名
filename = 'Question_3_data.json'

# 将字典写入 JSON 文件
with open(filename, 'w') as f:
    json.dump(Q, f, indent=4)

# %%
from datetime import datetime

# 获取当前时间
current_time = datetime.now()

# 打印当前时间
print(current_time.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2024-08-06 20:50:46
