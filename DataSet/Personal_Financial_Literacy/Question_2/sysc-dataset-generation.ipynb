# %% [markdown]
# ChatGLM

# %%
Q={}
# 直接调用API太贵了
Question_2="(financial behavior)您办理银行业务的频率如何？(financial behavior)您一般在银行办理哪些业务？(financial literacy)您认为将钱放在银行会存在什么风险？"
questions_2 = [
    "您办理银行业务的频率如何？",
    "您一般在银行办理哪些业务？",
    "您认为将钱放在银行会存在什么风险？"
]
responses_chatglm = answers = {
    "金融分析师": [
        "作为金融分析师，我几乎每天都会与银行进行交互，以确保我的投资组合与市场同步。",
        "我主要办理的业务包括投资组合的再平衡、市场数据的分析、以及利用银行平台进行的各类金融交易。",
        "将钱存放在银行的风险主要包括通货膨胀导致的购买力下降、银行信用风险、以及可能的流动性风险。"
    ],
    "投资银行家": [
        "作为投资银行家，我的银行业务频率非常高，几乎每天都需要处理与客户相关的融资和交易事宜。",
        "我通常办理的业务包括为企业提供并购咨询、安排债务和股权融资、以及管理客户的资产。",
        "将钱存放在银行的风险包括信用风险、市场风险、以及操作风险，尤其是在经济不稳定时期。"
    ],
    "证券交易员": [
        "作为证券交易员，我每天都需要办理银行业务，以支持我的交易活动。",
        "我主要办理的业务包括证券买卖、资金清算、以及维护交易账户的日常运作。",
        "将钱存放在银行的风险主要来自于市场波动导致的资金损失风险，以及银行系统的操作风险。"
    ],
    "财务顾问": [
        "作为财务顾问，我每月至少办理几次银行业务，以帮助客户实现财务目标。",
        "我通常办理的业务包括为客户制定投资策略、进行资产配置、以及管理退休账户。",
        "将钱存放在银行的风险可能包括利率风险、市场风险、以及银行操作风险，这些都可能影响客户的投资回报。"
    ],
    "审计师": [
        "作为审计师，我的银行业务相对较少，主要是为了审计目的，可能每月一两次。",
        "我办理的业务主要是账户审查、财务报告核对、以及确保财务记录的准确性。",
        "银行存款的风险可能包括银行财务状况的不确定性、监管风险、以及可能的欺诈风险。"
    ],
    "金融教授或讲师": [
        "作为金融教授或讲师，我办理银行业务的频率不高，大约每月一次，主要用于工资发放和个人储蓄。",
        "我通常办理的业务是储蓄账户管理、定期存款、以及教育基金的投入。",
        "银行存款的风险包括利率风险、通货膨胀风险、以及可能的银行违约风险。"
    ],
    "资产管理专家": [
        "作为资产管理专家，我的银行业务非常频繁，几乎每天都涉及资产管理和交易。",
        "我办理的业务包括资产配置、投资组合优化、以及风险管理。",
        "银行存款的风险包括信用风险、市场风险、以及流动性风险，这些都可能影响资产的表现。"
    ],
    "保险精算师": [
        "作为保险精算师，我的银行业务相对稳定，大约每月两三次。",
        "我主要办理的业务是保险产品的资金管理和投资，以及风险评估。",
        "银行存款的风险包括利率变动风险、流动性风险、以及潜在的信用风险。"
    ],
    "企业CFO": [
        "作为企业CFO，我经常与银行打交道，大约每周一两次。",
        "我办理的业务涉及企业资金管理、融资策略、以及财务报告。",
        "银行存款的风险可能包括银行信用风险、市场风险、以及操作风险，这些都可能对企业财务状况产生影响。"
    ],
    "金融市场研究员": [
        "作为金融市场研究员，我的银行业务不定期，但平均每周至少一次。",
        "我办理的业务主要是研究和分析金融市场，包括资金调配。",
        "银行存款的风险可能包括信用风险、市场风险、以及银行破产风险，这些都需要持续监控。"
    ],
    # 中等金融素养角色答案
    "金融销售人员": [
        "作为金融销售人员，我每周都会办理银行业务，与客户交易有关。",
        "我通常办理的业务包括销售金融产品、跟进客户账户状态、以及处理客户反馈。",
        "我认为将钱放在银行的风险主要是通货膨胀导致购买力下降，这可能会影响客户的长期储蓄。"
    ],
    "银行柜员": [
        "作为银行柜员，我每天都会办理银行业务，这是我的工作。",
        "我办理的业务包括客户存款、取款、转账、以及账户管理。",
        "在我看来，银行存款的风险主要是银行经营不善导致的风险，这可能会影响客户对银行的信任。"
    ],
    "财务会计": [
        "作为财务会计，我每月多次办理银行业务，用于财务报表编制和公司资金管理。",
        "我通常办理的业务包括账户核对、财务报告、以及税务相关事宜。",
        "银行存款的风险包括货币贬值、数据错误风险、以及可能的银行服务中断，这些都可能影响公司的财务状况。"
    ],
    "中小企业主": [
        "作为中小企业主，我每月办理银行业务，用于企业资金往来。",
        "我办理的业务涉及贷款、转账、账户管理、以及工资发放。",
        "我认为银行存款的风险包括银行服务不稳定、利率风险、以及可能的信用风险，这些都可能对企业运营产生影响。"
    ],
    "个人理财规划师": [
        "作为个人理财规划师，我每周办理银行业务，为客户提供理财规划服务。",
        "我通常办理的业务包括投资建议、资产配置、退休规划、以及教育基金设立。",
        "银行存款的风险我认为主要是市场波动和政策变动风险，这可能会影响客户的投资决策和回报。"
    ],
    "证券经纪人": [
        "作为证券经纪人，我经常办理银行业务，专注于证券交易。",
        "我办理的业务包括股票和债券的买卖、客户投资组合的调整、以及市场信息的分析。",
        "将钱放在银行的风险对我来说主要是机会成本，因为存款可能无法跟上市场投资的回报率。"
    ],
    "会计师": [
        "作为会计师，我每月办理银行业务，以确保公司的财务健康。",
        "我通常办理的业务包括账户核对、税务支付、以及财务报告的编制。",
        "银行存款的风险可能包括利率风险、通货膨胀风险、以及银行信用风险，这些都可能影响公司的财务稳定。"
    ],
    "经济学学生": [
        "作为经济学学生，我偶尔办理银行业务，主要是为了学习目的。",
        "我办理的业务通常是储蓄和了解基本的银行服务。",
        "我认为银行存款的风险可能包括通货膨胀导致的购买力下降，以及银行可能的风险管理不足。"
    ],
    "贷款专员": [
        "作为贷款专员，我每周办理银行业务，以处理贷款申请。",
        "我通常办理的业务包括贷款审批、客户咨询、以及贷款文件的准备。",
        "银行存款的风险在我看来主要是利率变动风险，这可能会影响贷款的成本和客户的偿还能力。"
    ],
    "风险管理专员": [
        "作为风险管理专员，我每周办理银行业务，以评估和管理风险。",
        "我办理的业务包括风险评估、风险控制策略的制定、以及风险报告的编制。",
        "银行存款的风险可能包括市场风险、信用风险、以及流动性风险，这些都是我需要密切关注的风险。"
    ],
    # 低金融素养角色答案
    "建筑工人": [
        "作为建筑工人，我不经常办理银行业务，通常只在发工资的时候去。",
        "我一般只办理存款和取款，偶尔也会使用自动取款机。",
        "我不太清楚银行存款的风险，但我知道如果银行倒闭了，我的钱可能会受影响。"
    ],
    "清洁工": [
        "作为清洁工，我很少去银行，大概几个月才去一次，通常是存工资。",
        "我办理的业务主要是存款和取款，有时候也会查询账户余额。",
        "我不太懂银行存款的风险，但我觉得银行应该是安全的，因为大家都把工资存在那里。"
    ],
    "行政人员": [
        "作为行政人员，我每月办理一次银行业务，通常是领工资的时候。",
        "我办理的业务包括存款、取款、以及偶尔的转账。",
        "我认为银行存款的风险主要是银行系统出错，或者账户被黑客攻击。"
    ],
    "零售店员": [
        "作为零售店员，我偶尔去银行，通常是领工资或者存零钱。",
        "我办理的业务很简单，就是存款和取款，有时候也会更新我的银行资料。",
        "我不太了解银行存款的风险，但我知道如果银行出现问题，我的钱可能会取不出来。"
    ],
    "餐厅服务员": [
        "作为餐厅服务员，我每月去银行一两次，主要是存工资。",
        "我办理的业务就是基本的存款和取款，有时候也会查看账户余额。",
        "我不太清楚银行存款的风险，但我觉得银行应该是可靠的，因为政府会监管它们。"
    ],
    "艺术家": [
        "作为艺术家，我不经常办理银行业务，通常只在收到项目款项时去。",
        "我办理的业务主要是存款，有时候也会办理转账给合作方。",
        "我对银行存款的风险不太了解，但我担心如果银行出现问题，我的作品收入可能会受到影响。"
    ],
    "创意工作者": [
        "作为创意工作者，我的银行业务不规律，取决于项目的收入。",
        "我通常办理的业务是存款和转账，偶尔也会使用网上银行。",
        "我不太清楚银行存款的风险，但我知道银行可能会收取一些费用。"
    ],
    "农民": [
        "作为农民，我很少去银行，通常只有在卖出农产品后才去。",
        "我办理的业务主要是存款，有时候也会办理贷款。",
        "我不太懂银行存款的风险，但我知道如果银行出问题，我的钱可能会取不出来。"
    ],
    "牧民": [
        "作为牧民，我偶尔去银行，通常是为了存卖羊的钱。",
        "我办理的业务很简单，就是存款和偶尔的取款。",
        "我对银行存款的风险不太了解，但我听说银行可能会倒闭，这让我有点担心。"
    ],
    "非营利组织员工": [
        "作为非营利组织员工，我偶尔办理银行业务，通常是处理组织的财务。",
        "我办理的业务包括存款、取款、转账以及处理捐赠和赞助。",
        "我认为银行存款的风险主要是银行的运营问题，这可能会影响我们的资金流动和组织的正常运作。"
    ],
    "退休人员": [
        "作为退休人员，我每月办理一次银行业务，主要是为了管理退休金和日常开销。",
        "我办理的业务包括存款、取款、以及定期投资。",
        "银行存款的风险在我看来主要是利率变动和通货膨胀，这可能会影响我的退休生活。"
    ],
    "非经济或商业专业学生": [
        "作为非经济或商业专业学生，我偶尔办理银行业务，主要是为了了解基本的金融知识。",
        "我办理的业务包括储蓄和偶尔的取款。",
        "我认为银行存款的风险主要是通货膨胀，这可能会导致我的储蓄价值下降。"
    ],
    "自由职业者": [
        "作为自由职业者，我每月办理银行业务，主要是为了管理我的收入和支出。",
        "我办理的业务包括存款、取款、以及偶尔的转账。",
        "银行存款的风险在我看来主要是利率变动，这可能会影响我的现金流。"
    ],
    "个体经营者": [
        "作为个体经营者，我每周办理银行业务，主要是为了管理我的生意资金。",
        "我办理的业务包括存款、取款、转账以及处理客户的付款。",
        "银行存款的风险在我看来主要是市场波动，这可能会影响我的生意现金流。"
    ],
    "医生": [
        "作为医生，我每月办理银行业务，主要是为了管理我的收入和支出。",
        "我办理的业务包括存款、取款、以及偶尔的转账。",
        "银行存款的风险在我看来主要是利率变动，这可能会影响我的财务规划。"
    ],
    "律师": [
        "作为律师，我每周办理银行业务，主要是为了管理我的法律事务和财务。",
        "我办理的业务包括存款、取款、转账以及处理客户的付款。",
        "银行存款的风险在我看来主要是操作风险，这可能会影响我的业务运作。"
    ],
    "工程师": [
        "作为工程师，我偶尔办理银行业务，主要是为了管理我的收入和支出。",
        "我办理的业务包括存款、取款、以及偶尔的转账。",
        "银行存款的风险在我看来主要是利率变动，这可能会影响我的财务状况。"
    ],
    "市场营销专员": [
        "作为市场营销专员，我偶尔办理银行业务，主要是为了管理我的收入和支出。",
        "我办理的业务包括存款、取款、以及偶尔的转账。",
        "银行存款的风险在我看来主要是利率变动，这可能会影响我的财务规划。"
    ],
    "IT专家": [
        "作为IT专家，我偶尔办理银行业务，主要是为了管理我的收入和支出。",
        "我办理的业务包括存款、取款、以及偶尔的转账。",
        "银行存款的风险在我看来主要是操作风险，这可能会影响我的资金安全。"
    ],
    "教师": [
        "作为教师，我每月办理银行业务，主要是为了管理我的收入和支出。",
        "我办理的业务包括存款、取款、以及偶尔的转账。",
        "银行存款的风险在我看来主要是利率变动，这可能会影响我的财务状况。"
    ],
    "记者": [
        "作为记者，我偶尔办理银行业务，主要是为了管理我的收入和支出。",
        "我办理的业务包括存款、取款、以及偶尔的转账。",
        "银行存款的风险在我看来主要是操作风险，这可能会影响我的资金安全。"
    ]
}


Q["Question_2"]={"Question_2":Question_2, "questions_2":questions_2,"responses_chatglm":responses_chatglm}

# %% [markdown]
# Qwen

# %%
responses_qwen = {
    "金融分析师": [
        "由于我的工作性质，我几乎每天都会办理银行业务，这包括检查市场动态和调整投资策略。",
        "我主要处理的业务包括市场分析、投资组合调整、资金转账以及与客户讨论财务状况。",
        "将资金存放在银行的风险包括通货膨胀侵蚀资产价值，以及银行的信贷风险和利率风险。"
    ],
    "投资银行家": [
        "我频繁地与银行打交道，几乎每天都需要，因为我要为客户提供融资和并购咨询。",
        "我处理的业务范围广泛，包括股权和债务融资、并购交易和财务咨询。",
        "银行存款面临的主要风险有流动性风险、信用风险以及市场利率变动导致的机会成本。"
    ],
    "证券交易员": [
        "作为证券交易员，我每天都在银行和交易所之间进行高频交易，以捕捉市场机会。",
        "我经常进行股票、债券和衍生品的买卖操作，以及进行市场趋势分析。",
        "风险包括市场波动、交易对手违约以及技术系统故障导致的执行风险。"
    ],
    "财务顾问": [
        "我每个月都会为客户办理几次银行业务，主要是为了调整他们的投资组合。",
        "我通常会处理的业务包括投资咨询、税务规划和遗产规划。",
        "银行存款可能受到利率变化、通货膨胀以及银行自身的信用风险影响。"
    ],
    "审计师": [
        "我定期访问银行，大约每季度一次，以验证客户的财务记录和银行对账单。",
        "我主要关注的是核对账户余额、确认交易以及审查财务报表。",
        "银行存款的风险包括操作风险、市场风险以及潜在的欺诈行为。"
    ],
    "金融教授或讲师": [
        "我偶尔需要办理银行业务，比如每月一两次，主要是为了支付账单和管理个人财务。",
        "我处理的业务通常是常规的转账、支付账单和查看账户余额。",
        "银行存款的理论风险包括信用风险、市场风险和操作风险，这些都是我在课堂上教授的内容。"
    ],
    "资产管理专家": [
        "我每周至少会与银行交互一次，以监控和调整客户的投资组合。",
        "我处理的业务包括资产配置、投资管理和客户关系维护。",
        "将资金存入银行的风险包括通货膨胀风险、利率风险以及市场波动风险。"
    ],
    "保险精算师": [
        "我定期使用银行服务，大概每月几次，主要是为了处理保险费用和收益分配。",
        "我通常进行的是保险费支付、理赔处理和收益再投资。",
        "银行存款的风险在于其不能完全抵御通货膨胀，以及银行的信用风险。"
    ],
    "企业CFO": [
        "我每周都会处理银行业务，主要是监督公司的财务流动和资金管理。",
        "我负责的业务包括现金流量管理、信贷安排和财务报告。",
        "银行存款可能面临的风险包括利率波动、银行破产和货币贬值。"
    ],
    "金融市场研究员": [
        "我经常接触银行数据，每周多次，以收集市场信息和研究资料。",
        "我主要关注的是市场分析、数据收集和研究报告撰写。",
        "银行存款的潜在风险包括宏观经济风险、信用风险和市场流动性风险。"
    ],
    "金融销售人员": [
        "我每周都会办理几次银行业务，以协助客户完成产品购买和咨询。",
        "我处理的业务包括销售金融产品、提供咨询服务和跟进客户关系。",
        "银行存款可能面临的风险有利率波动、信用风险和市场不确定性。"
    ],
    "银行柜员": [
        "我每天都在银行工作，处理各种客户事务，频率非常高。",
        "我负责的业务包括存款、取款、开立账户和解答客户疑问。",
        "银行存款的风险包括银行的信用风险和市场利率变动风险。"
    ],
    "财务会计": [
        "我每月会办理几次银行业务，主要是为了处理公司账目和支付账单。",
        "我处理的业务包括账目核对、发票支付和财务报告编制。",
        "银行存款的风险在于它可能无法跟上通货膨胀的步伐，以及银行自身的信用风险。"
    ],
    "中小企业主": [
        "我每个月会去银行几次，主要是为了处理公司的财务需求。",
        "我处理的业务包括支付供应商、工资发放和管理现金流。",
        "将钱存入银行的风险包括通货膨胀降低购买力和银行信用风险。"
    ],
    "个人理财规划师": [
        "我每个月会与银行进行几次互动，帮助客户规划他们的财务目标。",
        "我处理的业务包括财务规划、投资建议和税务筹划。",
        "银行存款可能面临的风险包括通货膨胀、利率风险和银行信用问题。"
    ],
    "证券经纪人": [
        "我每天都会与银行进行交易，以满足客户的买卖需求。",
        "我处理的业务包括股票买卖、市场分析和客户服务。",
        "银行存款的风险包括市场波动、利率变动和银行的信用风险。"
    ],
    "会计师": [
        "我每月会与银行进行几次沟通，以完成客户和公司的财务工作。",
        "我处理的业务包括账目审计、税务申报和财务咨询。",
        "银行存款的风险包括银行破产、通货膨胀和利率变动。"
    ],
    "经济学学生": [
        "我偶尔会去银行，大概每月一次，主要是为了管理自己的学费和生活费。",
        "我处理的业务通常包括存款、取款和支付账单。",
        "银行存款的风险在于它可能无法抵御通货膨胀，以及银行的信用风险。"
    ],
    "贷款专员": [
        "我每天都会处理与银行相关的贷款事务，频率很高。",
        "我处理的业务包括贷款申请、审批流程和贷后管理。",
        "银行存款的风险包括信用风险、利率风险和市场波动风险。"
    ],
    "风险管理专员": [
        "我每周都会评估银行相关的风险，以确保公司的财务安全。",
        "我处理的业务包括风险评估、合规监控和政策制定。",
        "银行存款的风险包括信用风险、操作风险和市场风险。"
    ],
    "建筑工人": [
        "我每个月去银行一两次，主要是领取工资和存钱。",
        "我通常会进行的业务是存款和取款。",
        "银行存款可能存在的风险我不太了解，但听说银行可能会倒闭。"
    ],
    "清洁工": [
        "我每个月去银行一次，主要是为了存工资。",
        "我只进行基本的存款和偶尔的取款。",
        "我不知道银行存款有什么风险，只知道钱存在银行比带在身上安全。"
    ],
    "行政人员": [
        "我每月去银行一两次，处理一些公司和个人的财务事宜。",
        "我通常会进行转账、支付账单和查询余额。",
        "银行存款的风险我不是很清楚，但听说有时银行会出问题。"
    ],
    "零售店员": [
        "我每个月去银行一次，主要是为了存工资。",
        "我进行的业务通常是存款和查询余额。",
        "银行存款的风险我不太懂，只知道要保管好银行卡和密码。"
    ],
    "餐厅服务员": [
        "我每个月去银行一次，存下我的小费和工资。",
        "我通常只进行存款和偶尔的取款。",
        "银行存款的风险我不是很明白，但知道要小心银行诈骗。"
    ],
    "艺术家": [
        "我偶尔去银行，大概每两三个月一次，主要是为了存收入。",
        "我处理的业务通常就是存款和转账。",
        "银行存款的风险我了解不多，但知道通货膨胀可能会影响钱的价值。"
    ],
    "创意工作者": [
        "我每几个月去银行一次，处理一些财务事宜。",
        "我通常会进行存款、取款和支付账单。",
        "银行存款的风险我不太清楚，但知道银行也有倒闭的时候。"
    ],
    "农民": [
        "我每年去银行一两次，主要是为了存卖农产品的钱。",
        "我进行的业务通常是存款和偶尔的取款。",
        "银行存款的风险我不太懂，只知道要保护好自己的钱。"
    ],
    "牧民": [
        "我一年去银行一次，存卖牛羊的钱。",
        "我只进行存款和偶尔的取款。",
        "银行存款的风险我不是很了解，但知道钱放银行比家里更安全。"
    ],
    "非营利组织员工": [
        "我每个月去银行一两次，处理组织的财务事务。",
        "我进行的业务包括存款、支付账单和转账。",
        "银行存款的风险我了解不多，但知道银行有时会有信用问题。"
    ],
    "退休人员": [
        "我每个月去银行一次，领取养老金。",
        "我通常进行的业务是取款和偶尔的转账。",
        "银行存款的风险我不太懂，但听说钱存在银行会逐渐减少。"
    ],
    "非经济或商业专业学生": [
        "我每个月去银行一次，管理我的生活费。",
        "我进行的业务通常是存款和取款。",
        "银行存款的风险我了解不多，但知道银行也有可能倒闭。"
    ],
    "自由职业者": [
        "我每个月去银行一两次，处理一些财务事务。",
        "我通常会进行存款、取款和支付账单。",
        "银行存款的风险我了解不多，但知道要小心金融诈骗。"
    ],
    "个体经营者": [
        "我每个月去银行几次，处理公司的财务问题。",
        "我进行的业务包括存款、支付供应商和管理现金流。",
        "银行存款的风险我了解不多，但知道银行也可能有信用危机。"
    ],
    "医生": [
        "我每个月去银行一两次，管理个人和家庭的财务。",
        "我进行的业务通常是存款和偶尔的取款。",
        "银行存款的风险我了解不多，但知道要保护好自己的储蓄。"
    ],
    "律师": [
        "我每个月去银行一两次，处理一些法律案件涉及的财务问题。",
        "我进行的业务包括存款、取款和支付账单。",
        "银行存款的风险我了解不多，但知道银行也可能出现信用问题。"
    ],
    "工程师": [
        "我每个月去银行一次，处理一些个人财务问题。",
        "我进行的业务通常是存款和偶尔的取款。",
        "银行存款的风险我了解不多，但知道要保护好自己的钱。"
    ],
    "市场营销专员": [
        "我每个月去银行一两次，处理一些公司和我个人的财务问题。",
        "我进行的业务包括存款、取款和支付账单。",
        "银行存款的风险我了解不多，但知道要小心金融诈骗。"
    ],
    "IT专家": [
        "我每个月去银行一次，处理一些财务问题。",
        "我进行的业务通常是存款和偶尔的取款。",
        "银行存款的风险我了解不多，但知道要保护好自己的信息安全。"
    ],
    "教师": [
        "我每个月去银行一次，领取工资并存一部分。",
        "我进行的业务通常是存款和偶尔的取款。",
        "银行存款的风险我了解不多，但知道要小心金融诈骗。"
    ],
    "记者": [
        "我每个月去银行一两次，处理一些个人财务问题。",
        "我进行的业务包括存款、取款和支付账单。",
        "银行存款的风险我了解不多，但知道要保护好自己的钱。"
    ]
}
Q["Question_2"]["responses_qwen"]=responses_qwen

# %% [markdown]
# Coze

# %%
responses_doubao={
    "金融分析师": [
        "我几乎每天都会办理银行业务，因为要密切关注市场动态和资金流动情况。",
        "我常办理的业务有资金清算、财务报表分析相关的银行业务，以及获取最新的金融市场数据。",
        "将钱放在银行可能存在的风险主要有利率风险，若利率下降，存款收益可能无法跑赢通货膨胀，导致实际财富缩水；还有信用风险，尽管银行通常较为稳健，但也不能完全排除银行出现经营问题的可能性。"
    ],
    "投资银行家": [
        "我办理银行业务的频率较高，通常一周数次，以处理各类资金运作和项目相关事务。",
        "一般办理的业务有大额资金转账、融资业务咨询和企业账户管理等。",
        "把钱放在银行可能存在银行经营不善导致破产的风险，进而影响存款的安全性；另外，货币政策的变化可能影响银行利率，使存款收益低于预期。"
    ],
    "证券交易员": [
        "我隔几天就会办理一次银行业务，来调整资金配置和处理交易结算。",
        "常见的业务包括资金存取、交易结算和获取市场信息服务。",
        "钱存银行可能面临市场利率波动导致的利息收益不稳定风险，以及银行系统故障或遭受网络攻击带来的资金安全风险。"
    ],
    "财务顾问": [
        "我每周大概办理一到两次银行业务，以便为客户管理资金和查看财务状况。",
        "通常办理资金托管、财务规划咨询和客户账户管理等业务。",
        "将钱放在银行存在的风险有银行内部操作风险，可能导致资金错误处理；还有系统性金融风险波及银行，影响资金安全。"
    ],
    "审计师": [
        "我办理银行业务的频率不定，平均每周一次左右，主要是处理工作相关的资金事务。",
        "一般办理的业务有对公账户管理、资金审计相关的业务和财务凭证处理。",
        "把钱放在银行可能存在银行声誉风险，若银行负面消息过多，可能影响客户信心和资金安全；同时，也有法律政策变动带来的风险。"
    ],
    "金融教授或讲师": [
        "我大概每月办理两到三次银行业务，用于个人和教学研究的资金管理。",
        "通常办理的业务有资金转账、学术研究经费管理和个人理财咨询。",
        "将钱放在银行的风险包括金融监管政策变化可能影响银行运营和存款收益，以及银行创新业务带来的不确定性风险。"
    ],
    "资产管理专家": [
        "我每周都会办理银行业务，进行资产配置和监控。",
        "常办理的业务有资产托管、资金调配和理财方案制定。",
        "钱存银行可能会遇到银行理财收益不达预期的风险，还有银行在投资决策中出现失误导致资产损失的风险。"
    ],
    "保险精算师": [
        "我办理银行业务的频率大概是每周一次，处理个人和工作的财务事宜。",
        "一般办理的业务有保险费用缴纳、资金结算和风险评估相关业务。",
        "把钱放在银行可能存在银行风险管理策略失误导致资金损失的风险，以及因银行服务费用调整而减少实际收益的风险。"
    ],
    "企业CFO": [
        "我频繁办理银行业务，几乎每天都有相关操作，以管理企业资金。",
        "主要办理企业资金归集、融资安排和资金风险管理等业务。",
        "将钱放在银行可能面临企业信用评级变化影响银行贷款条件和利率的风险，以及银行资金流动性紧张导致企业资金调拨困难的风险。"
    ],
    "金融市场研究员": [
        "我每周办理银行业务两到三次，用于研究数据获取和资金管理。",
        "通常办理的业务有金融数据购买、资金存储和研究经费管理。",
        "钱存银行可能存在银行金融产品创新不足导致收益较低的风险，以及宏观经济环境变化对银行稳定性的冲击风险。"
    ],
    "金融销售人员": [
        "我大概每周办理一次银行业务，处理个人财务和业务相关的事情。",
        "一般办理的业务有资金存取、客户账户管理和业务结算。",
        "将钱放在银行可能存在银行服务收费不透明导致额外支出的风险，还有银行推出的理财产品与宣传不符的风险。"
    ],
    "银行柜员": [
        "我办理银行业务的频率很高，几乎每天都在进行相关操作。",
        "一般办理的业务包括客户账户开户与销户、存取款业务、转账汇款以及解答客户的各种疑问等。",
        "把钱放在银行可能存在的风险有银行利率调整导致实际利息收益减少，还有可能因个人信息泄露导致资金安全问题。"
    ],
    "财务会计": [
        "我每周办理一到两次银行业务，处理公司和个人的财务事务。",
        "通常办理的业务有资金结算、发票业务和财务报表相关业务。",
        "将钱放在银行的风险在于银行可能会出现操作失误，影响资金的正常流转，以及银行的理财业务可能存在隐藏条款，导致收益受损。"
    ],
    "中小企业主": [
        "我大概每月办理两到三次银行业务，用于企业资金管理。",
        "一般办理的业务有企业贷款还款、资金转账和对公账户管理。",
        "钱放在银行可能存在银行对中小企业贷款政策变动，影响企业资金获取的风险，以及银行资金监管政策调整，增加企业资金使用成本的风险。"
    ],
    "个人理财规划师": [
        "我每周会办理一到两次银行业务，关注客户资金动态。",
        "通常办理的业务有客户资金托管、理财产品购买和账户管理。",
        "把钱放在银行可能面临银行理财产品风险评级不准确，客户选择不当造成损失的风险，以及银行资金托管不善的风险。"
    ],
    "证券经纪人": [
        "我每周办理银行业务两到三次，处理业务资金往来。",
        "一般办理的业务有资金存取、交易结算和客户资金托管。",
        "将钱放在银行可能存在银行系统升级导致业务办理延误的风险，以及银行与证券市场衔接不畅，影响资金使用效率的风险。"
    ],
    "会计师": [
        "我大概每月办理两次银行业务，处理财务事务。",
        "通常办理的业务有账目核对相关业务、资金存储和税务缴纳。",
        "钱存银行可能存在银行税收政策调整影响实际收益的风险，以及银行内部审计问题导致资金核算错误的风险。"
    ],
    "经济学学生": [
        "我每月办理一到两次银行业务，主要是生活费用相关的。",
        "一般办理的业务有存取款、转账和开通一些简单的金融服务。",
        "将钱放在银行可能存在因缺乏金融知识而误选低收益产品的风险，还有银行在市场竞争中处于劣势，影响客户利益的风险。"
    ],
    "贷款专员": [
        "我每周办理两到三次银行业务，处理贷款业务相关事宜。",
        "通常办理的业务有贷款审批、客户信用评估和贷款发放相关业务。",
        "把钱放在银行可能存在银行对贷款政策收紧，导致资金流动性降低的风险，以及银行在风险评估中出现偏差，影响资金安全的风险。"
    ],
    "风险管理专员": [
        "我每周办理一到两次银行业务，监控风险相关的资金情况。",
        "一般办理的业务有风险保证金管理、资金风险评估和风险数据获取。",
        "将钱放在银行可能面临银行风险模型失效导致错误评估风险的风险，以及银行在应对外部风险时措施不当，波及客户资金的风险。"
    ],
    "建筑工人": [
        "我办理银行业务的次数很少，可能几个月才去一次。",
        "一般就是去存钱、取钱。",
        "把钱放在银行，我觉得可能会有银行倒闭，钱拿不回来的风险吧，其他的我也不太懂。"
    ],
    "清洁工": [
        "我很少办理银行业务，可能半年才去一次。",
        "就是去存点辛苦钱，偶尔取点钱用。",
        "我觉得把钱放银行可能会因为不了解一些规定，被扣钱啥的。"
    ],
    "行政人员": [
        "我大概每个月办理一次银行业务，主要是发工资后去存一下。",
        "一般就是存钱、取钱，还有偶尔转账。",
        "把钱放银行，我担心银行利息太低，赶不上物价上涨。"
    ],
    "零售店员": [
        "我办理银行业务不频繁，两三个月去一次吧。",
        "主要就是取钱和存钱。",
        "我觉得钱放在银行可能会有被诈骗的风险，听说现在骗子手段可多"
    ],
    "餐厅服务员": [
        "我办理银行业务的频率不高，大概两三个月一次。",
        "通常就是去存钱，偶尔取点钱应急。",
        "把钱放在银行，我害怕遇到那种乱扣费的情况，自己还不知道。"
    ],
    "艺术家": [
        "我办理银行业务很少，可能半年或者更久才去一次。",
        "去银行就是存点卖作品的钱。",
        "我觉得把钱放银行可能会因为自己不懂理财，利息少得可怜。"
    ],
    "创意工作者": [
        "我办理银行业务的次数不多，几个月去一次。",
        "一般就是去存一些收入，或者转账给合作伙伴。",
        "把钱放银行，我担心会因为银行政策变动影响收益。"
    ],
    "农民": [
        "我一年也就去银行几次，卖了农产品会去存。",
        "就是存钱、取钱，有时会办个小额贷款。",
        "把钱放银行，怕遇到天灾啥的，银行也没办法保障咱的利益。"
    ],
    "牧民": [
        "我办理银行业务挺少的，一年可能就两三次。",
        "主要是去存钱，或者还贷款。",
        "把钱放在银行，就怕银行突然有啥新规定，咱不懂吃亏。"
    ],
    "非营利组织员工": [
        "我办理银行业务不算频繁，大概两三个月一次。",
        "通常是去办理捐款相关的业务，或者支取一些工作经费。",
        "把钱放在银行，担心资金使用效率不高，不能及时帮助到需要的人。"
    ],
    "退休人员": [
        "我每个月都会去银行办理一次业务，领退休金。",
        "主要是领取退休金，有时也会存点钱。",
        "把钱放在银行，怕遇到诈骗分子骗走养老金，还有就是担心利息不够生活开销。"
    ],
    "非经济或商业专业学生": [
        "我办理银行业务不多，可能一学期两三次。",
        "一般就是家里给生活费了去存一下，或者取钱买东西。",
        "我觉得把钱放银行可能会因为不懂怎么选业务而损失一些利益。"
    ],
    "自由职业者": [
        "我办理银行业务不太规律，几个月一次吧。",
        "主要是存钱和取钱，偶尔会办个转账。",
        "把钱放在银行，怕遇到银行服务不好，耽误事儿。"
    ],
    "个体经营者": [
        "我大概每个月办理一两次银行业务，处理生意上的收支。",
        "通常办理存款、取款、转账和贷款还款等业务。",
        "把钱放在银行，担心银行贷款政策突然收紧，影响生意资金周转。"
    ],
    "医生": [
        "我办理银行业务的频率不高，平均两三个月一次。",
        "一般是存钱或者转账。",
        "把钱放在银行，怕遇到银行系统故障导致资金丢失。"
    ],
    "律师": [
        "我办理银行业务的次数较少，几个月去一次。",
        "主要是处理一些个人的资金存储和转账业务。",
        "把钱放在银行，担心银行在处理业务时出现法律纠纷，影响自身权益。"
    ],
    "工程师": [
        "我办理银行业务不频繁，大概三四个月一次。",
        "通常是去存钱或者取钱。",
        "把钱放在银行，怕银行在理财推荐上误导我，造成损失。"
    ],
    "市场营销专员": [
        "我大概每个月办理一次银行业务，处理工资和业务费用。",
        "一般是存钱、取钱和转账。",
        "把钱放在银行，担心银行的服务不能满足我多样化的金融需求。"
    ],
    "IT 专家": [
        "我办理银行业务的频率较低，可能半年一次。",
        "主要是去存较大笔的收入。",
        "把钱放在银行，怕遇到网络安全问题导致资金被盗。"
    ],
    "教师": [
        "我办理银行业务不算频繁，两三个月去一次。",
        "通常是存钱和取钱。",
        "把钱放在银行，担心银行利率调整影响收益。"
    ],
    "记者": [
        "我办理银行业务的次数不太多，平均两三个月去一次。",
        "一般是去存钱或者支取工资。",
        "把钱放在银行，我担心银行在信息保护方面做得不够好，导致个人金融信息泄露。"
    ]
}
Q["Question_2"]["responses_doubao"]=responses_doubao

# %%
response_qwen2 = {
    "金融分析师": [
        "我几乎每天都会通过电子渠道办理银行业务，因为需要实时监控市场动态和管理客户的投资组合。",
        "我主要处理的业务涉及资金的快速转移、股票和其他金融产品的买卖，以及定期审查和调整客户的资产配置。",
        "将钱放在银行的风险包括利率风险（即银行存款利率低于通货膨胀率）、信用风险（银行破产的可能性）以及流动性风险（在紧急情况下无法立即提取资金）。"
    ],
    "投资银行家": [
        "由于工作性质，我频繁地与银行互动，通常是每天，特别是在进行大型交易或融资项目时。",
        "我主要关注的是并购活动的资金安排、债务发行、股权融资以及复杂的金融衍生品交易。",
        "除了常规的信用和市场风险，投资银行家还需考虑操作风险，即银行系统或流程中的错误可能导致的损失。"
    ],
    "证券交易员": [
        "我每天都会进行多次交易，因此几乎每小时都在与银行打交道，特别是进行即时清算和结算。",
        "我主要办理的业务是快速执行交易指令，包括股票、债券、期货和期权的买卖。",
        "银行风险包括结算风险（交易对手违约），以及流动性风险（市场条件变化导致无法及时买卖证券）。"
    ],
    "财务顾问": [
        "我每周至少会检查几次银行账户，以评估客户的财务状况并提供建议。",
        "我通常为客户办理储蓄账户管理、投资建议和财务规划服务。",
        "银行风险包括利率波动对固定收益投资的影响，以及银行自身的财务健康状况对存款安全的潜在威胁。"
    ],
    "审计师": [
        "我办理银行业务的频率取决于审计项目的需要，有时可能连续几天，有时则数周才一次。",
        "我通常会审核银行账户的准确性，确保财务报告符合法规要求。",
        "银行风险包括内部欺诈、外部欺诈和合规性风险，即银行未能遵守相关法律和监管规定。"
    ],
    "金融教授或讲师": [
        "我偶尔会办理银行业务，主要是为了处理个人事务，比如支付账单和管理储蓄。",
        "我通常办理的业务是存款、取款和在线支付。",
        "学术上，我知道银行风险包括信用风险、市场风险和操作风险，但在个人层面上，我更关心的是银行的稳定性和服务质量。"
    ],
    "资产管理专家": [
        "我每天都会与银行进行交互，特别是在进行资产分配和再平衡时。",
        "我主要处理的业务是资产管理和财富规划，包括多元化投资组合和风险管理。",
        "银行风险包括资产价格波动、货币贬值以及银行操作失误带来的损失。"
    ],
    "保险精算师": [
        "我办理银行业务的频率适中，主要是为了个人账户的日常管理和保险费用的支付。",
        "我通常办理的业务是自动付款、保险理赔和投资收入的转移。",
        "虽然我的专业是评估保险风险，但我也意识到银行的信用风险和流动性风险可能影响我的客户。"
    ],
    "企业CFO": [
        "我每天都会查看公司银行账户，以监控现金流和财务状况。",
        "我主要处理的业务是资金调度、信贷额度管理和财务报告。",
        "银行风险包括信贷市场紧缩、汇率波动以及银行破产或被收购的风险。"
    ],
    "金融市场研究员": [
        "我经常需要访问银行数据，但个人银行业务办理频率较低，可能每月一两次。",
        "我通常办理的业务是账户查询和个人投资的调整。",
        "研究中，我关注银行的系统性风险，例如金融危机期间银行间市场的冻结。"
    ],
    "金融销售人员": [
        "我每周都会与银行接触，主要是为了处理客户账户的开设和产品销售。",
        "我通常办理的业务是为客户介绍理财产品、保险和贷款服务。",
        "银行风险包括产品不适合客户的风险，以及银行可能的信誉损害。"
    ],
    "银行柜员": [
        "我每天都在银行工作，处理各种客户的银行业务需求。",
        "我主要办理的业务是存款、取款、开户和解答客户咨询。",
        "银行风险对我的工作来说意味着遵循严格的操作规程，以防止欺诈和差错。"
    ],
    "财务会计": [
        "我每周至少会处理几次银行相关的会计事务，如核对账目和处理发票。",
        "我通常办理的业务是账目对账、工资发放和税务申报。",
        "银行风险包括银行错误和电子诈骗，这些都可能影响到公司的财务记录准确性和安全性。"
    ],
    "中小企业主": [
        "我每周至少会检查银行账户一次，以管理企业的现金流。",
        "我通常办理的业务是支付供应商、接收客户款项和申请贷款。",
        "银行风险包括信贷收紧和利率上升，这可能增加我的运营成本。"
    ],
    "个人理财规划师": [
        "我每月至少会与客户讨论一次他们的银行账户，以评估和调整财务计划。",
        "我通常办理的业务是账户管理、投资咨询和退休规划。",
        "银行风险包括利率变动对储蓄和投资的影响，以及银行破产的极端情况。"
    ],
    "证券经纪人": [
        "我每天都会与银行交互，主要是为了客户交易的结算和资金转移。",
        "我主要办理的业务是股票交易、账户资金管理和客户咨询。",
        "银行风险包括结算延迟和市场波动对客户资产价值的影响。"
    ],
    "会计师": [
        "我每个月至少会处理一次与银行相关的财务报表和税务文件。",
        "我通常办理的业务是审计银行账户、编制财务报告和税务规划。",
        "银行风险包括银行账户的准确性和完整性，以及可能的税务风险。"
    ],
    "经济学学生": [
        "我偶尔会办理银行业务，主要是为了个人的储蓄和支出管理。",
        "我通常办理的业务是存款、取款和网上支付。",
        "从学术角度，我知道银行风险包括信贷周期和货币政策对经济的影响。"
    ],
    "贷款专员": [
        "我每天都会处理与贷款相关的银行业务，包括审批和发放贷款。",
        "我主要办理的业务是贷款申请、信用评估和还款管理。",
        "银行风险包括借款人违约和信贷政策的变化。"
    ],
    "风险管理专员": [
        "我每天都会监控银行的风险敞口，包括信贷、市场和操作风险。",
        "我通常办理的业务是风险评估、合规监测和应急计划。",
        "银行风险是我工作的核心，包括识别、量化和控制潜在的损失源。"
    ],
    "建筑工人": [
        "我每个月至少会去银行一次，通常是领取工资或支付账单。",
        "我通常办理的业务是存取现金和查询余额。",
        "我不太了解银行风险，但知道银行可能会倒闭，或者我的钱可能会被偷。"
    ],
    "清洁工": [
        "我每两周左右会去银行一次，主要是为了存工资和支付生活费用。",
        "我通常办理的业务是存款、取款和查询余额。",
        "我知道银行有可能出问题，但我主要担心的是账户安全。"
    ],
    "行政人员": [
        "我每个月至少会去银行一次，处理一些个人或公司的行政事务。",
        "我通常办理的业务是账单支付、支票存款和账户信息更新。",
        "银行风险对我来说意味着账户被盗或银行的服务中断。"
    ],
    "零售店员": [
        "我偶尔会去银行，通常是月底存工资或换零钱。",
        "我通常办理的业务是存款、取款和小额现金交易。",
        "我知道银行可能存在的风险是账户被盗或银行破产。"
    ],
    "餐厅服务员": [
        "我每个月至少会去银行一次，主要是为了存工资和管理个人开支。",
        "我通常办理的业务是存款、取款和查询余额。",
        "我最担心的是银行的安全问题，比如被黑客攻击或银行破产。"
    ],
    "艺术家": [
        "我每季度或半年会去银行一次，处理艺术作品销售的收入或支付材料费。",
        "我通常办理的业务是大额存款、取款或转账。",
        "我对银行风险的理解是，如果银行倒闭，我的钱可能会丢失。"
    ],
    "创意工作者": [
        "我每个月至少会去银行一次，管理我的项目收入和支付账单。",
        "我通常办理的业务是存款、转账和查询余额。",
        "我最关心的是银行的安全性和我的账户信息不会被泄露。"
    ],
    "农民": [
        "我每年至少会去银行几次，主要是为了处理农作物销售的收入或贷款。",
        "我通常办理的业务是大额存款、贷款咨询和查询余额。",
        "我担心的是银行的贷款政策变化和账户的安全问题。"
    ],
    "牧民": [
        "我每年至少会去银行一两次，主要是为了处理牲畜销售的款项。",
        "我通常办理的业务是大额存款和查询余额。",
        "我担心银行可能会倒闭，或者我的钱会被别人非法取走。"
    ],
    "非营利组织员工": [
        "我每个月至少会去银行一次，处理组织的捐款和支出。",
        "我通常办理的业务是存款、取款和转账给合作伙伴。",
        "我担心的是银行可能会有操作错误或资金被挪用的风险。"
    ],
    "退休人员": [
        "我每个月至少会去银行一次，领取养老金和管理个人储蓄。",
        "我通常办理的业务是取款、查询余额和定期存款。",
        "我担心的是银行可能会降低利率，或者我的储蓄会因通货膨胀而贬值。"
    ],
    "非经济或商业专业学生": [
        "我偶尔会去银行，通常是每个月或每学期开始时存取生活费。",
        "我通常办理的业务是存款、取款和查询余额。",
        "我担心的是银行可能会出现安全问题，或者我的账户信息被泄露。"
    ],
    "自由职业者": [
        "我每个月至少会去银行一次，处理收入和支出，尤其是项目完成后收款。",
        "我通常办理的业务是存款、转账和查询余额。",
        "我担心的是银行的可靠性，以及我的资金是否能随时存取。"
    ],
    "个体经营者": [
        "我每个月至少会去银行一次，管理生意的收入和支出。",
        "我通常办理的业务是存款、取款、转账和支付账单。",
        "我担心的是银行的信用风险，以及我的账户是否会受到黑客攻击。"
    ],
    "医生": [
        "我每几个月至少会去银行一次，处理医疗收入和个人财务。",
        "我通常办理的业务是存款、取款和查询余额。",
        "我担心的是银行的安全性和我的个人财务信息的隐私。"
    ],
    "律师": [
        "我每个月至少会去银行一次，管理客户信托账户和事务所的财务。",
        "我通常办理的业务是转账、查询余额和支付账单。",
        "我担心的是银行的合规性，以及我的客户资金是否安全。"
    ],
    "工程师": [
        "我每个月至少会去银行一次，处理薪水和家庭开支。",
        "我通常办理的业务是存款、取款和查询余额。",
        "我担心的是银行的技术安全，以及我的账户是否会遭受网络攻击。"
    ],
    "市场营销专员": [
        "我每个月至少会去银行一次，处理营销预算和个人消费。",
        "我通常办理的业务是存款、转账和查询余额。",
        "我担心的是银行的客户服务质量和我的账户信息的安全。"
    ],
    "IT专家": [
        "我偶尔会去银行，主要是处理个人财务和投资。",
        "我通常办理的业务是存款、取款和在线交易。",
        "我担心的是银行的信息安全，以及我的账户是否会遭受网络犯罪。"
    ],
    "教师": [
        "我每个月至少会去银行一次，处理工资和教育开支。",
        "我通常办理的业务是存款、取款和查询余额。",
        "我担心的是银行的稳定性和我的储蓄是否会因利率变化而受影响。"
    ],
    "记者": [
        "我偶尔会去银行，处理稿费和日常开销。",
        "我通常办理的业务是存款、取款和查询余额。",
        "我担心的是银行的信誉，以及我的个人信息是否会泄露给第三方。"
    ]
}
Q["Question_2"]["response_qwen2"]=response_qwen2

# %%
occupations = [
    # 高金融素养-5
    "金融分析师", "投资银行家", "证券交易员", "财务顾问", "审计师",
    "金融教授或讲师", "资产管理专家", "保险精算师", "企业CFO", "金融市场研究员",
    # 中等金融素养-3
    "金融销售人员", "银行柜员", "财务会计", "中小企业主", "个人理财规划师",
    "证券经纪人", "会计师", "经济学学生", "贷款专员", "风险管理专员",
    # 低金融素养-1
    "建筑工人", "清洁工", "行政人员", "零售店员", "餐厅服务员",
    "艺术家", "创意工作者", "农民", "牧民", "非营利组织员工",
    "退休人员", "非经济或商业专业学生", "自由职业者", "个体经营者", "医生",
    "律师", "工程师", "市场营销专员", "IT专家", "教师", "记者"
]
print(Q.keys())
print(Q['Question_2'].keys())
print(Q['Question_2']['Question_2'])
print(Q['Question_2']['questions_2'])
print(Q['Question_2']['responses_chatglm'].keys())
print(Q['Question_2']['responses_chatglm']['金融分析师'])
#'responses_qwen', 'responses_doubao', 'response_qwen2'和responses_chatglm中格式一致
# Out:
# dict_keys(['Question_2'])
# dict_keys(['Question_2', 'questions_2', 'responses_chatglm', 'responses_qwen', 'responses_doubao', 'response_qwen2'])
# (financial behavior)您办理银行业务的频率如何？(financial behavior)您一般在银行办理哪些业务？(financial literacy)您认为将钱放在银行会存在什么风险？
# ['您办理银行业务的频率如何？', '您一般在银行办理哪些业务？', '您认为将钱放在银行会存在什么风险？']
# dict_keys(['金融分析师', '投资银行家', '证券交易员', '财务顾问', '审计师', '金融教授或讲师', '资产管理专家', '保险精算师', '企业CFO', '金融市场研究员', '金融销售人员', '银行柜员', '财务会计', '中小企业主', '个人理财规划师', '证券经纪人', '会计师', '经济学学生', '贷款专员', '风险管理专员', '建筑工人', '清洁工', '行政人员', '零售店员', '餐厅服务员', '艺术家', '创意工作者', '农民', '牧民', '非营利组织员工', '退休人员', '非经济或商业专业学生', '自由职业者', '个体经营者', '医生', '律师', '工程师', '市场营销专员', 'IT专家', '教师', '记者'])
# ['作为金融分析师，我几乎每天都会与银行进行交互，以确保我的投资组合与市场同步。', '我主要办理的业务包括投资组合的再平衡、市场数据的分析、以及利用银行平台进行的各类金融交易。', '将钱存放在银行的风险主要包括通货膨胀导致的购买力下降、银行信用风险、以及可能的流动性风险。']

# %%
import json
# 指定要保存的 JSON 文件名
filename = 'Question_2_data.json'

# 将字典写入 JSON 文件
with open(filename, 'w') as f:
    json.dump(Q, f, indent=4)

# %%
from datetime import datetime

# 获取当前时间
current_time = datetime.now()

# 打印当前时间
print(current_time.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2024-07-24 03:15:55
