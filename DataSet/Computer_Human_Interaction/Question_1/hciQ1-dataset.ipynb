# %% [markdown]
# ChatGLM

# %%
Q={}
Question_1 = "(AI Response Expectations) AI系统的响应是否符合你的期望？(AI Understanding Accuracy) 在使用AI系统时，你是否感到AI对你的需求理解准确？(Desired AI Features) 你希望AI系统增加哪些功能来提高用户体验？"
questions_1 = [
    "AI系统的响应是否符合你的期望？",
    "在使用AI系统时，你是否感到AI对你的需求理解准确？",
    "你希望AI系统增加哪些功能来提高用户体验？"
]
responses_chatglm = answers = {
    # 高专业程度 (Advanced) - 5
    "人机交互研究员": [
        "AI系统的响应基本符合我的期望，但在复杂交互场景中的自然语言处理方面还有提升空间。",
        "AI对我的需求理解较为准确，特别是在实验设计和数据分析方面，但在理解非标准化的交互意图上还需改进。",
        "我希望AI系统能够增加情感识别和情境适应性，以提高与用户的互动质量。"
    ],
    "交互设计专家": [
        "AI系统的响应在设计方面有时缺乏创新，不完全符合我的创意期望。",
        "AI对用户需求的理解存在一定偏差，特别是在处理用户界面设计时的细微差别。",
        "我希望AI系统能够提供更个性化的设计建议和用户行为分析，以优化用户体验。"
    ],
    "计算机科学教授": [
        "AI系统的响应在逻辑运算和数据处理上符合我的期望，但在创新问题解决上表现不足。",
        "AI对我的需求理解较为准确，尤其是在算法优化和程序设计方面。",
        "我希望AI系统能够集成更多前沿算法，以支持复杂问题的研究。"
    ],
    "人工智能研究员": [
        "AI系统的响应通常符合我的期望，但我知道它在自主学习方面还有很大的进步空间。",
        "AI对我的需求理解准确，特别是在数据处理和模型训练方面。",
        "我希望AI系统能够实现更高级的机器学习技术，以提升其智能水平。"
    ],
    "认知科学专家": [
        "AI系统的响应在模仿人类认知过程方面尚有差距，不完全符合我的期望。",
        "AI对复杂人类行为的理解还有待提高，特别是在理解认知偏差和情感表达上。",
        "我希望AI系统能够更好地模拟人类认知过程，包括记忆和注意力分配。"
    ],
    "社会学研究员": [
        "AI系统的响应在社会数据分析上基本符合我的期望，但在理解社会互动复杂性上有所不足。",
        "AI对我的需求理解较为准确，特别是在量化研究和社会趋势分析方面。",
        "我希望AI系统能够增加对社会网络和人类行为模式的理解，以提高分析准确性。"
    ],
    "虚拟现实专家": [
        "AI系统的响应在虚拟环境交互上符合我的期望，但在创造沉浸式体验上还有提升空间。",
        "AI对我的需求理解准确，特别是在场景设计和用户互动方面。",
        "我希望AI系统能够提供更高级的虚拟现实交互技术，以增强用户体验。"
    ],
    "技术伦理学家": [
        "AI系统的响应在伦理判断上存在不足，不完全符合我的期望。",
        "AI对我的需求理解有限，特别是在处理伦理困境和道德决策上。",
        "我希望AI系统能够增加伦理决策支持功能，以提高其道德判断能力。"
    ],
    "用户体验研究员": [
        "AI系统的响应在用户研究方面基本符合我的期望，但在深入挖掘用户需求上还需加强。",
        "AI对我的需求理解较为准确，特别是在用户访谈和数据分析方面。",
        "我希望AI系统能够提供更深入的用户洞察和体验优化建议。"
    ],
    "人机交互技术顾问": [
        "AI系统的响应在提供交互技术建议上符合我的期望，但在定制化解决方案上还需改进。",
        "AI对我的需求理解准确，特别是在技术选型和交互设计方面。",
        "我希望AI系统能够提供更灵活的技术咨询和解决方案。"
    ],

    # 中等专业程度 (Intermediate) - 3
    "软件开发者": [
        "AI系统的响应在编程辅助和代码优化上基本符合我的期望，但在理解复杂项目需求上有所欠缺。",
        "AI对我的需求理解一般，特别是在处理特定编程语言和环境的问题上。",
        "我希望AI系统能够提供更强大的代码分析和自动化测试功能。"
    ],
    "UX/UI设计师": [
        "AI系统的响应在设计辅助上有时缺乏创意，不完全符合我的创意期望。",
        "AI对我的设计需求理解存在偏差，特别是在处理设计细节和用户心理上。",
        "我希望AI系统能够提供更丰富的设计素材和用户研究支持。"
    ],
    "产品经理": [
        "AI系统的响应在市场分析和用户反馈上符合我的期望，但在产品规划方面还需加强。",
        "AI对我的需求理解较为准确，特别是在用户需求和市场竞争分析上。",
        "我希望AI系统能够提供更精准的市场预测和产品优化建议。"
    ],
    "技术支持工程师": [
        "AI系统的响应在解决技术问题上基本符合我的期望，但在处理紧急情况时反应不够迅速。",
        "AI对我的需求理解较为准确，特别是在解决常见技术问题上。",
        "我希望AI系统能够提供更快捷的技术支持，以提高用户满意度。"
    ],
    "系统管理员": [
        "AI系统的响应在系统维护和更新上基本符合我的期望，但在处理突发问题时反应不够迅速。",
        "AI对我的需求理解较为准确，特别是在系统监控和故障排除上。",
        "我希望AI系统能够提供更实时的系统监控和故障预警功能。"
    ],
    "数据分析师": [
        "AI系统的响应在数据处理和分析上基本符合我的期望，但在处理大数据集时效率有待提高。",
        "AI对我的需求理解较为准确，特别是在数据挖掘和趋势分析上。",
        "我希望AI系统能够提供更高效的大数据分析工具和预测模型。"
    ],
    "内容创作者": [
        "AI系统的响应在内容创作辅助上基本符合我的期望，但在处理创意和个性化内容时表现不足。",
        "AI对我的需求理解较为准确，特别是在内容编辑和优化上。",
        "我希望AI系统能够提供更强大的内容创作工具和个性化推荐功能。"
    ],
    "教育技术专家": [
        "AI系统的响应在教育辅助上基本符合我的期望，但在处理复杂教育问题时表现不足。",
        "AI对我的需求理解较为准确，特别是在教学资源和课程设计上。",
        "我希望AI系统能够提供更灵活的教育辅助工具和个性化学习方案。"
    ],
    "游戏开发者": [
        "AI系统的响应在游戏开发辅助上基本符合我的期望，但在处理复杂游戏逻辑和AI设计时表现不足。",
        "AI对我的需求理解较为准确，特别是在游戏平衡和AI行为上。",
        "我希望AI系统能够提供更强大的游戏开发工具和AI优化功能。"
    ],
    "数字营销专员": [
        "AI系统的响应在数字营销策略上基本符合我的期望，但在处理实时营销数据和个性化营销上表现不足。",
        "AI对我的需求理解较为准确，特别是在营销分析和目标受众上。",
        "我希望AI系统能够提供更实时的营销数据分析和个性化营销工具。"
    ],
    # 低金融素养角色答案
    "普通消费者": [
        "AI系统的响应有时候让我感到困惑，不太符合我的期望。",
        "AI对我的需求理解有时候不够准确，我需要重复说明我的问题。",
        "我希望AI系统能够更加简单易用，减少操作步骤。"
    ],
    "中学生": [
        "AI系统的响应有时候挺酷的，但有时候不太懂我在说什么。",
        "AI对我的学习需求理解一般，有时候给出的帮助并不合适。",
        "我希望AI系统能够像老师一样耐心地教我，并且能够陪我玩游戏。"
    ],
    "家庭主妇/主夫": [
        "AI系统的响应有时候挺方便的，但有时候我觉得它不够智能。",
        "AI对我日常生活的需求理解有时候不够准确，比如做菜时给出的建议。",
        "我希望AI系统能够提供更实用的生活小窍门和自动化家务解决方案。"
    ],
    "老年人": [
        "AI系统的响应有时候挺方便的，但有时候我觉得它不够智能。",
        "AI对我日常生活的需求理解有时候不够准确，比如做菜时给出的建议。",
        "我希望AI系统能够提供更实用的生活小窍门和自动化家务解决方案。"
    ],
    "残障人士": [
        "AI系统的响应有时候挺方便的，但有时候我觉得它不够智能。",
        "AI对我日常生活的需求理解有时候不够准确，比如做菜时给出的建议。",
        "我希望AI系统能够提供更实用的生活小窍门和自动化家务解决方案。"
    ],
    "零售店员": [
        "AI系统的响应有时候挺方便的，但有时候我觉得它不够智能。",
        "AI对我日常生活的需求理解有时候不够准确，比如做菜时给出的建议。",
        "我希望AI系统能够提供更实用的生活小窍门和自动化家务解决方案。"
    ],
    "非技术工作者": [
        "AI系统的响应有时候挺方便的，但有时候我觉得它不够智能。",
        "AI对我日常生活的需求理解有时候不够准确，比如做菜时给出的建议。",
        "我希望AI系统能够提供更实用的生活小窍门和自动化家务解决方案。"
    ],
    "自由职业者": [
        "AI系统的响应有时候挺方便的，但有时候我觉得它不够智能。",
        "AI对我日常生活的需求理解有时候不够准确，比如做菜时给出的建议。",
        "我希望AI系统能够提供更实用的生活小窍门和自动化家务解决方案。"
    ],
    "游戏爱好者": [
        "AI系统的响应有时候挺方便的，但有时候我觉得它不够智能。",
        "AI对我日常生活的需求理解有时候不够准确，比如做菜时给出的建议。",
        "我希望AI系统能够提供更实用的生活小窍门和自动化家务解决方案。"
    ],
    "退休人员": [
        "AI系统的响应有时候挺方便的，但有时候我觉得它不够智能。",
        "AI对我日常生活的需求理解有时候不够准确，比如做菜时给出的建议。",
        "我希望AI系统能够提供更实用的生活小窍门和自动化家务解决方案。"
    ]
}


Q["Question_1"]={"Question_1":Question_1, "questions_1":questions_1,"responses_chatglm":responses_chatglm}

# %% [markdown]
# Qwen

# %%
responses_qwen = {
    "人机交互研究员": [
        "AI系统的响应大多时候符合我的期望，特别是在任务明确的情况下。",
        "总体来说，AI能够理解我的需求，但在复杂指令上有时会出现偏差。",
        "我希望AI能更好地理解自然语言中的隐喻和抽象概念，提升对话的流畅性和自然度。"
    ],
    "交互设计专家": [
        "AI系统的响应大多数情况下是符合预期的，尤其是在用户界面友好的情况下。",
        "AI对我的需求理解比较准确，但仍需要改进在多步骤任务中的表现。",
        "我希望AI能够更好地处理多模态输入，比如语音和手势的结合，以增强用户体验。"
    ],
    "计算机科学教授": [
        "AI系统的响应通常非常准确，但也有一些边缘情况下的挑战。",
        "在大多数情况下，AI能很好地理解我的需求，但仍有改进的空间。",
        "我希望能看到更多关于AI透明度和可解释性的功能，这对教学很有帮助。"
    ],
    "人工智能研究员": [
        "AI系统的响应在大多数情况下都能达到我的期望，尤其是在学术研究领域。",
        "AI通常能准确地理解我的需求，但还有些细微差别需要进一步改善。",
        "我希望能够有更多定制化的训练选项，以便更精细地调教AI的行为。"
    ],
    "认知科学专家": [
        "AI系统的响应在认知任务方面表现良好，但在理解和模拟人类思维方面仍有差距。",
        "AI对我的需求理解还算准确，但在处理模糊概念时会遇到困难。",
        "我希望AI能更好地模拟人类的思考过程，包括情感和社会认知。"
    ],
    "社会学研究员": [
        "AI系统的响应在数据分析方面很好，但在社会情境的理解上有待加强。",
        "AI能理解我的大部分需求，但在复杂的社会议题上有时不够深入。",
        "我希望能够有更多的文化适应性和敏感性设置，以更好地服务于全球用户。"
    ],
    "虚拟现实专家": [
        "AI在虚拟环境中的表现令人满意，但在某些交互细节上还可以做得更好。",
        "AI通常能准确理解我在虚拟环境中的需求，但在复杂场景中需要更多的上下文理解。",
        "我希望AI能够更好地支持空间感知和环境适应性，以增强沉浸感。"
    ],
    "技术伦理学家": [
        "AI系统的响应在道德和伦理问题上的表现参差不齐。",
        "AI对我的需求理解尚可，但在涉及伦理决策时需要更谨慎。",
        "我希望AI能有更强的道德判断能力和对隐私保护的关注。"
    ],
    "用户体验研究员": [
        "AI系统的响应通常符合我的期望，但在特定情境下还需要优化。",
        "AI对我的需求理解比较准确，但在个性化体验方面有待提高。",
        "我希望AI能够提供更个性化的建议和服务，以增强用户的参与度。"
    ],
    "人机交互技术顾问": [
        "AI系统的响应在大多数情况下是符合期望的，但有时缺乏灵活性。",
        "AI对我的需求理解准确，但在处理复杂命令时有时需要更智能的方法。",
        "我希望AI能更好地支持多语言和方言识别，以扩大用户群体。"
    ],
    "软件开发者": [
        "AI系统的响应在编程帮助方面非常有用，但有时需要更具体的上下文。",
        "AI通常能理解我的需求，但在代码审查和调试方面还需要改进。",
        "我希望AI能够更好地支持代码生成和重构，以提高开发效率。"
    ],
    "UX/UI设计师": [
        "AI系统的响应在设计灵感和反馈方面很有帮助，但在具体实现上还需努力。",
        "AI对我的需求理解准确，但在设计细节上有时需要更专业的指导。",
        "我希望AI能够更好地支持设计元素的自动布局和风格转换。"
    ],
    "产品经理": [
        "AI系统的响应在市场分析方面很有帮助，但在战略规划上还需加强。",
        "AI通常能理解我的需求，但在预测市场趋势时有时需要更准确的数据。",
        "我希望AI能够更好地支持竞品分析和用户反馈的自动化收集。"
    ],
    "技术支持工程师": [
        "AI系统的响应在故障排除方面非常有用，但有时需要更详细的说明。",
        "AI对我的需求理解准确，但在处理复杂的技术问题时需要更专业的知识。",
        "我希望AI能够更好地支持故障诊断和自动修复流程。"
    ],
    "系统管理员": [
        "AI系统的响应在监控和维护方面很有帮助，但有时需要更具体的指令。",
        "AI通常能理解我的需求，但在处理网络配置时有时需要更深入的知识。",
        "我希望AI能够更好地支持自动化运维任务，如备份和安全检查。"
    ],
    "数据分析师": [
        "AI系统的响应在数据分析方面非常有效，但在解释复杂模型时需要更清晰。",
        "AI对我的需求理解准确，但在解释统计结果时有时需要更详细的说明。",
        "我希望AI能够更好地支持高级数据分析工具的集成。"
    ],
    "内容创作者": [
        "AI系统的响应在创作灵感方面很有帮助，但在创造性写作上还需努力。",
        "AI通常能理解我的需求，但在生成高质量文章时有时需要更深入的思考。",
        "我希望AI能够更好地支持文本生成和编辑，以提高创作效率。"
    ],
    "教育技术专家": [
        "AI系统的响应在教育资源推荐方面很有用，但在课程设计上还需加强。",
        "AI对我的需求理解准确，但在个性化学习路径规划方面需要更多的创新。",
        "我希望AI能够更好地支持学习进度跟踪和评估反馈。"
    ],
    "游戏开发者": [
        "AI系统的响应在游戏设计方面非常有用，但在关卡设计上还需努力。",
        "AI通常能理解我的需求，但在生成游戏内资源时有时需要更具体的指引。",
        "我希望AI能够更好地支持游戏内智能NPC的行为设计。"
    ],
    "数字营销专员": [
        "AI系统的响应在广告投放方面很有帮助，但在内容创作上还需加强。",
        "AI通常能理解我的需求，但在创意广告策划上有时需要更专业的建议。",
        "我希望AI能够更好地支持社交媒体互动和用户行为分析。"
    ],
    "普通消费者": [
        "AI系统的响应有时符合我的期望，但在日常使用中还需要更多的实践。",
        "AI有时能理解我的需求，但在处理简单查询时有时需要更直接的回应。",
        "我希望AI能够更加友好易用，减少学习成本。"
    ],
    "中学生": [
        "AI系统的响应在作业辅导方面很有用，但在复杂问题上有时需要更详细的解释。",
        "AI通常能理解我的需求，但在解答难题时有时需要更深入的知识。",
        "我希望AI能够更好地支持家庭作业辅导和学习资源推荐。"
    ],
    "家庭主妇/主夫": [
        "AI系统的响应在日常家务管理方面很有帮助，但在食谱建议上有时需要更个性化的选择。",
        "AI通常能理解我的需求，但在处理家居事务时有时需要更具体的指令。",
        "我希望AI能够更好地支持家务安排和购物清单管理。"
    ],
    "老年人": [
        "AI系统的响应有时符合我的期望，但在使用时需要更多的耐心。",
        "AI有时能理解我的需求，但在处理简单的查询时有时需要更清晰的指示。",
        "我希望AI能够更加简洁明了，减少复杂的操作步骤。"
    ],
    "残障人士": [
        "AI系统的响应在辅助生活方面很有帮助，但在特定需求上有时需要更细致的服务。",
        "AI通常能理解我的需求，但在处理特殊辅助需求时有时需要更专业的支持。",
        "我希望AI能够更好地支持无障碍功能，如语音识别和屏幕阅读器。"
    ],
    "零售店员": [
        "AI系统的响应在库存管理方面很有帮助，但在处理订单时有时需要更明确的指导。",
        "AI通常能理解我的需求，但在处理顾客查询时有时需要更具体的回答。",
        "我希望AI能够更好地支持库存查询和客户咨询服务。"
    ],
    "非技术工作者": [
        "AI系统的响应有时符合我的期望，但在日常工作中还需要更简单的操作指南。",
        "AI有时能理解我的需求，但在处理简单任务时有时需要更直接的解决方案。",
        "我希望AI能够更加直观易用，减少技术门槛。"
    ],
    "自由职业者": [
        "AI系统的响应在项目管理方面很有帮助，但在处理复杂任务时有时需要更灵活的选项。",
        "AI通常能理解我的需求，但在处理项目规划时有时需要更专业的建议。",
        "我希望AI能够更好地支持时间管理和任务分配。"
    ],
    "游戏爱好者": [
        "AI系统的响应在游戏攻略方面很有帮助，但在游戏内帮助上有时需要更详细的指导。",
        "AI通常能理解我的需求，但在处理游戏内问题时有时需要更具体的解答。",
        "我希望AI能够更好地支持游戏内提示和成就追踪。"
    ],
    "退休人员": [
        "AI系统的响应有时符合我的期望，但在使用过程中还需要更多的指导。",
        "AI有时能理解我的需求，但在处理简单任务时有时需要更简单的说明。",
        "我希望AI能够更加简洁明了，减少不必要的复杂性。"
    ]
}
Q["Question_1"]["responses_qwen"]=responses_qwen

# %% [markdown]
# Coze

# %%
responses_doubao={
    "人机交互研究员": [
        "我致力于人机交互研究，期望AI系统响应能深度契合用户的自然行为模式，实现无障碍交流。",
        "使用中，AI对复杂行为意图的理解准确性不够，尤其在多任务场景下。",
        "希望AI系统增加对用户行为模式的动态学习和自适应能力。"
    ],
    "交互设计专家": [
        "身为交互设计专家，期待AI系统响应带来极具创意和舒适的交互体验。",
        "但AI在处理特殊情境下的交互需求时，理解不够全面和细腻。",
        "希望AI系统能更好地融合多元文化元素，提升个性化交互水平。"
    ],
    "计算机科学教授": [
        "以计算机科学教授的眼光，希望AI系统响应具备顶尖的科学计算和逻辑推理能力。",
        "然而，AI在处理一些前沿科学问题的需求理解上，深度和广度不足。",
        "期望AI系统能紧跟学术前沿，强化复杂科学问题的处理能力。"
    ],
    "人工智能研究员": [
        "作为人工智能研究员，期待AI系统响应在复杂任务中展现出卓越的智能表现。",
        "但在跨领域复杂需求方面，AI的理解准确性和全面性有待提高。",
        "希望AI系统加强跨领域知识融合，提升应对复杂需求的能力。"
    ],
    "认知科学专家": [
        "从认知科学角度，期望AI系统响应符合人类认知规律，提供自然流畅的交互。",
        "但AI在模拟人类复杂认知和情感过程时，还不够精准。",
        "希望AI系统能深度融入认知科学成果，优化对用户需求的理解。"
    ],
    "社会学研究员": [
        "身为社会学研究员，期望AI系统响应充分考虑社会文化背景和群体差异。",
        "但在实际中，AI对社会因素影响下的需求理解不够深入。",
        "希望AI系统能建立更完善的社会模型，提升对社会需求的适应性。"
    ],
    "虚拟现实专家": [
        "作为虚拟现实专家，期待AI系统在虚拟环境中响应创造超逼真体验。",
        "然而，AI对虚拟场景中复杂需求的理解和响应尚有不足。",
        "希望AI系统增强在虚拟现实中的环境感知和交互能力。"
    ],
    "技术伦理学家": [
        "作为技术伦理学家，期望AI系统响应始终遵循伦理原则，确保安全可靠。",
        "但在一些复杂伦理情境中，AI对需求的理解和判断不够成熟。",
        "希望AI系统构建更完善的伦理评估体系，保障响应符合道德规范。"
    ],
    "用户体验研究员": [
        "身为用户体验研究员，期待AI系统响应能带给用户极致的满意和舒适。",
        "但AI在捕捉用户细微的情感和潜在需求时，表现不够出色。",
        "希望AI系统加强情感分析和潜在需求挖掘，提升用户体验。"
    ],
    "人机交互技术顾问": [
        "作为人机交互技术顾问，期望AI系统响应为业务带来显著的效率提升。",
        "但在面对复杂多变的业务需求时，AI的理解和响应存在差距。",
        "希望AI系统能深度融合业务场景，提供更精准有效的解决方案。"
    ],
    "软件开发者": [
        "作为软件开发者，期望AI系统响应能大幅提高开发效率和质量。",
        "但AI在处理复杂的代码逻辑和创新需求时，理解不够到位。",
        "希望AI系统能增强代码生成和优化能力，提供更创新的开发思路。"
    ],
    "UX/UI设计师": [
        "身为UX/UI设计师，期待AI系统响应能激发更多独特的设计灵感。",
        "但AI在理解前沿的设计趋势和用户个性化需求时，尚有不足。",
        "希望AI系统能紧跟设计潮流，提供更具前瞻性的设计建议。"
    ],
    "产品经理": [
        "作为产品经理，期望AI系统响应能助力精准的产品定位和决策。",
        "但AI在预测市场动态和新兴用户需求方面，准确性有待提高。",
        "希望AI系统能融合更多市场数据，提供更精准的市场分析。"
    ],
    "技术支持工程师": [
        "作为技术支持工程师，期望AI系统响应能快速解决各种技术难题。",
        "但AI在处理罕见和复杂的技术故障时，理解和解决方案不够完善。",
        "希望AI系统能积累更多故障案例，提升诊断和解决能力。"
    ],
    "系统管理员": [
        "身为系统管理员，期望AI系统响应能保障系统的稳定高效运行。",
        "但AI在应对特殊的系统配置和优化需求时，表现不够灵活。",
        "希望AI系统能适应多样的系统环境，提供更个性化的优化策略。"
    ],
    "数据分析师": [
        "作为数据分析师，期望AI系统响应能提供深入且精准的数据分析。",
        "但AI在处理多源异构和复杂关联的数据需求时，能力有待加强。",
        "希望AI系统能提升数据融合和洞察能力，提供更有价值的分析报告。"
    ],
    "内容创作者": [
        "身为内容创作者，期待AI系统响应能激发更多创意和丰富素材。",
        "但AI在理解特定风格和深度的内容创作需求时，不够精准。",
        "希望AI系统能学习更多专业知识，提供更优质的创作辅助。"
    ],
    "教育技术专家": [
        "作为教育技术专家，期望AI系统响应能显著提升教育效果。",
        "但AI在满足个性化教育需求和应对复杂教学场景时，还有差距。",
        "希望AI系统能结合更多教育理论，提供更智能的教育支持。"
    ],
    "游戏开发者": [
        "作为游戏开发者，期待AI系统响应能为游戏增添更多趣味和挑战。",
        "但AI在理解玩家深层次的游戏体验需求和创新玩法时，存在不足。",
        "希望AI系统能加强玩家行为分析，提供更具吸引力的游戏设计。"
    ],
    "数字营销专员": [
        "身为数字营销专员，期望AI系统响应能精准定位目标客户和提升营销效果。",
        "但AI在捕捉潜在客户的细微需求和市场变化时，不够敏锐。",
        "希望AI系统能整合更多营销数据，提供更精准的营销策略。"
    ],
    "普通消费者": [
        "作为普通消费者，期望AI系统响应能简便易用，满足日常生活需求。",
        "但AI有时不能准确理解我在购物和生活服务方面的具体要求。",
        "希望AI系统能更好地了解我的消费习惯，提供更贴心的推荐和服务。"
    ],
    "中学生": [
        "AI系统的响应在作业辅导方面很有用，但在复杂问题上有时需要更详细的解释。",
        "AI通常能理解我的需求，但在解答难题时有时需要更深入的知识。",
        "我希望AI能够更好地支持家庭作业辅导和学习资源推荐。"
    ],
    "家庭主妇/主夫": [
        "作为家庭主妇/主夫，期望AI系统响应能协助处理家务和购物决策。",
        "但AI在理解家庭特殊需求和预算限制方面，不够精准。",
        "希望AI系统能提供更多实用的家居管理和经济实惠的购物建议。"
    ],
    "老年人": [
        "作为老年人，期望AI系统响应操作简单便捷，服务贴心周到。",
        "但AI对我们的操作习惯和特殊需求理解不够，界面不够友好。",
        "希望AI系统能增加大字体、语音引导和简单易懂的操作说明。"
    ],
    "残障人士": [
        "作为残障人士，期望AI系统响应能充分考虑特殊需求，提供无障碍服务。",
        "但AI在适应特殊操作方式和辅助功能方面，还有待完善。",
        "希望AI系统能加强个性化定制，提供更贴合残障人士需求的功能。"
    ],
    "零售店员": [
        "作为零售店员，期望AI系统响应能提升销售效率和客户服务质量。",
        "但AI在理解顾客个性化需求和库存管理的复杂情况时，表现欠佳。",
        "希望AI系统能提供更精准的顾客分析和库存优化建议。"
    ],
    "非技术工作者": [
        "作为非技术工作者，期望AI系统响应简单易懂，能解决工作中的常见问题。",
        "但AI在处理非技术领域的特定需求时，理解不够准确。",
        "希望AI系统能更贴近实际工作场景，提供实用的解决方案。"
    ],
    "自由职业者": [
        "作为自由职业者，期望AI系统响应能有效管理时间和资源。",
        "但AI在理解自由职业的特殊工作模式和需求时，不够全面。",
        "希望AI系统能提供更灵活的项目管理和财务规划支持。"
    ],
    "游戏爱好者": [
        "作为游戏爱好者，期望AI系统响应能让游戏体验更精彩刺激。",
        "但AI在理解玩家独特的游戏偏好和策略需求时，不够到位。",
        "希望AI系统能增加更多个性化游戏设置和策略指导。"
    ],
    "退休人员": [
        "作为退休人员，期望AI系统响应能丰富休闲生活和提供便捷服务。",
        "但AI在满足养老、健康和娱乐等特殊需求时，内容不够丰富。",
        "希望AI系统能提供更多养生保健知识和兴趣活动推荐。"
    ]
}
Q["Question_1"]["responses_doubao"]=responses_doubao

# %%
response_qwen2 = {
     "人机交互研究员": [
        "AI系统的响应大多时候符合我的期望，特别是在任务明确的情况下。但在处理隐含的意图时，AI的表现还不够理想。",
        "总体来说，AI能够理解我的需求，但在处理复杂语境和非言语线索时会显得力不从心。",
        "我希望AI能更好地理解自然语言中的隐喻和抽象概念，提升对话的流畅性和自然度。"
    ],
    "交互设计专家": [
        "AI系统的响应大多数情况下是符合预期的，尤其是在用户界面友好的情况下。但有时在处理模糊指令时显得有些笨拙。",
        "AI对我的需求理解比较准确，但仍需要改进在多步骤任务中的表现。特别是在处理连续对话时，AI需要更好地记住上下文。",
        "我希望AI能够更好地处理多模态输入，比如语音和手势的结合，以增强用户体验。"
    ],
    "计算机科学教授": [
        "AI系统的响应通常非常准确，但也有一些边缘情况下的挑战。特别是在涉及到理论与实践相结合的场景中。",
        "在大多数情况下，AI能很好地理解我的需求，但仍有改进的空间。特别是在需要深入解析算法原理时。",
        "我希望能看到更多关于AI透明度和可解释性的功能，这对教学很有帮助。"
    ],
    "人工智能研究员": [
        "AI系统的响应在大多数情况下都能达到我的期望，尤其是在学术研究领域。但在理论探讨方面有时会缺乏深度。",
        "AI通常能准确地理解我的需求，但还有一些细微差别需要进一步改善。特别是在处理多模态数据融合时。",
        "我希望能够有更多定制化的训练选项，以便更精细地调教AI的行为。"
    ],
    "认知科学专家": [
        "AI系统的响应在认知任务方面表现良好，但在理解和模拟人类思维方面仍有差距。特别是在处理复杂的情感表达时。",
        "AI对我的需求理解还算准确，但在处理模糊概念时会遇到困难。特别是在需要推断上下文意义的情境下。",
        "我希望AI能更好地模拟人类的思考过程，包括情感和社会认知。"
    ],
    "社会学研究员": [
        "AI系统的响应在数据分析方面很好，但在社会情境的理解上有待加强。特别是在处理跨文化交流时。",
        "AI能理解我的大部分需求，但在复杂的社会议题上有时不够深入。特别是在需要考虑历史背景的情况下。",
        "我希望能够有更多的文化适应性和敏感性设置，以更好地服务于全球用户。"
    ],
    "虚拟现实专家": [
        "AI在虚拟环境中的表现令人满意，但在某些交互细节上还可以做得更好。特别是在需要精确控制时。",
        "AI通常能准确理解我在虚拟环境中的需求，但在复杂场景中需要更多的上下文理解。特别是在处理虚拟物体交互时。",
        "我希望AI能够更好地支持空间感知和环境适应性，以增强沉浸感。"
    ],
    "技术伦理学家": [
        "AI系统的响应在道德和伦理问题上的表现参差不齐。特别是在需要权衡利益冲突时。",
        "AI对我的需求理解尚可，但在涉及伦理决策时需要更谨慎。特别是在处理隐私保护问题时。",
        "我希望AI能有更强的道德判断能力和对隐私保护的关注。"
    ],
    "用户体验研究员": [
        "AI系统的响应通常符合我的期望，但在特定情境下还需要优化。特别是在需要快速迭代设计时。",
        "AI对我的需求理解比较准确，但在个性化体验方面有待提高。特别是在处理用户情感反馈时。",
        "我希望AI能够提供更个性化的建议和服务，以增强用户的参与度。"
    ],
    "人机交互技术顾问": [
        "AI系统的响应在大多数情况下是符合期望的，但有时缺乏灵活性。特别是在需要快速调整策略时。",
        "AI对我的需求理解准确，但在处理复杂命令时有时需要更智能的方法。特别是在需要理解用户意图时。",
        "我希望AI能更好地支持多语言和方言识别，以扩大用户群体。"
    ],
     "软件开发者": [
        "AI系统的响应在编程帮助方面非常有用，但有时需要更具体的上下文。特别是在处理特定框架的问题时。",
        "AI通常能理解我的需求，但在代码审查和调试方面还需要改进。特别是在需要深入理解业务逻辑时。",
        "我希望AI能够更好地支持代码生成和重构，以提高开发效率。"
    ],
    "UX/UI设计师": [
        "AI系统的响应在设计灵感和反馈方面很有帮助，但在具体实现上还需努力。特别是在需要创新的设计方案时。",
        "AI对我的需求理解准确，但在设计细节上有时需要更专业的指导。特别是在需要遵循严格的设计规范时。",
        "我希望AI能够更好地支持设计元素的自动布局和风格转换。"
    ],
    "产品经理": [
        "AI系统的响应在市场分析方面很有帮助，但在战略规划上还需加强。特别是在需要预测未来趋势时。",
        "AI通常能理解我的需求，但在预测市场趋势时有时需要更准确的数据。特别是在需要分析竞争对手时。",
        "我希望AI能够更好地支持竞品分析和用户反馈的自动化收集。"
    ],
    "技术支持工程师": [
        "AI系统的响应在故障排除方面非常有用，但有时需要更详细的说明。特别是在处理硬件问题时。",
        "AI对我的需求理解准确，但在处理复杂的技术问题时需要更专业的知识。特别是在需要深入分析日志时。",
        "我希望AI能够更好地支持故障诊断和自动修复流程。"
    ],
    "系统管理员": [
        "AI系统的响应在监控和维护方面很有帮助，但有时需要更具体的指令。特别是在需要快速定位问题时。",
        "AI通常能理解我的需求，但在处理网络配置时有时需要更深入的知识。特别是在需要配置复杂的防火墙规则时。",
        "我希望AI能够更好地支持自动化运维任务，如备份和安全检查。"
    ],
    "数据分析师": [
        "AI系统的响应在数据分析方面非常有效，但在解释复杂模型时需要更清晰。特别是在需要解释机器学习模型时。",
        "AI对我的需求理解准确，但在解释统计结果时有时需要更详细的说明。特别是在需要处理异常值时。",
        "我希望AI能够更好地支持高级数据分析工具的集成。"
    ],
    "内容创作者": [
        "AI系统的响应在创作灵感方面很有帮助，但在创造性写作上还需努力。特别是在需要编写长篇故事时。",
        "AI通常能理解我的需求，但在生成高质量文章时有时需要更深入的思考。特别是在需要处理主题思想时。",
        "我希望AI能够更好地支持文本生成和编辑，以提高创作效率。"
    ],
    "教育技术专家": [
        "AI系统的响应在教育资源推荐方面很有用，但在课程设计上还需加强。特别是在需要创建互动式课程时。",
        "AI对我的需求理解准确，但在个性化学习路径规划方面需要更多的创新。特别是在需要考虑学生差异时。",
        "我希望AI能够更好地支持学习进度跟踪和评估反馈。"
    ],
    "游戏开发者": [
        "AI系统的响应在游戏设计方面非常有用，但在关卡设计上还需努力。特别是在需要创造富有挑战性的谜题时。",
        "AI通常能理解我的需求，但在生成游戏内资源时有时需要更具体的指引。特别是在需要设计角色动作时。",
        "我希望AI能够更好地支持游戏内智能NPC的行为设计。"
    ],
    "数字营销专员": [
        "AI系统的响应在广告投放方面很有帮助，但在内容创作上还需加强。特别是在需要撰写吸引人的广告文案时。",
        "AI通常能理解我的需求，但在创意广告策划上有时需要更专业的建议。特别是在需要分析受众心理时。",
        "我希望AI能够更好地支持社交媒体互动和用户行为分析。"
    ],
     "普通消费者": [
        "AI系统的响应有时符合我的期望，但在日常使用中还需要更多的实践。特别是在需要快速获取信息时。",
        "AI有时能理解我的需求，但在处理简单查询时有时需要更直接的回应。特别是在需要查找特定产品信息时。",
        "我希望AI能够更加友好易用，减少学习成本。"
    ],
    "中学生": [
        "AI系统的响应在作业辅导方面很有用，但在复杂问题上有时需要更详细的解释。特别是在需要理解数学公式时。",
        "AI通常能理解我的需求，但在解答难题时有时需要更深入的知识。特别是在需要理解文学作品时。",
        "我希望AI能够更好地支持家庭作业辅导和学习资源推荐。"
    ],
    "家庭主妇/主夫": [
        "AI系统的响应在日常家务管理方面很有帮助，但在食谱建议上有时需要更个性化的选择。特别是在需要考虑饮食限制时。",
        "AI通常能理解我的需求，但在处理家居事务时有时需要更具体的指令。特别是在需要组织家庭活动时。",
        "我希望AI能够更好地支持家务安排和购物清单管理。"
    ],
    "老年人": [
        "AI系统的响应有时符合我的期望，但在使用时需要更多的耐心。特别是在需要设置设备时。",
        "AI有时能理解我的需求，但在处理简单的查询时有时需要更清晰的指示。特别是在需要了解新功能时。",
        "我希望AI能够更加简洁明了，减少复杂的操作步骤。"
    ],
    "残障人士": [
        "AI系统的响应在辅助生活方面很有帮助，但在特定需求上有时需要更细致的服务。特别是在需要紧急求助时。",
        "AI通常能理解我的需求，但在处理特殊辅助需求时有时需要更专业的支持。特别是在需要无障碍浏览时。",
        "我希望AI能够更好地支持无障碍功能，如语音识别和屏幕阅读器。"
    ],
    "零售店员": [
        "AI系统的响应在库存管理方面很有帮助，但在处理订单时有时需要更明确的指导。特别是在需要处理退货时。",
        "AI通常能理解我的需求，但在处理顾客查询时有时需要更具体的回答。特别是在需要解释促销活动时。",
        "我希望AI能够更好地支持库存查询和客户咨询服务。"
    ],
    "非技术工作者": [
        "AI系统的响应有时符合我的期望，但在日常工作中还需要更简单的操作指南。特别是在需要使用办公软件时。",
        "AI有时能理解我的需求，但在处理简单任务时有时需要更直接的解决方案。特别是在需要填写表格时。",
        "我希望AI能够更加直观易用，减少技术门槛。"
    ],
    "自由职业者": [
        "AI系统的响应在项目管理方面很有帮助，但在处理复杂任务时有时需要更灵活的选项。特别是在需要跟踪时间时。",
        "AI通常能理解我的需求，但在处理项目规划时有时需要更专业的建议。特别是在需要估算工作量时。",
        "我希望AI能够更好地支持时间管理和任务分配。"
    ],
    "游戏爱好者": [
        "AI系统的响应在游戏攻略方面很有帮助，但在游戏内帮助上有时需要更详细的指导。特别是在需要掌握游戏机制时。",
        "AI通常能理解我的需求，但在处理游戏内问题时有时需要更具体的解答。特别是在需要解锁成就时。",
        "我希望AI能够更好地支持游戏内提示和成就追踪。"
    ],
    "退休人员": [
        "AI系统的响应有时符合我的期望，但在使用过程中还需要更多的指导。特别是在需要使用智能手机时。",
        "AI有时能理解我的需求，但在处理简单任务时有时需要更简单的说明。特别是在需要预约医生时。",
        "我希望AI能够更加简洁明了，减少不必要的复杂性。"
    ]
}
Q["Question_1"]["response_qwen2"]=response_qwen2

# %%
occupations = [
    # 高专业程度 (Advanced) - 5
    "人机交互研究员", "交互设计专家", "计算机科学教授", "人工智能研究员", "认知科学专家",
    "社会学研究员", "虚拟现实专家", "技术伦理学家", "用户体验研究员", "人机交互技术顾问",

    # 中等专业程度 (Intermediate) - 3
    "软件开发者", "UX/UI设计师", "产品经理", "技术支持工程师", "系统管理员",
    "数据分析师", "内容创作者", "教育技术专家", "游戏开发者", "数字营销专员",

    # 低专业程度 (Beginner) - 1
    "普通消费者", "中学生", "家庭主妇/主夫", "老年人", "残障人士",
    "零售店员", "非技术工作者", "自由职业者", "游戏爱好者", "退休人员"
]


print(Q.keys())
print(Q['Question_1'].keys())
print(Q['Question_1']['Question_1'])
print(Q['Question_1']['questions_1'])
print(Q['Question_1']['responses_chatglm'].keys())
print(Q['Question_1']['responses_chatglm']['软件开发者'])
#'responses_qwen', 'responses_doubao', 'response_qwen2'和responses_chatglm中格式一致
# Out:
# dict_keys(['Question_1'])
# dict_keys(['Question_1', 'questions_1', 'responses_chatglm', 'responses_qwen', 'responses_doubao', 'response_qwen2'])
# (AI Response Expectations) AI系统的响应是否符合你的期望？(AI Understanding Accuracy) 在使用AI系统时，你是否感到AI对你的需求理解准确？(Desired AI Features) 你希望AI系统增加哪些功能来提高用户体验？
# ['AI系统的响应是否符合你的期望？', '在使用AI系统时，你是否感到AI对你的需求理解准确？', '你希望AI系统增加哪些功能来提高用户体验？']
# dict_keys(['人机交互研究员', '交互设计专家', '计算机科学教授', '人工智能研究员', '认知科学专家', '社会学研究员', '虚拟现实专家', '技术伦理学家', '用户体验研究员', '人机交互技术顾问', '软件开发者', 'UX/UI设计师', '产品经理', '技术支持工程师', '系统管理员', '数据分析师', '内容创作者', '教育技术专家', '游戏开发者', '数字营销专员', '普通消费者', '中学生', '家庭主妇/主夫', '老年人', '残障人士', '零售店员', '非技术工作者', '自由职业者', '游戏爱好者', '退休人员'])
# ['AI系统的响应在编程辅助和代码优化上基本符合我的期望，但在理解复杂项目需求上有所欠缺。', 'AI对我的需求理解一般，特别是在处理特定编程语言和环境的问题上。', '我希望AI系统能够提供更强大的代码分析和自动化测试功能。']

# %%
import json
# 指定要保存的 JSON 文件名
filename = 'Question_1_data.json'

# 将字典写入 JSON 文件
with open(filename, 'w') as f:
    json.dump(Q, f, indent=4)

# %%
from datetime import datetime

# 获取当前时间
current_time = datetime.now()

# 打印当前时间
print(current_time.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2024-08-06 20:50:33
