# %% [markdown]
# ChatGLM

# %%
Q={}
Question_2 = "(User Preferences) 当前输入设备是否符合你的操作习惯？(Usability Challenges) 你在使用输入设备时是否遇到过任何不便？(Design Improvements) 你希望输入设备在设计上有哪些改进？"
questions_2 = [
    "当前输入设备是否符合你的操作习惯？",
    "你在使用输入设备时是否遇到过任何不便？",
    "你希望输入设备在设计上有哪些改进？"
]
responses_chatglm = answers = {
    # 高专业程度 (Advanced) - 5
     "人机交互研究员": [
        "当前输入设备基本符合我的操作习惯，但在复杂交互场景中的自然语言处理方面还有提升空间。",
        "我在使用输入设备时遇到了一些手势与功能匹配不准确的问题。",
        "我希望输入设备能够提供更精准的手势识别和更丰富的交互方式。"
    ],
    "交互设计专家": [
        "当前输入设备在设计上符合我的操作习惯，但在多任务处理时有些不便。",
        "我在使用输入设备时遇到了一些界面元素位置和布局上的问题。",
        "我希望输入设备能够提供更加灵活和可自定义的界面布局。"
    ],
    "计算机科学教授": [
        "当前输入设备符合我的操作习惯，但在教学演示时，有时输入响应不够迅速。",
        "我在使用输入设备时遇到了一些输入延迟和系统响应不一致的问题。",
        "我希望输入设备能够提供更快的输入响应和更稳定的系统性能。"
    ],
    "人工智能研究员": [
        "当前输入设备符合我的操作习惯，但在数据输入和处理时，有时会遇到效率问题。",
        "我在使用输入设备时遇到了一些输入设备与工作流程不匹配的问题。",
        "我希望输入设备能够提供更加高效的数据输入和处理功能。"
    ],
    "认知科学专家": [
        "当前输入设备符合我的操作习惯，但在模拟复杂认知任务时，交互体验还有待提升。",
        "我在使用输入设备时遇到了一些交互体验不够自然和直观的问题。",
        "我希望输入设备能够提供更加自然和直观的交互方式。"
    ],
    "社会学研究员": [
        "当前输入设备符合我的操作习惯，但在数据分析时，输入设备的响应速度有些慢。",
        "我在使用输入设备时遇到了一些输入设备与数据分析软件集成不够紧密的问题。",
        "我希望输入设备能够提供更加快速的响应和更好的软件集成。"
    ],
    "虚拟现实专家": [
        "当前输入设备基本符合我的操作习惯，但在虚拟现实应用中，手柄的舒适度有待提高。",
        "我在使用输入设备时遇到了一些手柄操作与虚拟环境不匹配的问题。",
        "我希望输入设备能够提供更加舒适和精准的虚拟现实交互体验。"
    ],
    "技术伦理学家": [
        "当前输入设备符合我的操作习惯，但在处理敏感数据时，输入设备的安全性有待提高。",
        "我在使用输入设备时遇到了一些输入设备在处理敏感数据时的安全漏洞。",
        "我希望输入设备能够提供更加安全和可靠的数据处理功能。"
    ],
    "用户体验研究员": [
        "当前输入设备基本符合我的操作习惯，但在用户研究中，输入设备的可用性有待提升。",
        "我在使用输入设备时遇到了一些输入设备在用户研究中不够直观和易用的问题。",
        "我希望输入设备能够提供更加直观和易用的用户研究工具。"
    ],
    "人机交互技术顾问": [
        "当前输入设备符合我的操作习惯，但在定制化解决方案时，输入设备的灵活性有待提高。",
        "我在使用输入设备时遇到了一些输入设备在定制化解决方案中的限制。",
        "我希望输入设备能够提供更加灵活和可定制的解决方案。"
    ],

    # 中等专业程度 (Intermediate) - 3
    "软件开发者": [
        "当前输入设备基本符合我的操作习惯，但在开发复杂项目时，输入设备的响应速度有些慢。",
        "我在使用输入设备时遇到了一些输入设备在处理复杂项目需求时的效率问题。",
        "我希望输入设备能够提供更加快速和高效的开发工具。"
    ],
    "UX/UI设计师": [
        "当前输入设备在设计上符合我的操作习惯，但在设计创新时，输入设备的创意辅助功能还有待提升。",
        "我在使用输入设备时遇到了一些输入设备在设计创新方面的限制。",
        "我希望输入设备能够提供更加创新和灵活的设计工具。"
    ],
    "产品经理": [
        "当前输入设备在产品规划上符合我的操作习惯，但在市场分析时，输入设备的实时数据处理功能还有待提升。",
        "我在使用输入设备时遇到了一些输入设备在市场分析中的实时数据处理问题。",
        "我希望输入设备能够提供更加实时和高效的市场分析工具。"
    ],
    "技术支持工程师": [
        "当前输入设备在解决技术问题上基本符合我的操作习惯，但在处理紧急情况时反应不够迅速。",
        "我在使用输入设备时遇到了一些输入设备在处理紧急情况时的响应问题。",
        "我希望输入设备能够提供更快捷的技术支持，以提高用户满意度。"
    ],
    "系统管理员": [
        "当前输入设备在系统维护和更新上基本符合我的操作习惯，但在处理突发问题时反应不够迅速。",
        "我在使用输入设备时遇到了一些输入设备在处理突发情况时的响应问题。",
        "我希望输入设备能够提供更快捷的系统监控和故障预警功能。"
    ],
    "数据分析师": [
        "当前输入设备在数据处理和分析上基本符合我的操作习惯，但在处理大数据集时效率有待提高。",
        "我在使用输入设备时遇到了一些输入设备在处理大数据集时的效率问题。",
        "我希望输入设备能够提供更加高效的大数据分析工具和预测模型。"
    ],
    "内容创作者": [
        "当前输入设备在内容创作辅助上基本符合我的操作习惯，但在处理创意和个性化内容时表现不足。",
        "我在使用输入设备时遇到了一些输入设备在处理创意和个性化内容时的限制。",
        "我希望输入设备能够提供更加强大的内容创作工具和个性化推荐功能。"
    ],
    "教育技术专家": [
        "当前输入设备在教育辅助上基本符合我的操作习惯，但在处理复杂教育问题时表现不足。",
        "我在使用输入设备时遇到了一些输入设备在处理复杂教育问题时的限制。",
        "我希望输入设备能够提供更加灵活的教育辅助工具和个性化学习方案。"
    ],
    "游戏开发者": [
        "当前输入设备在游戏开发辅助上基本符合我的操作习惯，但在处理复杂游戏逻辑和AI设计时表现不足。",
        "我在使用输入设备时遇到了一些输入设备在处理复杂游戏逻辑和AI设计时的限制。",
        "我希望输入设备能够提供更加强大的游戏开发工具和AI优化功能。"
    ],
    "数字营销专员": [
        "当前输入设备在数字营销策略上基本符合我的操作习惯，但在处理实时营销数据和个性化营销上表现不足。",
        "我在使用输入设备时遇到了一些输入设备在处理实时营销数据和个性化营销时的限制。",
        "我希望输入设备能够提供更加实时的营销数据分析和个性化营销工具。"
    ],
    # 低金融素养角色答案
    "普通消费者": [
        "当前输入设备基本符合我的操作习惯，但在使用时，有时会遇到一些操作上的不便。",
        "我在使用输入设备时遇到了一些输入设备在操作上的不直观和复杂的问题。",
        "我希望输入设备能够提供更加简单易用的操作界面。"
    ],
    "中学生": [
        "当前输入设备基本符合我的操作习惯，但在学习时，有时会遇到一些操作上的不便。",
        "我在使用输入设备时遇到了一些输入设备在学习时的不直观和复杂的问题。",
        "我希望输入设备能够提供更加简单易用的操作界面。"
    ],
    "家庭主妇/主夫": [
        "当前输入设备基本符合我的操作习惯，但在日常家务管理时，有时会遇到一些操作上的不便。",
        "我在使用输入设备时遇到了一些输入设备在日常家务管理时的不直观和复杂的问题。",
        "我希望输入设备能够提供更加简单易用的操作界面。"
    ],
    "老年人": [
        "当前输入设备基本符合我的操作习惯，但在使用时，有时会遇到一些操作上的不便。",
        "我在使用输入设备时遇到了一些输入设备在操作上的不直观和复杂的问题。",
        "我希望输入设备能够提供更加简单易用的操作界面。"
    ],
    "残障人士": [
        "当前输入设备基本符合我的操作习惯，但在使用时，有时会遇到一些操作上的不便。",
        "我在使用输入设备时遇到了一些输入设备在操作上的不直观和复杂的问题。",
        "我希望输入设备能够提供更加简单易用的操作界面。"
    ],
    "零售店员": [
        "当前输入设备基本符合我的操作习惯，但在工作操作时，有时会遇到一些操作上的不便。",
        "我在使用输入设备时遇到了一些输入设备在工作操作时的不直观和复杂的问题。",
        "我希望输入设备能够提供更加简单易用的操作界面。"
    ],
    "非技术工作者": [
        "当前输入设备基本符合我的操作习惯，但在日常工作操作时，有时会遇到一些操作上的不便。",
        "我在使用输入设备时遇到了一些输入设备在日常操作时的不直观和复杂的问题。",
        "我希望输入设备能够提供更加简单易用的操作界面。"
    ],
    "自由职业者": [
        "当前输入设备基本符合我的操作习惯，但在工作操作时，有时会遇到一些操作上的不便。",
        "我在使用输入设备时遇到了一些输入设备在工作操作时的不直观和复杂的问题。",
        "我希望输入设备能够提供更加简单易用的操作界面。"
    ],
    "游戏爱好者": [
        "当前输入设备基本符合我的操作习惯，但在游戏操作时，有时会遇到一些操作上的不便。",
        "我在使用输入设备时遇到了一些输入设备在游戏操作时的不直观和复杂的问题。",
        "我希望输入设备能够提供更加简单易用的操作界面。"
    ],
    "退休人员": [
        "当前输入设备基本符合我的操作习惯，但在日常休闲活动时，有时会遇到一些操作上的不便。",
        "我在使用输入设备时遇到了一些输入设备在日常休闲活动时的不直观和复杂的问题。",
        "我希望输入设备能够提供更加简单易用的操作界面。"
    ]
}


Q["Question_2"]={"Question_2":Question_2, "questions_2":questions_2,"responses_chatglm":responses_chatglm}

# %% [markdown]
# Qwen

# %%
responses_qwen = {
    "人机交互研究员": [
        "我使用的输入设备一般都符合我的操作习惯，特别是那些支持自定义映射和宏命令的设备。不过，在处理复杂的多点触控手势时，偶尔会感觉不够直观。",
        "在我使用输入设备的过程中，最大的不便就是当设备不支持高精度的输入时，例如在进行精确的手势识别时会出现误差。",
        "我希望未来的输入设备能够在触觉反馈和手势识别方面有所改进，以提供更加自然和准确的交互体验。"
    ],
    "交互设计专家": [
        "我目前使用的输入设备总体上符合我的操作习惯，尤其是那些带有可编程按钮的设备。但在多模态输入方面，还有改进的空间。",
        "我遇到的主要不便是在一些特定的应用程序中，输入设备无法识别复杂的手势或表情。这限制了交互的多样性和丰富性。",
        "我期待输入设备能够支持更多的生物识别认证方式，如面部识别和虹膜扫描，以及更好的触觉反馈机制。"
    ],
    "计算机科学教授": [
        "我所使用的键盘和鼠标都非常符合我的操作习惯，特别是那些支持多种连接方式的无线设备。然而，在课堂演示时，设备的切换有时不太顺畅。",
        "我在使用输入设备时遇到的最大不便是在移动设备上进行精确的文本输入，特别是当需要快速打字时。",
        "我希望未来的输入设备能够在便携性和准确性之间找到更好的平衡，同时支持更多的连接协议，如蓝牙和Wi-Fi直连。"
    ],
    "人工智能研究员": [
        "我常用的输入设备基本上能满足我的需求，特别是那些能够通过语音命令进行交互的设备。不过，在处理大量数据时，手写输入的支持略显不足。",
        "我遇到的一个主要问题是当设备无法正确识别我的语音指令时，特别是在嘈杂的环境中。",
        "我希望输入设备能够增强语音识别的准确率，并支持更自然的语言处理能力，同时也希望增加对手写输入的支持。"
    ],
    "认知科学专家": [
        "我使用的输入设备通常都很符合我的习惯，特别是那些能够模拟自然输入方式的设备。然而，在进行长时间的研究工作时，手指疲劳是个问题。",
        "我遇到的不便主要是当设备在长时间使用后变得不那么灵敏，尤其是在触控屏上。",
        "我希望输入设备能够在人体工程学设计上做得更好，以减少长时间使用带来的疲劳，并且能够更加耐用。"
    ],
    "社会学研究员": [
        "我使用的输入设备很适合我的日常工作，特别是那些支持多种语言输入的设备。但是，在远程协作时，输入设备的兼容性问题有时会成为障碍。",
        "我遇到的主要不便是在使用不同的操作系统时，输入设备的驱动和设置不一致，导致操作习惯的变化。",
        "我希望未来的输入设备能够提供更好的跨平台兼容性，并且能够自动适应不同的操作系统环境。"
    ],
    "虚拟现实专家": [
        "我使用的输入设备非常适合VR环境，特别是那些支持手势识别的设备。但是，当我在复杂的虚拟环境中导航时，设备有时会反应迟钝。",
        "我在使用输入设备时遇到的最大不便是在虚拟现实中进行精细的操作时，设备的反馈不够及时。",
        "我希望输入设备能够提供更加精准的位置跟踪和更快的响应速度，同时支持更丰富的手势输入。"
    ],
    "技术伦理学家": [
        "我使用的输入设备通常符合我的习惯，特别是那些注重隐私保护的产品。但是在公共场合使用时，隐私泄露的风险仍然存在。",
        "我遇到的不便主要是在公共场所使用输入设备时，担心个人信息被旁观者窃取。",
        "我希望输入设备能够提供更强大的隐私保护措施，例如生物特征锁和加密功能，以防止未经授权的访问。"
    ],
    "用户体验研究员": [
        "我使用的输入设备非常符合我的习惯，尤其是那些可以根据用户行为动态调整的设备。但在某些情况下，设备的自适应能力还不足够。",
        "我在使用输入设备时遇到的主要不便是在不同场景间切换时，设备的适应性不足。",
        "我希望输入设备能够更好地适应不同的使用场景，并且能够自动调整到最合适的输入模式。"
    ],
    "人机交互技术顾问": [
        "我使用的输入设备总体上满足了我的需求，尤其是那些支持多种输入方式的设备。但在一些特定的专业应用中，设备的功能还有待增强。",
        "我在使用输入设备时遇到的最大不便是在专业软件中，设备的快捷键配置有时不那么直观。",
        "我希望输入设备能够提供更多的可编程按键选项，并且支持更广泛的软件兼容性。"
    ],
    "软件开发者": [
        "我使用的键盘和鼠标基本上符合我的习惯，特别是那些具有背光和宏功能的设备。但有时在长时间编码后，手腕会有不适。",
        "我在使用输入设备时遇到的最大不便是在多个显示器之间切换时，设备的响应不够迅速。",
        "我希望输入设备能够提供更好的人体工学设计，减少长时间使用造成的身体疲劳，并且能够支持更快速的显示器切换。"
    ],
    "UX/UI设计师": [
        "我使用的绘图板和触控笔很符合我的习惯，特别是那些支持压力感应的设备。但在使用平板电脑进行设计时，有时会感觉不够精确。",
        "我在使用输入设备时遇到的主要不便是在进行精细的图形设计时，设备的精度不足。",
        "我希望输入设备能够提供更高的精度，并且能够支持更自然的手写笔输入体验。"
    ],
    "产品经理": [
        "我使用的笔记本电脑和平板电脑通常符合我的习惯，特别是那些支持触控笔的设备。但在会议中使用时，设备的电池续航有时不足。",
        "我在使用输入设备时遇到的最大不便是在外出时，设备的电量不足以支撑一整天的工作。",
        "我希望输入设备能够提供更长的电池续航能力，并且支持快速充电功能。"
    ],
    "技术支持工程师": [
        "我使用的键盘和鼠标非常符合我的习惯，特别是那些具有额外功能键的设备。但在远程支持时，设备的连接稳定性有时会成为问题。",
        "我在使用输入设备时遇到的最大不便是在进行远程故障排除时，设备的延迟和不稳定连接。",
        "我希望输入设备能够提供更稳定的无线连接，并且支持远程桌面功能。"
    ],
    "系统管理员": [
        "我使用的输入设备总体上符合我的习惯，特别是那些支持多种接口的设备。但在服务器机房使用时，设备的耐用性有时会受到挑战。",
        "我在使用输入设备时遇到的主要不便是在服务器机房中，设备容易遭受灰尘污染。",
        "我希望输入设备能够提供更好的耐用性和防尘设计。"
    ],
    "数据分析师": [
        "我使用的键盘和鼠标符合我的习惯，特别是那些具有可编程宏的设备。但在处理大数据集时，设备的响应速度有时会变慢。",
        "我在使用输入设备时遇到的最大不便是在处理大量数据时，设备的性能不足。",
        "我希望输入设备能够提供更快的响应速度，并且支持更多的并行计算功能。"
    ],
    "内容创作者": [
        "我使用的键盘和触控板符合我的习惯，特别是那些支持多点触控手势的设备。但在视频编辑时，设备的精确度有时会降低。",
        "我在使用输入设备时遇到的主要不便是在进行视频剪辑时，设备的精确度不够。",
        "我希望输入设备能够提供更高的精确度，并且支持更多的自定义手势。"
    ],
    "教育技术专家": [
        "我使用的输入设备通常符合我的习惯，特别是那些支持触摸屏的设备。但在教室里使用时，设备的可视角度有时会影响观看效果。",
        "我在使用输入设备时遇到的最大不便是在大教室中，设备的显示效果不佳。",
        "我希望输入设备能够提供更宽广的可视角度，并且支持更明亮的显示效果。"
    ],
    "游戏开发者": [
        "我使用的键盘和鼠标非常符合我的习惯，特别是那些支持RGB灯光的设备。但在长时间使用后，手腕会感到疲劳。",
        "我在使用输入设备时遇到的主要不便是在长时间游戏测试后，设备的舒适度降低。",
        "我希望输入设备能够提供更好的人体工学设计，减少长时间使用造成的身体不适。"
    ],
    "数字营销专员": [
        "我使用的键盘和触控板符合我的习惯，特别是那些支持手势控制的设备。但在社交媒体管理时，设备的快捷键有时不够方便。",
        "我在使用输入设备时遇到的最大不便是在处理多个社交媒体账户时，设备的切换不够快速。",
        "我希望输入设备能够提供更多的快捷键选项，并且支持更快速的账户切换功能。"
    ],
    "普通消费者": [
        "我使用的鼠标和键盘基本符合我的习惯，但我有时会发现触控板的使用不如传统鼠标直观。",
        "我在使用输入设备时遇到的最大不便是在安装新设备时，经常找不到正确的驱动程序。",
        "我希望输入设备能够更加易于安装，并且能够提供更直观的使用教程。"
    ],
    "中学生": [
        "我使用的输入设备通常符合我的习惯，特别是那些具有简单快捷键的设备。但在使用平板电脑时，有时会感觉不够直观。",
        "我在使用输入设备时遇到的最大不便是在完成作业时，设备的响应速度有时较慢。",
        "我希望输入设备能够提供更快的响应速度，并且支持更多的自定义快捷键。"
    ],
    "家庭主妇/主夫": [
        "我使用的输入设备符合我的习惯，特别是那些支持语音输入的设备。但在做饭时，触摸屏的使用有时不太方便。",
        "我在使用输入设备时遇到的最大不便是在厨房里使用时，设备容易受到水溅。",
        "我希望输入设备能够提供更好的防水设计，并且支持更多的语音控制功能。"
    ],
    "老年人": [
        "我使用的输入设备通常符合我的习惯，特别是那些具有大字体的设备。但在使用智能手机时，有时会觉得触摸屏反应不够灵敏。",
        "我在使用输入设备时遇到的最大不便是在使用智能手机时，屏幕亮度有时不够。",
        "我希望输入设备能够提供更大的字体选项，并且支持更明亮的屏幕显示。"
    ],
    "残障人士": [
        "我使用的输入设备基本符合我的习惯，特别是那些支持辅助技术的设备。但在使用触控板时，有时会感觉不够精确。",
        "我在使用输入设备时遇到的最大不便是在进行精确操作时，设备的反馈不够明显。",
        "我希望输入设备能够提供更多的辅助功能，并且支持更大的触控区域。"
    ],
    "零售店员": [
        "我使用的条形码扫描器符合我的习惯，但在处理大量商品时，设备的扫描速度有时不够快。",
        "我在使用输入设备时遇到的最大不便是在高峰时段，设备的响应速度减慢。",
        "我希望输入设备能够提供更快的扫描速度，并且支持更远距离的无线连接。"
    ],
    "非技术工作者": [
        "我使用的键盘和鼠标符合我的习惯，但在使用办公软件时，设备的快捷键有时不够直观。",
        "我在使用输入设备时遇到的最大不便是在学习新软件时，设备的学习曲线较陡。",
        "我希望输入设备能够提供更直观的快捷键，并且支持更多的自定义选项。"
    ],
    "自由职业者": [
        "我使用的笔记本电脑和平板电脑符合我的习惯，但在远程工作时，设备的电池续航有时不足。",
        "我在使用输入设备时遇到的最大不便是在户外使用时，设备的屏幕反光严重。",
        "我希望输入设备能够提供更长的电池续航能力，并且支持更好的抗反射屏幕。"
    ],
    "游戏爱好者": [
        "我使用的键盘和鼠标符合我的习惯，特别是在玩游戏时。但在长时间游戏后，设备的温度有时过高。",
        "我在使用输入设备时遇到的最大不便是在进行激烈的游戏时，设备的散热不够。",
        "我希望输入设备能够提供更好的散热设计，并且支持更舒适的握持体验。"
    ],
    "退休人员": [
        "我使用的输入设备通常符合我的习惯，特别是那些具有大字体的设备。但在使用智能手机时，有时会觉得触摸屏反应不够灵敏。",
        "我在使用输入设备时遇到的最大不便是在使用智能手机时，屏幕亮度有时不够。",
        "我希望输入设备能够提供更大的字体选项，并且支持更明亮的屏幕显示。"
    ],

}
Q["Question_2"]["responses_qwen"]=responses_qwen

# %% [markdown]
# Coze

# %%
responses_doubao={
    "人机交互研究员": [
        "作为人机交互研究员，我认为当前的输入设备在一定程度上符合操作习惯，但仍有优化空间。对于常见的键盘和鼠标，其布局和功能基本能满足日常操作，但在一些特定场景下，如移动端的触摸操作，精准度和反馈还需提升。",
        "在使用输入设备时，遇到过诸如触摸屏幕的误触、键盘按键的触感不一致等不便。特别是在进行长时间连续输入时，设备的人体工程学设计不足可能导致手部疲劳。",
        "希望输入设备能更好地适应不同的操作场景，比如在户外强光下屏幕的显示效果能更佳。同时，设备的材质和形状应更符合人体工程学，减少长时间使用带来的疲劳。"
    ],
    "交互设计专家": [
        "身为交互设计专家，当前的输入设备与操作习惯的匹配度有待提高。部分设备的操作逻辑不够直观，增加了用户的学习成本。",
        "使用中常遇到输入方式不够自然流畅的问题，比如手写笔的识别准确率不稳定。而且，不同设备之间的操作连贯性欠佳。",
        "期望输入设备在设计上更注重用户的直觉操作，增强多设备间的无缝切换能力，并提升输入的准确性和响应速度。"
    ],
    "计算机科学教授": [
        "以计算机科学教授的角度看，当前输入设备基本符合操作习惯，但在处理复杂数据输入时，效率和便捷性有待改进。",
        "遇到过输入设备在处理大量数据时的卡顿和延迟问题，以及某些特殊符号的输入不便。",
        "希望输入设备能提升处理复杂任务的性能，优化特殊字符和快捷键的设置，以提高工作效率。"
    ],
    "人工智能研究员": [
        "作为人工智能研究员，当前输入设备对于常规操作习惯尚可，但在与智能系统交互时，不够智能和高效。",
        "使用时发现输入设备在与AI进行复杂指令输入时，理解和响应不够准确及时，影响研究进度。",
        "希望输入设备能更好地与人工智能系统融合，实现更自然和高效的交互，例如通过语音输入能更准确地传达复杂指令。"
    ],
    "认知科学专家": [
        "从认知科学角度，当前输入设备在符合人类操作习惯方面还有所欠缺，未能充分考虑人类认知特点。",
        "在使用中，感觉输入设备对人类认知负荷的考虑不足，导致长时间使用容易产生疲劳和错误。",
        "期望输入设备的设计能基于人类认知模型，减少认知负担，提高操作的准确性和舒适度。"
    ],
    "社会学研究员": [
        "身为社会学研究员，当前输入设备在满足不同社会群体操作习惯上存在差异，不够公平和包容。",
        "遇到过因设备设计未考虑特殊社会群体需求而导致的使用不便，如老年人或残障人士的操作困难。",
        "希望输入设备的设计能更具社会包容性，考虑不同群体的特点和需求，提供多样化的操作选择。"
    ],
    "虚拟现实专家": [
        "作为虚拟现实专家，当前输入设备在虚拟环境中的操作习惯匹配度较低，沉浸感和交互性不足。",
        "使用时，在虚拟场景中的输入精准度和反馈不够理想，影响体验效果。",
        "期待输入设备在虚拟现实中能提供更真实的触感和更精准的定位，增强沉浸感和交互的自然性。"
    ],
    "技术伦理学家": [
        "作为技术伦理学家，当前输入设备在伦理层面的考虑不足，如用户数据的采集和使用方式存在隐患。",
        "遇到过因设备收集过多个人数据而引发的隐私担忧，以及设备使用对社会伦理产生的潜在影响。",
        "希望输入设备在设计上遵循严格的伦理准则，保障用户隐私和权益，避免产生不良的社会伦理后果。"
    ],
    "用户体验研究员": [
        "身为用户体验研究员，当前输入设备在整体操作习惯上表现一般，部分细节影响用户满意度。",
        "使用中发现设备的按键布局不合理、触摸灵敏度不稳定等问题给用户带来不便。",
        "期望输入设备能在细节方面进行优化，如改善按键手感、提升触摸响应的一致性等，以提升用户体验。"
    ],
    "人机交互技术顾问": [
        "作为人机交互技术顾问，当前输入设备与用户操作习惯的契合度参差不齐，需要进一步优化。",
        "遇到过因设备兼容性问题导致的操作不便，以及在不同应用场景下的适应性不足。",
        "希望输入设备在通用性和场景适应性方面有所改进，同时提供更多个性化设置选项，满足不同用户的需求。"
    ],
    "软件开发者": [
        "作为软件开发者，当前输入设备对于编程等专业操作的习惯支持不够完善，影响开发效率。",
        "在进行代码输入时，快捷键设置不够灵活，特殊字符输入麻烦等问题时有出现。",
        "希望输入设备能针对软件开发需求提供更高效的快捷键配置和更便捷的代码输入方式。"
    ],
    "UX/UI设计师": [
        "身为UX/UI设计师，当前输入设备在设计创作过程中的操作习惯不够流畅，限制创意发挥。",
        "使用中，手绘板的压感精度和响应速度不够理想，影响设计效果。",
        "期望输入设备在绘图和创意表达方面提供更精准、更灵敏的支持，提升设计效率和质量。"
    ],
    "产品经理": [
        "作为产品经理，当前输入设备在满足多样化的用户需求和操作习惯上存在不足，影响产品规划。",
        "遇到过因设备功能单一或操作复杂导致用户抱怨，影响产品的市场竞争力。",
        "希望输入设备在功能集成和操作简化方面有所突破，以更好地满足不同用户群体的需求。"
    ],
    "技术支持工程师": [
        "作为技术支持工程师，当前输入设备在故障诊断和维护操作中的习惯适配性有待加强。",
        "使用时，在输入特定的诊断指令和参数时不够便捷，影响故障排除效率。",
        "希望输入设备能提供更便捷的专业工具集成和操作界面，提高技术支持工作的效率和准确性。"
    ],
    "系统管理员": [
        "身为系统管理员，当前输入设备在系统配置和管理操作中的习惯匹配度一般，增加工作负担。",
        "遇到过因设备对批量操作和复杂指令输入的支持不足，导致管理效率低下。",
        "期望输入设备能针对系统管理任务提供更高效的批量处理和复杂指令输入功能。"
    ],
    "数据分析师": [
        "作为数据分析师，当前输入设备在数据输入和分析操作习惯上存在不便，影响工作效率。",
        "使用中，数据输入的准确性和速度受到一定限制，特别是在处理大量数据时。",
        "希望输入设备能提供更高效的数据输入方式，如语音识别和智能数据填充，提高数据分析的效率和准确性。"
    ],
    "内容创作者": [
        "身为内容创作者，当前输入设备在文字创作和素材处理操作习惯上有待优化，影响创作灵感。",
        "遇到过输入设备在长时间创作时的舒适性问题，以及多媒体素材处理的便捷性不足。",
        "期望输入设备能在舒适性和多媒体处理能力方面有所提升，为内容创作提供更好的支持。"
    ],
    "教育技术专家": [
        "作为教育技术专家，当前输入设备在教育场景中的操作习惯适应性不足，影响教学效果。",
        "使用中，发现设备在课堂互动和学生操作方面存在不便，如学生端设备的操作复杂性。",
        "希望输入设备能针对教育环境提供更简单易用、互动性强的设计，提升教学效率和学生参与度。"
    ],
    "游戏开发者": [
        "作为游戏开发者，当前输入设备在游戏开发和测试操作习惯上存在局限，影响开发进度。",
        "遇到过输入设备在游戏操控模拟和测试数据输入方面的不准确和不便捷。",
        "希望输入设备能更好地支持游戏开发过程中的各种操作，提供更真实的游戏操控模拟和高效的数据输入方式。"
    ],
    "数字营销专员": [
        "身为数字营销专员，当前输入设备在数据收集和营销操作习惯上不够便捷，影响工作效率。",
        "使用中，发现输入设备在快速收集和整理市场数据方面存在不足，以及在多平台操作时的兼容性问题。",
        "期望输入设备能提供更高效的数据收集工具和更好的多平台兼容性，以适应数字营销的快节奏需求。"
    ],
    "普通消费者": [
        "作为普通消费者，当前输入设备基本能满足日常操作习惯，但在一些细节上还不够方便。",
        "使用时遇到过手机屏幕在湿手情况下操作不灵敏，键盘按键容易积灰等问题。",
        "希望输入设备更耐用、防尘防水，并且操作更简单易懂。"
    ],
    "中学生": [
        "作为中学生，觉得当前输入设备在学习使用中还可以，但有时不太顺手。",
        "比如在使用电子设备做笔记时，手写输入的识别速度有点慢。",
        "希望输入设备能更适合学习，比如有更好的护眼功能和更智能的学习辅助功能。"
    ],
    "家庭主妇/主夫": [
        "作为家庭主妇/主夫，当前输入设备在处理家务相关操作时不太方便。",
        "像在厨房操作智能设备时，手上有油污会导致触摸不灵。",
        "希望输入设备能防水防油，操作更简单快捷。"
    ],
    "老年人": [
        "作为老年人，当前输入设备用起来不太习惯，很多功能不会用。",
        "按键太小看不清，操作界面太复杂。",
        "希望输入设备的按键大一些，界面简单明了，有清晰的操作指引。"
    ],
    "残障人士": [
        "作为残障人士，当前输入设备很多时候不符合操作习惯，使用困难。",
        "比如对于手部活动不便的人，鼠标操作不方便。",
        "希望输入设备有更多针对残障人士的特殊设计，方便使用。"
    ],
    "零售店员": [
        "作为零售店员，当前输入设备在工作中的操作效率不高。",
        "扫码枪有时识别不准，键盘输入商品信息太慢。",
        "希望输入设备能提高扫码准确率和信息输入速度。"
    ],
    "非技术工作者": [
        "作为非技术工作者，当前输入设备有些复杂，不太容易上手。",
        "一些功能不知道怎么用，操作容易出错。",
        "希望输入设备更简单易用，有更直观的操作提示。"
    ],
    "自由职业者": [
        "作为自由职业者，当前输入设备在满足多样化工作需求时不够灵活。",
        "不同设备之间切换麻烦，数据同步不方便。",
        "希望输入设备能更好地支持多设备协同工作，数据同步更便捷。"
    ],
    "游戏爱好者": [
        "作为游戏爱好者，当前输入设备在游戏体验方面还有提升空间。",
        "游戏手柄的按键反馈不够好，响应速度有时跟不上。",
        "希望输入设备能有更出色的手感和更快的响应速度，提升游戏操作体验。"
    ],
    "退休人员": [
        "作为退休人员，当前输入设备用起来不太习惯，功能太多太复杂。",
        "操作步骤记不住，容易出错。",
        "希望输入设备功能简洁，操作容易，有专门针对老年人的简化模式。"
    ]
}
Q["Question_2"]["responses_doubao"]=responses_doubao

# %%
response_qwen2 = {
   # 高等专业水平角色
    "人机交互研究员": [
        "我使用的输入设备通常符合我的习惯，尤其是那些能够支持定制化操作流程的设备。然而，对于一些新型交互方式（如脑机接口），现有设备往往不能完全满足需求。",
        "我在使用输入设备时遇到的主要不便在于设备对新交互技术的支持不足，比如对眼球追踪或脑电波等信号的识别不够准确。",
        "我希望未来的输入设备能在新技术集成方面有所突破，比如提高对新兴交互信号的识别精度，或者开发全新的交互模式。"
    ],
    "交互设计专家": [
        "我使用的输入设备在大多数情况下都能很好地适应我的操作习惯，尤其是那些支持多模态交互的设备。但有时在进行设计迭代时，设备的灵活性稍显不足。",
        "我遇到的主要不便是在尝试快速原型设计时，设备的响应速度跟不上创意的产生速度。",
        "我期待输入设备能进一步提升交互速度和灵活性，比如实现更快的响应时间，以及支持更自然流畅的多模态交互。"
    ],
    "计算机科学教授": [
        "我使用的输入设备基本上符合我的操作习惯，特别是在编写代码和学术研究方面。但在课堂互动环节，有时设备的响应速度不够快。",
        "我遇到的主要不便是在进行在线教学时，设备的稳定性和网络连接质量难以保证。",
        "我希望输入设备能够提供更加稳定可靠的网络连接，并且支持更高效的互动工具，比如实时注释功能。"
    ],
    "人工智能研究员": [
        "我常用的输入设备基本上能满足我的需求，尤其是那些支持自然语言处理和语音识别的设备。但在处理大规模数据集时，设备的处理速度有待提高。",
        "我遇到的一个主要问题是当设备处理大量数据时，其运算速度明显下降。",
        "我希望输入设备能够支持更高效的数据处理算法，并且在硬件层面有更强的计算能力。"
    ],
    "认知科学专家": [
        "我使用的输入设备通常都很符合我的习惯，特别是那些能够模拟自然输入方式的设备。然而，在进行长时间的研究工作时，设备的人体工程学设计还有待加强。",
        "我遇到的不便主要是当长时间使用设备时，可能会出现手指或手腕疲劳。",
        "我希望输入设备能够在人体工程学设计上有所改进，比如采用更符合人体结构的设计，以减少长时间使用带来的身体不适。"
    ],
    "社会学研究员": [
        "我使用的输入设备很适合我的日常工作，特别是那些支持多语言输入和文化敏感性的设备。但在远程协作时，设备的文化适应性还需提高。",
        "我遇到的主要不便是在跨国团队合作时，设备的本地化功能不足以支持多元文化的交流。",
        "我希望输入设备能够提供更好的跨文化适应性，比如支持更多种语言和文化符号的输入。"
    ],
    "虚拟现实专家": [
        "我使用的输入设备非常适合VR环境，特别是那些支持手势识别和空间定位的设备。但是，当我在复杂的虚拟环境中导航时，设备的追踪精度有时会下降。",
        "我在使用输入设备时遇到的最大不便是在虚拟现实中进行精细的操作时，设备的追踪精度不够高。",
        "我希望输入设备能够提供更加精准的位置追踪，并且支持更丰富的手势输入，以提高虚拟环境中的交互体验。"
    ],
    "技术伦理学家": [
        "我使用的输入设备通常符合我的习惯，特别是那些注重隐私保护的产品。但在处理敏感信息时，设备的安全性还需进一步加强。",
        "我遇到的不便主要是在使用设备处理敏感数据时，担心数据泄露风险。",
        "我希望输入设备能够提供更强大的安全防护措施，比如生物特征认证和数据加密技术，以确保用户数据的安全。"
    ],
    "用户体验研究员": [
        "我使用的输入设备非常符合我的习惯，尤其是那些可以根据用户行为动态调整的设备。但在某些情况下，设备的自适应能力还有待提高。",
        "我在使用输入设备时遇到的主要不便是在使用不同应用程序时，设备的自适应程度不够。",
        "我希望输入设备能够更好地适应不同的应用场景，并且能够智能地预测用户的下一步操作。"
    ],
    "人机交互技术顾问": [
        "我使用的输入设备总体上满足了我的需求，尤其是那些支持多种输入方式的设备。但在一些特定的专业应用中，设备的功能还有待增强。",
        "我在使用输入设备时遇到的最大不便是在专业软件中，设备的快捷键配置有时不够灵活。",
        "我希望输入设备能够提供更多的可编程按键选项，并且支持更广泛的软件兼容性，以便更好地服务于专业应用领域。"
    ],

    # 中等专业水平角色
    "软件开发者": [
        "我使用的键盘和鼠标基本上符合我的习惯，特别是那些具有背光和宏功能的设备。但有时在长时间编码后，手腕会有不适。",
        "我在使用输入设备时遇到的最大不便是在编写复杂代码时，设备的快捷键配置不够直观。",
        "我希望输入设备能够提供更多的可编程按键选项，并且支持更灵活的宏命令设置，以提高编程效率。"
    ],
    "UX/UI设计师": [
        "我使用的绘图板和触控笔很符合我的习惯，特别是那些支持压力感应的设备。但在使用平板电脑进行设计时，有时会感觉不够精确。",
        "我在使用输入设备时遇到的主要不便是在进行精细的图形设计时，设备的压感不够灵敏。",
        "我希望输入设备能够提供更高的压力感应精度，并且支持更多的自定义快捷键，以适应不同的设计需求。"
    ],
    "产品经理": [
        "我使用的笔记本电脑和平板电脑通常符合我的习惯，特别是那些支持触控笔的设备。但在会议中使用时，设备的电池续航有时不足。",
        "我在使用输入设备时遇到的最大不便是在外出时，设备的电量不足以支撑全天的工作。",
        "我希望输入设备能够提供更长的电池续航，并且支持快速充电技术，以便在忙碌的工作日中保持高效。"
    ],
    "技术支持工程师": [
        "我使用的键盘和鼠标非常符合我的习惯，特别是那些具有额外功能键的设备。但在远程支持时，设备的连接稳定性有时会成为问题。",
        "我在使用输入设备时遇到的最大不便是在进行远程故障排除时，设备的延迟影响工作效率。",
        "我希望输入设备能够提供更稳定的无线连接，并且支持更低的延迟，以提高远程工作的效率。"
    ],
    "系统管理员": [
        "我使用的输入设备总体上符合我的习惯，特别是那些支持多种接口的设备。但在服务器机房使用时，设备的耐用性有时会受到挑战。",
        "我在使用输入设备时遇到的主要不便是在服务器机房中，设备容易遭受灰尘污染。",
        "我希望输入设备能够提供更好的耐用性和防尘设计，以适应恶劣的工作环境。"
    ],
    "数据分析师": [
        "我使用的键盘和鼠标符合我的习惯，特别是那些具有可编程宏的设备。但在处理大数据集时，设备的响应速度有时会变慢。",
        "我在使用输入设备时遇到的最大不便是在处理大量数据时，设备的性能瓶颈导致操作缓慢。",
        "我希望输入设备能够提供更快的响应速度，并且支持更多的并行计算功能，以加快数据分析过程。"
    ],
    "内容创作者": [
        "我使用的键盘和触控板符合我的习惯，特别是那些支持多点触控手势的设备。但在视频编辑时，设备的精确度有时会降低。",
        "我在使用输入设备时遇到的主要不便是在进行视频剪辑时，设备的触控精度不够。",
        "我希望输入设备能够提供更高的精确度，并且支持更多的自定义手势，以提高视频编辑的质量和效率。"
    ],
    "教育技术专家": [
        "我使用的输入设备通常符合我的习惯，特别是那些支持触摸屏的设备。但在教室里使用时，设备的可视角度有时会影响观看效果。",
        "我在使用输入设备时遇到的最大不便是在大教室中，设备的显示效果不佳。",
        "我希望输入设备能够提供更宽广的可视角度，并且支持更明亮的显示效果，以改善教室中的观看体验。"
    ],
    "游戏开发者": [
        "我使用的键盘和鼠标非常符合我的习惯，特别是那些支持RGB灯光的设备。但在长时间使用后，手腕会感到疲劳。",
        "我在使用输入设备时遇到的主要不便是在长时间游戏测试后，设备的舒适度降低。",
        "我希望输入设备能够提供更好的人体工学设计，减少长时间使用造成的身体不适，并且支持更多的可编程按键，以适应游戏开发的需求。"
    ],
    "数字营销专员": [
        "我使用的键盘和触控板符合我的习惯，特别是那些支持手势控制的设备。但在社交媒体管理时，设备的快捷键有时不够方便。",
        "我在使用输入设备时遇到的最大不便是在处理多个社交媒体账户时，设备的切换不够快速。",
        "我希望输入设备能够提供更多的快捷键选项，并且支持更快速的账户切换功能，以提高工作效率。"
    ],

    # 初等专业水平角色
    "普通消费者": [
        "我使用的鼠标和键盘基本符合我的习惯，但我有时会发现触控板的使用不如传统鼠标直观。",
        "我在使用输入设备时遇到的最大不便是在安装新设备时，经常找不到正确的驱动程序。",
        "我希望输入设备能够更加易于安装，并且提供更直观的用户指南，以便于初次使用者快速上手。"
    ],
    "中学生": [
        "我使用的输入设备通常符合我的习惯，特别是那些具有简单快捷键的设备。但在使用平板电脑时，有时会感觉不够直观。",
        "我在使用输入设备时遇到的最大不便是在完成作业时，设备的响应速度有时较慢。",
        "我希望输入设备能够提供更快的响应速度，并且支持更多的自定义快捷键，以简化常用任务的操作。"
    ],
    "家庭主妇/主夫": [
        "我使用的输入设备符合我的习惯，特别是那些支持语音输入的设备。但在做饭时，触摸屏的使用有时不太方便。",
        "我在使用输入设备时遇到的最大不便是在厨房里使用时，设备容易受到水溅。",
        "我希望输入设备能够提供更好的防水设计，并且支持更多的语音控制功能，以便在忙碌时也能轻松操控。"
    ],
    "老年人": [
        "我使用的输入设备通常符合我的习惯，特别是那些具有大字体的设备。但在使用智能手机时，有时会觉得触摸屏反应不够灵敏。",
        "我在使用输入设备时遇到的最大不便是在使用智能手机时，屏幕亮度有时不够。",
        "我希望输入设备能够提供更大的字体选项，并且支持更明亮的屏幕显示，以适应视力逐渐减弱的情况。"
    ],
    "残障人士": [
        "我使用的输入设备基本符合我的习惯，特别是那些支持辅助技术的设备。但在使用触控板时，有时会感觉不够精确。",
        "我在使用输入设备时遇到的最大不便是在进行精确操作时，设备的反馈不够明显。",
        "我希望输入设备能够提供更多的辅助功能，并且支持更大的触控区域，以适应不同的身体条件。"
    ],
    "零售店员": [
        "我使用的条形码扫描器符合我的习惯，但在处理大量商品时，设备的扫描速度有时不够快。",
        "我在使用输入设备时遇到的最大不便是在高峰时段，设备的响应速度减慢。",
        "我希望输入设备能够提供更快的扫描速度，并且支持更远距离的无线连接，以提高工作效率。"
    ],
    "非技术工作者": [
        "我使用的键盘和鼠标符合我的习惯，但在使用办公软件时，设备的快捷键有时不够直观。",
        "我在使用输入设备时遇到的最大不便是在学习新软件时，设备的学习曲线较陡。",
        "我希望输入设备能够提供更直观的快捷键，并且支持更多的自定义选项，以适应不同用户的个性化需求。"
    ],
    "自由职业者": [
        "我使用的笔记本电脑和平板电脑符合我的习惯，但在远程工作时，设备的电池续航有时不足。",
        "我在使用输入设备时遇到的最大不便是在户外使用时，设备的屏幕反光严重。",
        "我希望输入设备能够提供更长的电池续航能力，并且支持更好的抗反射屏幕，以适应各种工作环境。"
    ],
    "游戏爱好者": [
        "我使用的键盘和鼠标符合我的习惯，特别是在玩游戏时。但在长时间游戏后，设备的温度有时过高。",
        "我在使用输入设备时遇到的最大不便是在进行激烈的游戏时，设备的散热不够。",
        "我希望输入设备能够提供更好的散热设计，并且支持更舒适的握持体验，以减少长时间游戏带来的不适。"
    ],
    "退休人员": [
        "我使用的输入设备通常符合我的习惯，特别是那些具有大字体的设备。但在使用智能手机时，有时会觉得触摸屏反应不够灵敏。",
        "我在使用输入设备时遇到的最大不便是在使用智能手机时，屏幕亮度有时不够。",
        "我希望输入设备能够提供更大的字体选项，并且支持更明亮的屏幕显示，以适应视力变化的需求。"
    ]
}
Q["Question_2"]["response_qwen2"]=response_qwen2

# %%
occupations = [
    # 高专业程度 (Advanced) - 5
    "人机交互研究员", "交互设计专家", "计算机科学教授", "人工智能研究员", "认知科学专家",
    "社会学研究员", "虚拟现实专家", "技术伦理学家", "用户体验研究员", "人机交互技术顾问",

    # 中等专业程度 (Intermediate) - 3
    "软件开发者", "UX/UI设计师", "产品经理", "技术支持工程师", "系统管理员",
    "数据分析师", "内容创作者", "教育技术专家", "游戏开发者", "数字营销专员",

    # 低专业程度 (Beginner) - 1
    "普通消费者", "中学生", "家庭主妇/主夫", "老年人", "残障人士",
    "零售店员", "非技术工作者", "自由职业者", "游戏爱好者", "退休人员"
]


print(Q.keys())
print(Q['Question_2'].keys())
print(Q['Question_2']['Question_2'])
print(Q['Question_2']['questions_2'])
print(Q['Question_2']['responses_chatglm'].keys())
print(Q['Question_2']['responses_chatglm']['软件开发者'])
#'responses_qwen', 'responses_doubao', 'response_qwen2'和responses_chatglm中格式一致
# Out:
# dict_keys(['Question_2'])
# dict_keys(['Question_2', 'questions_2', 'responses_chatglm', 'responses_qwen', 'responses_doubao', 'response_qwen2'])
# (User Preferences) 当前输入设备是否符合你的操作习惯？(Usability Challenges) 你在使用输入设备时是否遇到过任何不便？(Design Improvements) 你希望输入设备在设计上有哪些改进？
# ['当前输入设备是否符合你的操作习惯？', '你在使用输入设备时是否遇到过任何不便？', '你希望输入设备在设计上有哪些改进？']
# dict_keys(['人机交互研究员', '交互设计专家', '计算机科学教授', '人工智能研究员', '认知科学专家', '社会学研究员', '虚拟现实专家', '技术伦理学家', '用户体验研究员', '人机交互技术顾问', '软件开发者', 'UX/UI设计师', '产品经理', '技术支持工程师', '系统管理员', '数据分析师', '内容创作者', '教育技术专家', '游戏开发者', '数字营销专员', '普通消费者', '中学生', '家庭主妇/主夫', '老年人', '残障人士', '零售店员', '非技术工作者', '自由职业者', '游戏爱好者', '退休人员'])
# ['当前输入设备基本符合我的操作习惯，但在开发复杂项目时，输入设备的响应速度有些慢。', '我在使用输入设备时遇到了一些输入设备在处理复杂项目需求时的效率问题。', '我希望输入设备能够提供更加快速和高效的开发工具。']

# %%
import json
# 指定要保存的 JSON 文件名
filename = 'Question_2_data.json'

# 将字典写入 JSON 文件
with open(filename, 'w') as f:
    json.dump(Q, f, indent=4)

# %%
from datetime import datetime

# 获取当前时间
current_time = datetime.now()

# 打印当前时间
print(current_time.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2024-08-06 20:50:40
